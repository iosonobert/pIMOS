# %%
import zutils.file as zfile

from pIMOS.xrwrap import solander_ctd
from pIMOS.xrwrap import rsi_vmp
import pIMOS.xrwrap.lisst as lisst

# import pIMOS.xrwrap.SEABIRD_37_39_56 as wrap_sbd

import os
import matplotlib.pyplot as plt
import datetime
import numpy as np 
import pandas as pd
import xarray as xr
import glob

from pIMOS.utils import othertime
import pIMOS.utils.quality_control as pqc
import importlib

# O Drive is //drive.irds.uwa.edu.au/CEME-BBL-001
# pIMOS_export_dir = r'O:\Data\pIMOS\KISSME'

project_root = r'G:\Experiments\kissme17'
# project_root = r'D:\Experiments\kissme17'
project_root = r'E:\Experiments\kissme17'

archive_dir = os.path.join(project_root, 'Archive_Profiling_FV00') 
dbconfig_file = os.path.join('./', 'database', 'config.txt') 

if not os.path.exists(archive_dir):
    os.mkdir(archive_dir)
    
import pIMOS.utils.UWA_archive_utils as ai

db_config = ai.parse_dbconfig(dbconfig_file)
db_data = ai.read_db(dbconfig_file)
db_config
db_data
# Out:
# <frozen importlib._bootstrap>:228: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject
# autonomous_metadata = pIMOS_KISSME_Instruments.csv
#
# profiler_metadata = pIMOS_KISSME2017_CTDVMP_Logbook.csv
#
# possible_mooring_dates = pIMOS_possible_mooring_dates.csv
# autonomous_metadata = pIMOS_KISSME_Instruments.csv
#
# profiler_metadata = pIMOS_KISSME2017_CTDVMP_Logbook.csv
#
# possible_mooring_dates = pIMOS_possible_mooring_dates.csv
# {'autonomous_metadata':         Project            Site StationID        Type Trip Recovered  \
#  0      IMOS NWS    Browse Shelf    BRB200      Moored            NaN
#  1      IMOS NWS    Browse Shelf    BRB200      Moored            NaN
#  2      IMOS NWS    Browse Shelf    BRB200      Moored            NaN
#  3      IMOS NWS    Browse Shelf    BRB200      Moored            NaN
#  4      IMOS NWS    Browse Shelf    BRB200      Moored            NaN
#  ..          ...             ...       ...         ...            ...
#  127  KISSME2017  Browse Prelude     WP250      Moored     KISSME_REC
#  128  KISSME2017  Browse Prelude     WP250      Moored     KISSME_REC
#  129  KISSME2017  Browse Prelude     WP250      Moored     KISSME_REC
#  130  KISSME2017  Browse Prelude     WP250      Moored     KISSME_REC
#  131  KISSME2017  Browse Prelude       NaN  ProfileAux     KISSME_DEP
#
#       Longitude  Latitude  Depth TimeZone  InstrumentDepth  \
#  0     123.0459  -14.2426 -200.0      UTC           -193.1
#  1     123.0459  -14.2426 -200.0      UTC            -22.0
#  2     123.0459  -14.2426 -200.0      UTC            -38.0
#  3     123.0459  -14.2426 -200.0      UTC            -40.2
#  4     123.0459  -14.2426 -200.0      UTC            -50.2
#  ..         ...       ...    ...      ...              ...
#  127   123.3490  -13.7659 -252.0      UTC            -62.0
#  128   123.3490  -13.7659 -252.0      UTC            -62.0
#  129   123.3490  -13.7659 -252.0      UTC            -62.0
#  130   123.3490  -13.7659 -252.0      UTC            -22.0
#  131        NaN       NaN    NaN      UTC              NaN
#
#                           FileName                FilePath  \
#  0                    6752_000.000      Data\RDIADCP\16752
#  1    sbe37sm_08753_2017_05_23.cnv              Data\SBE37
#  2         Minilog-II-T_357688.csv              Data\Vemco
#  3    sbe37sm_08752_2017_05_23.cnv              Data\SBE37
#  4                    58551705.asc              Data\SBE39
#  ..                            ...                     ...
#  127                      3750.asc              Data\SBE39
#  128                      3749.asc              Data\SBE39
#  129                      3747.asc              Data\SBE39
#  130                      6526.asc              Data\SBE39
#  131                      L09*.csv  ProfileData\LISST\2009
#
#                  InstrumentType  SerialNo  InstrumentHeight  DeploymentHeight  \
#  0    RDI 150 kHz Quartermaster     16752               6.9              6.90
#  1                    SBE37 CTD      8753             178.0            178.00
#  2                      Vemco T    357688             162.0            162.00
#  3                    SBE37 CTD      8752             159.8            159.80
#  4                     SBE39 TP      5855             149.8            149.80
#  ..                         ...       ...               ...               ...
#  127                    SBE39 T      3750             190.0            169.97
#  128                    SBE39 T      3749             190.0            149.97
#  129                    SBE39 T      3747             190.0            139.97
#  130                   SBE39 TP      6526             230.0            229.97
#  131                 LISST 200X      2009               NaN               NaN
#
#      Orientation SidelobeInt
#  0            up    pressure
#  1           NaN         NaN
#  2           NaN         NaN
#  3           NaN         NaN
#  4           NaN         NaN
#  ..          ...         ...
#  127         NaN         NaN
#  128         NaN         NaN
#  129         NaN         NaN
#  130         NaN         NaN
#  131         NaN         NaN
#
#  [132 rows x 18 columns],
#  'profiler_metadata':         Project                  Trip      StationID Profiler in [DateUTC]  \
#  0    KISSME2017  KISSME2017Deployment         BRD200            31/03/2017
#  1    KISSME2017  KISSME2017Deployment         BRD200            31/03/2017
#  2    KISSME2017  KISSME2017Deployment         BRD200            31/03/2017
#  3    KISSME2017  KISSME2017Deployment         BRD200            31/03/2017
#  4    KISSME2017  KISSME2017Deployment         BRD200            31/03/2017
#  ..          ...                   ...            ...                   ...
#  122  KISSME2017  KISSME2017Deployment  UWAD_transect             7/04/2017
#  123  KISSME2017  KISSME2017Deployment  UWAD_transect             7/04/2017
#  124  KISSME2017  KISSME2017Deployment  UWAD_transect             7/04/2017
#  125  KISSME2017  KISSME2017Deployment            NaN                   NaN
#  126  KISSME2017  KISSME2017Deployment            NaN                   NaN
#
#      Profiler in [TimeUTC] Profiler out [TimeUTC]  Profiler in [Lat]  \
#  0                    4:30                    NaN                NaN
#  1                    5:32                   5:39                NaN
#  2                    5:55                   6:09                NaN
#  3                    6:14                   6:29                NaN
#  4                    6:32                   6:49                NaN
#  ..                    ...                    ...                ...
#  122                  4:56                    NaN          -14.23913
#  123                  6:22                    NaN          -14.23576
#  124                  7:23                    NaN          -14.22950
#  125                   NaN                    NaN                NaN
#  126                   NaN                    NaN                NaN
#
#       Profiler in [Lon]     Filename    InstrumentType  ...  \
#  0                  NaN       BRD200      Solander CTD  ...
#  1                  NaN  BRD200A_001      Solander CTD  ...
#  2                  NaN  BRD200A_002      Solander CTD  ...
#  3                  NaN  BRD200A_003      Solander CTD  ...
#  4                  NaN  BRD200A_004      Solander CTD  ...
#  ..                 ...          ...               ...  ...
#  122          123.04561      UWA_038  rockland_vmp_250  ...
#  123          123.04538      UWA_039  rockland_vmp_250  ...
#  124          123.04568      UWA_040  rockland_vmp_250  ...
#  125                NaN      UWA_041  rockland_vmp_250  ...
#  126                NaN      UWA_042  rockland_vmp_250  ...
#
#       Cast Depth Screen (m)  Depth Sounder (m)  Total Depth (m)  \
#  0                      NaN              200.0            202.0
#  1                    210.0              219.0            221.0
#  2                    237.5              247.0            249.0
#  3                    248.8              256.0            258.0
#  4                    256.5              264.0            266.0
#  ..                     ...                ...              ...
#  122                    NaN                NaN              NaN
#  123                    NaN                NaN              NaN
#  124                    NaN                NaN              NaN
#  125                    NaN                NaN              NaN
#  126                    NaN                NaN              NaN
#
#                                            Comment  UWA Bottles  \
#  0                                             NaN          NaN
#  1                             Falling Tide (500m)          NaN
#  2    (1000m), changed LISST set to 1 MA from 1 MA          NaN
#  3                                             NaN          NaN
#  4                                             NaN          NaN
#  ..                                            ...          ...
#  122                                           NaN          NaN
#  123                                           NaN          NaN
#  124                                           NaN          NaN
#  125                                           NaN          NaN
#  126                                           NaN          NaN
#
#      LISST Raw Filename Unnamed: 18 LISST NC Filename  Unnamed: 20  \
#  0             L0900428         NaN       L0900428_rs          NaN
#  1             L0900523         NaN       L0900523_rs          NaN
#  2             L0900554         NaN       L0900554_rs          NaN
#  3             L0900613         NaN       L0900613_rs          NaN
#  4             L0900632         NaN     L0900632-A_rs          NaN
#  ..                 ...         ...               ...          ...
#  122                NaN         NaN               NaN          NaN
#  123                NaN         NaN               NaN          NaN
#  124                NaN         NaN               NaN          NaN
#  125                NaN         NaN               NaN          NaN
#  126                NaN         NaN               NaN          NaN
#
#      UWA Niskin Bottle No. + Depth (m)
#  0                                 NaN
#  1                                 NaN
#  2                                 NaN
#  3                                 NaN
#  4                                 NaN
#  ..                                ...
#  122                               NaN
#  123                               NaN
#  124                               NaN
#  125                               NaN
#  126                               NaN
#
#  [127 rows x 22 columns],
#  'possible_mooring_dates':   Experiment        Recovered       Mooring           StartDate  \
#  0     kissme  kissme_recovery         sp250 2017-04-01 09:00:00
#  1     kissme  kissme_recovery  sp250-lander 2017-04-01 09:00:00
#  2     kissme  kissme_recovery         np250 2017-04-02 09:00:00
#  3     kissme  kissme_recovery         wp250 2017-04-02 09:00:00
#
#                EndDate
#  0 2017-05-21 23:30:00
#  1 2017-05-21 23:30:00
#  2 2017-05-21 23:30:00
#  3 2017-05-21 23:30:00  }

# %%
db_data['profiler_metadata']

direc = r'D:\Experiments\kissme17\ProfileData\CTD'
direc = r'E:/Experiments/kissme17/ProfileData/CTD/'
# instrument = ''

for index, row in db_data['profiler_metadata'].iterrows():

    attributes = ai.profiler_row_to_attrs(row)
    instrument = attributes['instrument_model']
    filename = attributes['raw_file_name']
    
    if not type(instrument) == str:
        print('Skipping')
        continue
    if not instrument.lower() in ['solander ctd']:
        print('Skipping')
        continue

    cnvfile = os.path.join(direc, filename+'.cnv')
    
    rr, ds = solander_ctd.from_cnvfile(cnvfile)
    rr.update_attributes_with_dict(attributes)
    
    comment_fields = ['UWA Niskin Bottle No. + Depth (m)', 'UWA Bottles', 'LISST Raw Filename', 'Comment']
    for field in comment_fields:
        print()
        if type(row[field]) == str:
            comment = field + ': ' + row[field]
        elif np.isnan(row[field]):
            comment = field + ': - '
        else:
            comment = field + ': ' + str(row[field])

        rr.add_comment('UWA', comment)

    rr.ds['t190C'].plot()
    plt.grid()
    plt.show()
    
    fn = filename
    ai.pIMOS_export(rr, archive_dir, instrument)
# Out:
# Initialising accessor.
# STORING RAW FILE ATTRIBUTES
# Setting attribute "raw_file_name" to "BRD200.cnv"
# Setting attribute "raw_file_directory" to "E:/Experiments/kissme17/ProfileData/CTD"
# {'title': '', 'institution': 'The University of Western Australia', 'institution_division': 'Ocean Dynamics', 'source': '', 'project': '', 'history': '', 'references': '', 'comment': '', 'Conventions': 'CF-1.7', 'trip': '', 'trip_deployed': '', 'site': '', 'site_station': '', 'instrument_make': '', 'instrument_model': '', 'instrument_serial_number': '', 'raw_file_name': 'BRD200.cnv', 'raw_file_directory': 'E:/Experiments/kissme17/ProfileData/CTD', 'raw_file_attributes': '', 'last_export_file_name': '', 'last_export_directory': '', 'last_load_file_name': '', 'last_load_directory': '', 'outfile_append': '', 'disclaimer': '', 'nominal_latitude': '', 'nominal_longitude': '', 'nominal_site_depth': '', 'pressure_sensor_height_asb': '', 'nominal_instrument_height_asb': '', 'nominal_instrument_orientation': '', 'timezone': '', 'is_profile_data': 0}
# Setting attribute "title" to "Measured data from a profiling Seabird CTD"
# Setting attribute "source" to "Profiling CTD from A.I.M.S. R.V. Solander"
# Setting attribute "project" to "KISSME2017"
# Setting attribute "raw_file_name" to "BRD200"
# Setting attribute "site_station" to "BRD200"
# Setting attribute "trip" to "KISSME2017Deployment"
# Setting attribute "is_profile_data" to "1"
# Setting attribute "timezone" to "UTC"
# Setting attribute "instrument_model" to "Solander CTD"
# Setting attribute "nominal_latitude" to ""
# Setting attribute "nominal_longitude" to ""
# Setting attribute "nominal_site_depth" to "202.0"
# E:\Experiments\kissme17\Archive_Profiling_FV00\Solander CTD
# Generating filename from naming convention.
# Best export dir is the raw_file_directory.
# Will to user input directory.
# Exporting E:\Experiments\kissme17\Archive_Profiling_FV00\Solander CTD//[KISSME2017]_[KISSME2017Deployment]_[BRD200]_[Solander CTD]_[]_[BRD200]_[].nc
# Initialising accessor.
# STORING RAW FILE ATTRIBUTES
# Setting attribute "raw_file_name" to "BRD200A_001.cnv"
# Setting attribute "raw_file_directory" to "E:/Experiments/kissme17/ProfileData/CTD"
# {'title': '', 'institution': 'The University of Western Australia', 'institution_division': 'Ocean Dynamics', 'source': '', 'project': '', 'history': '', 'references': '', 'comment': '', 'Conventions': 'CF-1.7', 'trip': '', 'trip_deployed': '', 'site': '', 'site_station': '', 'instrument_make': '', 'instrument_model': '', 'instrument_serial_number': '', 'raw_file_name': 'BRD200A_001.cnv', 'raw_file_directory': 'E:/Experiments/kissme17/ProfileData/CTD', 'raw_file_attributes': '', 'last_export_file_name': '', 'last_export_directory': '', 'last_load_file_name': '', 'last_load_directory': '', 'outfile_append': '', 'disclaimer': '', 'nominal_latitude': '', 'nominal_longitude': '', 'nominal_site_depth': '', 'pressure_sensor_height_asb': '', 'nominal_instrument_height_asb': '', 'nominal_instrument_orientation': '', 'timezone': '', 'is_profile_data': 0}
# Setting attribute "title" to "Measured data from a profiling Seabird CTD"
# Setting attribute "source" to "Profiling CTD from A.I.M.S. R.V. Solander"
# Setting attribute "project" to "KISSME2017"
# Setting attribute "raw_file_name" to "BRD200A_001"
# Setting attribute "site_station" to "BRD200"
# Setting attribute "trip" to "KISSME2017Deployment"
# Setting attribute "is_profile_data" to "1"
# Setting attribute "timezone" to "UTC"
# Setting attribute "instrument_model" to "Solander CTD"
# Setting attribute "nominal_latitude" to ""
# Setting attribute "nominal_longitude" to ""
# Setting attribute "nominal_site_depth" to "221.0"
# E:\Experiments\kissme17\Archive_Profiling_FV00\Solander CTD
# Generating filename from naming convention.
# Best export dir is the raw_file_directory.
# Will to user input directory.
# Exporting E:\Experiments\kissme17\Archive_Profiling_FV00\Solander CTD//[KISSME2017]_[KISSME2017Deployment]_[BRD200]_[Solander CTD]_[]_[BRD200A_001]_[].nc
# Initialising accessor.
# STORING RAW FILE ATTRIBUTES
# Setting attribute "raw_file_name" to "BRD200A_002.cnv"
# Setting attribute "raw_file_directory" to "E:/Experiments/kissme17/ProfileData/CTD"
# {'title': '', 'institution': 'The University of Western Australia', 'institution_division': 'Ocean Dynamics', 'source': '', 'project': '', 'history': '', 'references': '', 'comment': '', 'Conventions': 'CF-1.7', 'trip': '', 'trip_deployed': '', 'site': '', 'site_station': '', 'instrument_make': '', 'instrument_model': '', 'instrument_serial_number': '', 'raw_file_name': 'BRD200A_002.cnv', 'raw_file_directory': 'E:/Experiments/kissme17/ProfileData/CTD', 'raw_file_attributes': '', 'last_export_file_name': '', 'last_export_directory': '', 'last_load_file_name': '', 'last_load_directory': '', 'outfile_append': '', 'disclaimer': '', 'nominal_latitude': '', 'nominal_longitude': '', 'nominal_site_depth': '', 'pressure_sensor_height_asb': '', 'nominal_instrument_height_asb': '', 'nominal_instrument_orientation': '', 'timezone': '', 'is_profile_data': 0}
# Setting attribute "title" to "Measured data from a profiling Seabird CTD"
# Setting attribute "source" to "Profiling CTD from A.I.M.S. R.V. Solander"
# Setting attribute "project" to "KISSME2017"
# Setting attribute "raw_file_name" to "BRD200A_002"
# Setting attribute "site_station" to "BRD200"
# Setting attribute "trip" to "KISSME2017Deployment"
# Setting attribute "is_profile_data" to "1"
# Setting attribute "timezone" to "UTC"
# Setting attribute "instrument_model" to "Solander CTD"
# Setting attribute "nominal_latitude" to ""
# Setting attribute "nominal_longitude" to ""
# Setting attribute "nominal_site_depth" to "249.0"
# E:\Experiments\kissme17\Archive_Profiling_FV00\Solander CTD
# Generating filename from naming convention.
# Best export dir is the raw_file_directory.
# Will to user input directory.
# Exporting E:\Experiments\kissme17\Archive_Profiling_FV00\Solander CTD//[KISSME2017]_[KISSME2017Deployment]_[BRD200]_[Solander CTD]_[]_[BRD200A_002]_[].nc
# Initialising accessor.
# STORING RAW FILE ATTRIBUTES
# Setting attribute "raw_file_name" to "BRD200A_003.cnv"
# Setting attribute "raw_file_directory" to "E:/Experiments/kissme17/ProfileData/CTD"
# {'title': '', 'institution': 'The University of Western Australia', 'institution_division': 'Ocean Dynamics', 'source': '', 'project': '', 'history': '', 'references': '', 'comment': '', 'Conventions': 'CF-1.7', 'trip': '', 'trip_deployed': '', 'site': '', 'site_station': '', 'instrument_make': '', 'instrument_model': '', 'instrument_serial_number': '', 'raw_file_name': 'BRD200A_003.cnv', 'raw_file_directory': 'E:/Experiments/kissme17/ProfileData/CTD', 'raw_file_attributes': '', 'last_export_file_name': '', 'last_export_directory': '', 'last_load_file_name': '', 'last_load_directory': '', 'outfile_append': '', 'disclaimer': '', 'nominal_latitude': '', 'nominal_longitude': '', 'nominal_site_depth': '', 'pressure_sensor_height_asb': '', 'nominal_instrument_height_asb': '', 'nominal_instrument_orientation': '', 'timezone': '', 'is_profile_data': 0}
# Setting attribute "title" to "Measured data from a profiling Seabird CTD"
# Setting attribute "source" to "Profiling CTD from A.I.M.S. R.V. Solander"
# Setting attribute "project" to "KISSME2017"
# Setting attribute "raw_file_name" to "BRD200A_003"
# Setting attribute "site_station" to "BRD200"
# Setting attribute "trip" to "KISSME2017Deployment"
# Setting attribute "is_profile_data" to "1"
# Setting attribute "timezone" to "UTC"
# Setting attribute "instrument_model" to "Solander CTD"
# Setting attribute "nominal_latitude" to ""
# Setting attribute "nominal_longitude" to ""
# Setting attribute "nominal_site_depth" to "258.0"
# E:\Experiments\kissme17\Archive_Profiling_FV00\Solander CTD
# Generating filename from naming convention.
# Best export dir is the raw_file_directory.
# Will to user input directory.
# Exporting E:\Experiments\kissme17\Archive_Profiling_FV00\Solander CTD//[KISSME2017]_[KISSME2017Deployment]_[BRD200]_[Solander CTD]_[]_[BRD200A_003]_[].nc
# Initialising accessor.
# STORING RAW FILE ATTRIBUTES
# Setting attribute "raw_file_name" to "BRD200A_004.cnv"
# Setting attribute "raw_file_directory" to "E:/Experiments/kissme17/ProfileData/CTD"
# {'title': '', 'institution': 'The University of Western Australia', 'institution_division': 'Ocean Dynamics', 'source': '', 'project': '', 'history': '', 'references': '', 'comment': '', 'Conventions': 'CF-1.7', 'trip': '', 'trip_deployed': '', 'site': '', 'site_station': '', 'instrument_make': '', 'instrument_model': '', 'instrument_serial_number': '', 'raw_file_name': 'BRD200A_004.cnv', 'raw_file_directory': 'E:/Experiments/kissme17/ProfileData/CTD', 'raw_file_attributes': '', 'last_export_file_name': '', 'last_export_directory': '', 'last_load_file_name': '', 'last_load_directory': '', 'outfile_append': '', 'disclaimer': '', 'nominal_latitude': '', 'nominal_longitude': '', 'nominal_site_depth': '', 'pressure_sensor_height_asb': '', 'nominal_instrument_height_asb': '', 'nominal_instrument_orientation': '', 'timezone': '', 'is_profile_data': 0}
# Setting attribute "title" to "Measured data from a profiling Seabird CTD"
# Setting attribute "source" to "Profiling CTD from A.I.M.S. R.V. Solander"
# Setting attribute "project" to "KISSME2017"
# Setting attribute "raw_file_name" to "BRD200A_004"
# Setting attribute "site_station" to "BRD200"
# Setting attribute "trip" to "KISSME2017Deployment"
# Setting attribute "is_profile_data" to "1"
# Setting attribute "timezone" to "UTC"
# Setting attribute "instrument_model" to "Solander CTD"
# Setting attribute "nominal_latitude" to ""
# Setting attribute "nominal_longitude" to ""
# Setting attribute "nominal_site_depth" to "266.0"
# E:\Experiments\kissme17\Archive_Profiling_FV00\Solander CTD
# Generating filename from naming convention.
# Best export dir is the raw_file_directory.
# Will to user input directory.
# Exporting E:\Experiments\kissme17\Archive_Profiling_FV00\Solander CTD//[KISSME2017]_[KISSME2017Deployment]_[BRD200]_[Solander CTD]_[]_[BRD200A_004]_[].nc
# Initialising accessor.
# STORING RAW FILE ATTRIBUTES
# Setting attribute "raw_file_name" to "BRD200A_005.cnv"
# Setting attribute "raw_file_directory" to "E:/Experiments/kissme17/ProfileData/CTD"
# {'title': '', 'institution': 'The University of Western Australia', 'institution_division': 'Ocean Dynamics', 'source': '', 'project': '', 'history': '', 'references': '', 'comment': '', 'Conventions': 'CF-1.7', 'trip': '', 'trip_deployed': '', 'site': '', 'site_station': '', 'instrument_make': '', 'instrument_model': '', 'instrument_serial_number': '', 'raw_file_name': 'BRD200A_005.cnv', 'raw_file_directory': 'E:/Experiments/kissme17/ProfileData/CTD', 'raw_file_attributes': '', 'last_export_file_name': '', 'last_export_directory': '', 'last_load_file_name': '', 'last_load_directory': '', 'outfile_append': '', 'disclaimer': '', 'nominal_latitude': '', 'nominal_longitude': '', 'nominal_site_depth': '', 'pressure_sensor_height_asb': '', 'nominal_instrument_height_asb': '', 'nominal_instrument_orientation': '', 'timezone': '', 'is_profile_data': 0}
# Setting attribute "title" to "Measured data from a profiling Seabird CTD"
# Setting attribute "source" to "Profiling CTD from A.I.M.S. R.V. Solander"
# Setting attribute "project" to "KISSME2017"
# Setting attribute "raw_file_name" to "BRD200A_005"
# Setting attribute "site_station" to "BRD200"
# Setting attribute "trip" to "KISSME2017Deployment"
# Setting attribute "is_profile_data" to "1"
# Setting attribute "timezone" to "UTC"
# Setting attribute "instrument_model" to "Solander CTD"
# Setting attribute "nominal_latitude" to ""
# Setting attribute "nominal_longitude" to ""
# Setting attribute "nominal_site_depth" to "272.0"
# E:\Experiments\kissme17\Archive_Profiling_FV00\Solander CTD
# Generating filename from naming convention.
# Best export dir is the raw_file_directory.
# Will to user input directory.
# Exporting E:\Experiments\kissme17\Archive_Profiling_FV00\Solander CTD//[KISSME2017]_[KISSME2017Deployment]_[BRD200]_[Solander CTD]_[]_[BRD200A_005]_[].nc
# Initialising accessor.
# STORING RAW FILE ATTRIBUTES
# Setting attribute "raw_file_name" to "BRD200A_006.cnv"
# Setting attribute "raw_file_directory" to "E:/Experiments/kissme17/ProfileData/CTD"
# {'title': '', 'institution': 'The University of Western Australia', 'institution_division': 'Ocean Dynamics', 'source': '', 'project': '', 'history': '', 'references': '', 'comment': '', 'Conventions': 'CF-1.7', 'trip': '', 'trip_deployed': '', 'site': '', 'site_station': '', 'instrument_make': '', 'instrument_model': '', 'instrument_serial_number': '', 'raw_file_name': 'BRD200A_006.cnv', 'raw_file_directory': 'E:/Experiments/kissme17/ProfileData/CTD', 'raw_file_attributes': '', 'last_export_file_name': '', 'last_export_directory': '', 'last_load_file_name': '', 'last_load_directory': '', 'outfile_append': '', 'disclaimer': '', 'nominal_latitude': '', 'nominal_longitude': '', 'nominal_site_depth': '', 'pressure_sensor_height_asb': '', 'nominal_instrument_height_asb': '', 'nominal_instrument_orientation': '', 'timezone': '', 'is_profile_data': 0}
# Setting attribute "title" to "Measured data from a profiling Seabird CTD"
# Setting attribute "source" to "Profiling CTD from A.I.M.S. R.V. Solander"
# Setting attribute "project" to "KISSME2017"
# Setting attribute "raw_file_name" to "BRD200A_006"
# Setting attribute "site_station" to "BRD200"
# Setting attribute "trip" to "KISSME2017Deployment"
# Setting attribute "is_profile_data" to "1"
# Setting attribute "timezone" to "UTC"
# Setting attribute "instrument_model" to "Solander CTD"
# Setting attribute "nominal_latitude" to ""
# Setting attribute "nominal_longitude" to ""
# Setting attribute "nominal_site_depth" to "277.0"
# E:\Experiments\kissme17\Archive_Profiling_FV00\Solander CTD
# Generating filename from naming convention.
# Best export dir is the raw_file_directory.
# Will to user input directory.
# Exporting E:\Experiments\kissme17\Archive_Profiling_FV00\Solander CTD//[KISSME2017]_[KISSME2017Deployment]_[BRD200]_[Solander CTD]_[]_[BRD200A_006]_[].nc
# Initialising accessor.
# STORING RAW FILE ATTRIBUTES
# Setting attribute "raw_file_name" to "BRD200A_007.cnv"
# Setting attribute "raw_file_directory" to "E:/Experiments/kissme17/ProfileData/CTD"
# {'title': '', 'institution': 'The University of Western Australia', 'institution_division': 'Ocean Dynamics', 'source': '', 'project': '', 'history': '', 'references': '', 'comment': '', 'Conventions': 'CF-1.7', 'trip': '', 'trip_deployed': '', 'site': '', 'site_station': '', 'instrument_make': '', 'instrument_model': '', 'instrument_serial_number': '', 'raw_file_name': 'BRD200A_007.cnv', 'raw_file_directory': 'E:/Experiments/kissme17/ProfileData/CTD', 'raw_file_attributes': '', 'last_export_file_name': '', 'last_export_directory': '', 'last_load_file_name': '', 'last_load_directory': '', 'outfile_append': '', 'disclaimer': '', 'nominal_latitude': '', 'nominal_longitude': '', 'nominal_site_depth': '', 'pressure_sensor_height_asb': '', 'nominal_instrument_height_asb': '', 'nominal_instrument_orientation': '', 'timezone': '', 'is_profile_data': 0}
# Setting attribute "title" to "Measured data from a profiling Seabird CTD"
# Setting attribute "source" to "Profiling CTD from A.I.M.S. R.V. Solander"
# Setting attribute "project" to "KISSME2017"
# Setting attribute "raw_file_name" to "BRD200A_007"
# Setting attribute "site_station" to "BRD200"
# Setting attribute "trip" to "KISSME2017Deployment"
# Setting attribute "is_profile_data" to "1"
# Setting attribute "timezone" to "UTC"
# Setting attribute "instrument_model" to "Solander CTD"
# Setting attribute "nominal_latitude" to ""
# Setting attribute "nominal_longitude" to ""
# Setting attribute "nominal_site_depth" to "279.0"
# E:\Experiments\kissme17\Archive_Profiling_FV00\Solander CTD
# Generating filename from naming convention.
# Best export dir is the raw_file_directory.
# Will to user input directory.
# Exporting E:\Experiments\kissme17\Archive_Profiling_FV00\Solander CTD//[KISSME2017]_[KISSME2017Deployment]_[BRD200]_[Solander CTD]_[]_[BRD200A_007]_[].nc
# Initialising accessor.
# STORING RAW FILE ATTRIBUTES
# Setting attribute "raw_file_name" to "BRD200A_008.cnv"
# Setting attribute "raw_file_directory" to "E:/Experiments/kissme17/ProfileData/CTD"
# {'title': '', 'institution': 'The University of Western Australia', 'institution_division': 'Ocean Dynamics', 'source': '', 'project': '', 'history': '', 'references': '', 'comment': '', 'Conventions': 'CF-1.7', 'trip': '', 'trip_deployed': '', 'site': '', 'site_station': '', 'instrument_make': '', 'instrument_model': '', 'instrument_serial_number': '', 'raw_file_name': 'BRD200A_008.cnv', 'raw_file_directory': 'E:/Experiments/kissme17/ProfileData/CTD', 'raw_file_attributes': '', 'last_export_file_name': '', 'last_export_directory': '', 'last_load_file_name': '', 'last_load_directory': '', 'outfile_append': '', 'disclaimer': '', 'nominal_latitude': '', 'nominal_longitude': '', 'nominal_site_depth': '', 'pressure_sensor_height_asb': '', 'nominal_instrument_height_asb': '', 'nominal_instrument_orientation': '', 'timezone': '', 'is_profile_data': 0}
# Setting attribute "title" to "Measured data from a profiling Seabird CTD"
# Setting attribute "source" to "Profiling CTD from A.I.M.S. R.V. Solander"
# Setting attribute "project" to "KISSME2017"
# Setting attribute "raw_file_name" to "BRD200A_008"
# Setting attribute "site_station" to "BRD200"
# Setting attribute "trip" to "KISSME2017Deployment"
# Setting attribute "is_profile_data" to "1"
# Setting attribute "timezone" to "UTC"
# Setting attribute "instrument_model" to "Solander CTD"
# Setting attribute "nominal_latitude" to ""
# Setting attribute "nominal_longitude" to ""
# Setting attribute "nominal_site_depth" to "288.0"
# E:\Experiments\kissme17\Archive_Profiling_FV00\Solander CTD
# Generating filename from naming convention.
# Best export dir is the raw_file_directory.
# Will to user input directory.
# Exporting E:\Experiments\kissme17\Archive_Profiling_FV00\Solander CTD//[KISSME2017]_[KISSME2017Deployment]_[BRD200]_[Solander CTD]_[]_[BRD200A_008]_[].nc
# Initialising accessor.
# STORING RAW FILE ATTRIBUTES
# Setting attribute "raw_file_name" to "BRD200A_009.cnv"
# Setting attribute "raw_file_directory" to "E:/Experiments/kissme17/ProfileData/CTD"
# {'title': '', 'institution': 'The University of Western Australia', 'institution_division': 'Ocean Dynamics', 'source': '', 'project': '', 'history': '', 'references': '', 'comment': '', 'Conventions': 'CF-1.7', 'trip': '', 'trip_deployed': '', 'site': '', 'site_station': '', 'instrument_make': '', 'instrument_model': '', 'instrument_serial_number': '', 'raw_file_name': 'BRD200A_009.cnv', 'raw_file_directory': 'E:/Experiments/kissme17/ProfileData/CTD', 'raw_file_attributes': '', 'last_export_file_name': '', 'last_export_directory': '', 'last_load_file_name': '', 'last_load_directory': '', 'outfile_append': '', 'disclaimer': '', 'nominal_latitude': '', 'nominal_longitude': '', 'nominal_site_depth': '', 'pressure_sensor_height_asb': '', 'nominal_instrument_height_asb': '', 'nominal_instrument_orientation': '', 'timezone': '', 'is_profile_data': 0}
# Setting attribute "title" to "Measured data from a profiling Seabird CTD"
# Setting attribute "source" to "Profiling CTD from A.I.M.S. R.V. Solander"
# Setting attribute "project" to "KISSME2017"
# Setting attribute "raw_file_name" to "BRD200A_009"
# Setting attribute "site_station" to "BRD200"
# Setting attribute "trip" to "KISSME2017Deployment"
# Setting attribute "is_profile_data" to "1"
# Setting attribute "timezone" to "UTC"
# Setting attribute "instrument_model" to "Solander CTD"
# Setting attribute "nominal_latitude" to ""
# Setting attribute "nominal_longitude" to ""
# Setting attribute "nominal_site_depth" to "291.0"
# E:\Experiments\kissme17\Archive_Profiling_FV00\Solander CTD
# Generating filename from naming convention.
# Best export dir is the raw_file_directory.
# Will to user input directory.
# Exporting E:\Experiments\kissme17\Archive_Profiling_FV00\Solander CTD//[KISSME2017]_[KISSME2017Deployment]_[BRD200]_[Solander CTD]_[]_[BRD200A_009]_[].nc
# (array([23357, 23458, 23530, 23601, 23689], dtype=int64),)
# Initialising accessor.
# STORING RAW FILE ATTRIBUTES
# Setting attribute "raw_file_name" to "SP250_001.cnv"
# Setting attribute "raw_file_directory" to "E:/Experiments/kissme17/ProfileData/CTD"
# {'title': '', 'institution': 'The University of Western Australia', 'institution_division': 'Ocean Dynamics', 'source': '', 'project': '', 'history': '', 'references': '', 'comment': '', 'Conventions': 'CF-1.7', 'trip': '', 'trip_deployed': '', 'site': '', 'site_station': '', 'instrument_make': '', 'instrument_model': '', 'instrument_serial_number': '', 'raw_file_name': 'SP250_001.cnv', 'raw_file_directory': 'E:/Experiments/kissme17/ProfileData/CTD', 'raw_file_attributes': '', 'last_export_file_name': '', 'last_export_directory': '', 'last_load_file_name': '', 'last_load_directory': '', 'outfile_append': '', 'disclaimer': '', 'nominal_latitude': '', 'nominal_longitude': '', 'nominal_site_depth': '', 'pressure_sensor_height_asb': '', 'nominal_instrument_height_asb': '', 'nominal_instrument_orientation': '', 'timezone': '', 'is_profile_data': 0}
# Setting attribute "title" to "Measured data from a profiling Seabird CTD"
# Setting attribute "source" to "Profiling CTD from A.I.M.S. R.V. Solander"
# Setting attribute "project" to "KISSME2017"
# Setting attribute "raw_file_name" to "SP250_001"
# Setting attribute "site_station" to "SP250"
# Setting attribute "trip" to "KISSME2017Deployment"
# Setting attribute "is_profile_data" to "1"
# Setting attribute "timezone" to "UTC"
# Setting attribute "instrument_model" to "Solander CTD"
# Setting attribute "nominal_latitude" to ""
# Setting attribute "nominal_longitude" to ""
# Setting attribute "nominal_site_depth" to "261.0"
# E:\Experiments\kissme17\Archive_Profiling_FV00\Solander CTD
# Generating filename from naming convention.
# Best export dir is the raw_file_directory.
# Will to user input directory.
# Exporting E:\Experiments\kissme17\Archive_Profiling_FV00\Solander CTD//[KISSME2017]_[KISSME2017Deployment]_[SP250]_[Solander CTD]_[]_[SP250_001]_[].nc
# (array([22275, 22339, 22384, 22432, 22491], dtype=int64),)
# Initialising accessor.
# STORING RAW FILE ATTRIBUTES
# Setting attribute "raw_file_name" to "SP250_002.cnv"
# Setting attribute "raw_file_directory" to "E:/Experiments/kissme17/ProfileData/CTD"
# {'title': '', 'institution': 'The University of Western Australia', 'institution_division': 'Ocean Dynamics', 'source': '', 'project': '', 'history': '', 'references': '', 'comment': '', 'Conventions': 'CF-1.7', 'trip': '', 'trip_deployed': '', 'site': '', 'site_station': '', 'instrument_make': '', 'instrument_model': '', 'instrument_serial_number': '', 'raw_file_name': 'SP250_002.cnv', 'raw_file_directory': 'E:/Experiments/kissme17/ProfileData/CTD', 'raw_file_attributes': '', 'last_export_file_name': '', 'last_export_directory': '', 'last_load_file_name': '', 'last_load_directory': '', 'outfile_append': '', 'disclaimer': '', 'nominal_latitude': '', 'nominal_longitude': '', 'nominal_site_depth': '', 'pressure_sensor_height_asb': '', 'nominal_instrument_height_asb': '', 'nominal_instrument_orientation': '', 'timezone': '', 'is_profile_data': 0}
# Setting attribute "title" to "Measured data from a profiling Seabird CTD"
# Setting attribute "source" to "Profiling CTD from A.I.M.S. R.V. Solander"
# Setting attribute "project" to "KISSME2017"
# Setting attribute "raw_file_name" to "SP250_002"
# Setting attribute "site_station" to "SP250"
# Setting attribute "trip" to "KISSME2017Deployment"
# Setting attribute "is_profile_data" to "1"
# Setting attribute "timezone" to "UTC"
# Setting attribute "instrument_model" to "Solander CTD"
# Setting attribute "nominal_latitude" to ""
# Setting attribute "nominal_longitude" to ""
# Setting attribute "nominal_site_depth" to "260.0"
# E:\Experiments\kissme17\Archive_Profiling_FV00\Solander CTD
# Generating filename from naming convention.
# Best export dir is the raw_file_directory.
# Will to user input directory.
# Exporting E:\Experiments\kissme17\Archive_Profiling_FV00\Solander CTD//[KISSME2017]_[KISSME2017Deployment]_[SP250]_[Solander CTD]_[]_[SP250_002]_[].nc
# (array([15215, 19234, 20458, 21526, 22930, 24127, 25794, 32738, 32803,
#        32869, 32939, 33120], dtype=int64),)
# Initialising accessor.
# STORING RAW FILE ATTRIBUTES
# Setting attribute "raw_file_name" to "WP250_001.cnv"
# Setting attribute "raw_file_directory" to "E:/Experiments/kissme17/ProfileData/CTD"
# {'title': '', 'institution': 'The University of Western Australia', 'institution_division': 'Ocean Dynamics', 'source': '', 'project': '', 'history': '', 'references': '', 'comment': '', 'Conventions': 'CF-1.7', 'trip': '', 'trip_deployed': '', 'site': '', 'site_station': '', 'instrument_make': '', 'instrument_model': '', 'instrument_serial_number': '', 'raw_file_name': 'WP250_001.cnv', 'raw_file_directory': 'E:/Experiments/kissme17/ProfileData/CTD', 'raw_file_attributes': '', 'last_export_file_name': '', 'last_export_directory': '', 'last_load_file_name': '', 'last_load_directory': '', 'outfile_append': '', 'disclaimer': '', 'nominal_latitude': '', 'nominal_longitude': '', 'nominal_site_depth': '', 'pressure_sensor_height_asb': '', 'nominal_instrument_height_asb': '', 'nominal_instrument_orientation': '', 'timezone': '', 'is_profile_data': 0}
# Setting attribute "title" to "Measured data from a profiling Seabird CTD"
# Setting attribute "source" to "Profiling CTD from A.I.M.S. R.V. Solander"
# Setting attribute "project" to "KISSME2017"
# Setting attribute "raw_file_name" to "WP250_001"
# Setting attribute "site_station" to "WP250"
# Setting attribute "trip" to "KISSME2017Deployment"
# Setting attribute "is_profile_data" to "1"
# Setting attribute "timezone" to "UTC"
# Setting attribute "instrument_model" to "Solander CTD"
# Setting attribute "nominal_latitude" to ""
# Setting attribute "nominal_longitude" to ""
# Setting attribute "nominal_site_depth" to "259.0"
# E:\Experiments\kissme17\Archive_Profiling_FV00\Solander CTD
# Generating filename from naming convention.
# Best export dir is the raw_file_directory.
# Will to user input directory.
# Exporting E:\Experiments\kissme17\Archive_Profiling_FV00\Solander CTD//[KISSME2017]_[KISSME2017Deployment]_[WP250]_[Solander CTD]_[]_[WP250_001]_[].nc
# Initialising accessor.
# STORING RAW FILE ATTRIBUTES
# Setting attribute "raw_file_name" to "NP250_001.cnv"
# Setting attribute "raw_file_directory" to "E:/Experiments/kissme17/ProfileData/CTD"
# {'title': '', 'institution': 'The University of Western Australia', 'institution_division': 'Ocean Dynamics', 'source': '', 'project': '', 'history': '', 'references': '', 'comment': '', 'Conventions': 'CF-1.7', 'trip': '', 'trip_deployed': '', 'site': '', 'site_station': '', 'instrument_make': '', 'instrument_model': '', 'instrument_serial_number': '', 'raw_file_name': 'NP250_001.cnv', 'raw_file_directory': 'E:/Experiments/kissme17/ProfileData/CTD', 'raw_file_attributes': '', 'last_export_file_name': '', 'last_export_directory': '', 'last_load_file_name': '', 'last_load_directory': '', 'outfile_append': '', 'disclaimer': '', 'nominal_latitude': '', 'nominal_longitude': '', 'nominal_site_depth': '', 'pressure_sensor_height_asb': '', 'nominal_instrument_height_asb': '', 'nominal_instrument_orientation': '', 'timezone': '', 'is_profile_data': 0}
# Setting attribute "title" to "Measured data from a profiling Seabird CTD"
# Setting attribute "source" to "Profiling CTD from A.I.M.S. R.V. Solander"
# Setting attribute "project" to "KISSME2017"
# Setting attribute "raw_file_name" to "NP250_001"
# Setting attribute "site_station" to "NP250"
# Setting attribute "trip" to "KISSME2017Deployment"
# Setting attribute "is_profile_data" to "1"
# Setting attribute "timezone" to "UTC"
# Setting attribute "instrument_model" to "Solander CTD"
# Setting attribute "nominal_latitude" to ""
# Setting attribute "nominal_longitude" to ""
# Setting attribute "nominal_site_depth" to "262.0"
# E:\Experiments\kissme17\Archive_Profiling_FV00\Solander CTD
# Generating filename from naming convention.
# Best export dir is the raw_file_directory.
# Will to user input directory.
# Exporting E:\Experiments\kissme17\Archive_Profiling_FV00\Solander CTD//[KISSME2017]_[KISSME2017Deployment]_[NP250]_[Solander CTD]_[]_[NP250_001]_[].nc
# (array([17432, 18497, 19394, 21566, 23415, 25015, 25807, 32372, 32473,
#        32546, 32608, 32649], dtype=int64),)
# Initialising accessor.
# STORING RAW FILE ATTRIBUTES
# Setting attribute "raw_file_name" to "NP250_002.cnv"
# Setting attribute "raw_file_directory" to "E:/Experiments/kissme17/ProfileData/CTD"
# {'title': '', 'institution': 'The University of Western Australia', 'institution_division': 'Ocean Dynamics', 'source': '', 'project': '', 'history': '', 'references': '', 'comment': '', 'Conventions': 'CF-1.7', 'trip': '', 'trip_deployed': '', 'site': '', 'site_station': '', 'instrument_make': '', 'instrument_model': '', 'instrument_serial_number': '', 'raw_file_name': 'NP250_002.cnv', 'raw_file_directory': 'E:/Experiments/kissme17/ProfileData/CTD', 'raw_file_attributes': '', 'last_export_file_name': '', 'last_export_directory': '', 'last_load_file_name': '', 'last_load_directory': '', 'outfile_append': '', 'disclaimer': '', 'nominal_latitude': '', 'nominal_longitude': '', 'nominal_site_depth': '', 'pressure_sensor_height_asb': '', 'nominal_instrument_height_asb': '', 'nominal_instrument_orientation': '', 'timezone': '', 'is_profile_data': 0}
# Setting attribute "title" to "Measured data from a profiling Seabird CTD"
# Setting attribute "source" to "Profiling CTD from A.I.M.S. R.V. Solander"
# Setting attribute "project" to "KISSME2017"
# Setting attribute "raw_file_name" to "NP250_002"
# Setting attribute "site_station" to "NP250"
# Setting attribute "trip" to "KISSME2017Deployment"
# Setting attribute "is_profile_data" to "1"
# Setting attribute "timezone" to "UTC"
# Setting attribute "instrument_model" to "Solander CTD"
# Setting attribute "nominal_latitude" to ""
# Setting attribute "nominal_longitude" to ""
# Setting attribute "nominal_site_depth" to "262.0"
# E:\Experiments\kissme17\Archive_Profiling_FV00\Solander CTD
# Generating filename from naming convention.
# Best export dir is the raw_file_directory.
# Will to user input directory.
# Exporting E:\Experiments\kissme17\Archive_Profiling_FV00\Solander CTD//[KISSME2017]_[KISSME2017Deployment]_[NP250]_[Solander CTD]_[]_[NP250_002]_[].nc
# Initialising accessor.
# STORING RAW FILE ATTRIBUTES
# Setting attribute "raw_file_name" to "SP250_12hr_001.cnv"
# Setting attribute "raw_file_directory" to "E:/Experiments/kissme17/ProfileData/CTD"
# {'title': '', 'institution': 'The University of Western Australia', 'institution_division': 'Ocean Dynamics', 'source': '', 'project': '', 'history': '', 'references': '', 'comment': '', 'Conventions': 'CF-1.7', 'trip': '', 'trip_deployed': '', 'site': '', 'site_station': '', 'instrument_make': '', 'instrument_model': '', 'instrument_serial_number': '', 'raw_file_name': 'SP250_12hr_001.cnv', 'raw_file_directory': 'E:/Experiments/kissme17/ProfileData/CTD', 'raw_file_attributes': '', 'last_export_file_name': '', 'last_export_directory': '', 'last_load_file_name': '', 'last_load_directory': '', 'outfile_append': '', 'disclaimer': '', 'nominal_latitude': '', 'nominal_longitude': '', 'nominal_site_depth': '', 'pressure_sensor_height_asb': '', 'nominal_instrument_height_asb': '', 'nominal_instrument_orientation': '', 'timezone': '', 'is_profile_data': 0}
# Setting attribute "title" to "Measured data from a profiling Seabird CTD"
# Setting attribute "source" to "Profiling CTD from A.I.M.S. R.V. Solander"
# Setting attribute "project" to "KISSME2017"
# Setting attribute "raw_file_name" to "SP250_12hr_001"
# Setting attribute "site_station" to "SP250_12hr"
# Setting attribute "trip" to "KISSME2017Deployment"
# Setting attribute "is_profile_data" to "1"
# Setting attribute "timezone" to "UTC"
# Setting attribute "instrument_model" to "Solander CTD"
# Setting attribute "nominal_latitude" to ""
# Setting attribute "nominal_longitude" to ""
# Setting attribute "nominal_site_depth" to "260.0"
# E:\Experiments\kissme17\Archive_Profiling_FV00\Solander CTD
# Generating filename from naming convention.
# Best export dir is the raw_file_directory.
# Will to user input directory.
# Exporting E:\Experiments\kissme17\Archive_Profiling_FV00\Solander CTD//[KISSME2017]_[KISSME2017Deployment]_[SP250_12hr]_[Solander CTD]_[]_[SP250_12hr_001]_[].nc
# Initialising accessor.
# STORING RAW FILE ATTRIBUTES
# Setting attribute "raw_file_name" to "SP250_12hr_002.cnv"
# Setting attribute "raw_file_directory" to "E:/Experiments/kissme17/ProfileData/CTD"
# {'title': '', 'institution': 'The University of Western Australia', 'institution_division': 'Ocean Dynamics', 'source': '', 'project': '', 'history': '', 'references': '', 'comment': '', 'Conventions': 'CF-1.7', 'trip': '', 'trip_deployed': '', 'site': '', 'site_station': '', 'instrument_make': '', 'instrument_model': '', 'instrument_serial_number': '', 'raw_file_name': 'SP250_12hr_002.cnv', 'raw_file_directory': 'E:/Experiments/kissme17/ProfileData/CTD', 'raw_file_attributes': '', 'last_export_file_name': '', 'last_export_directory': '', 'last_load_file_name': '', 'last_load_directory': '', 'outfile_append': '', 'disclaimer': '', 'nominal_latitude': '', 'nominal_longitude': '', 'nominal_site_depth': '', 'pressure_sensor_height_asb': '', 'nominal_instrument_height_asb': '', 'nominal_instrument_orientation': '', 'timezone': '', 'is_profile_data': 0}
# Setting attribute "title" to "Measured data from a profiling Seabird CTD"
# Setting attribute "source" to "Profiling CTD from A.I.M.S. R.V. Solander"
# Setting attribute "project" to "KISSME2017"
# Setting attribute "raw_file_name" to "SP250_12hr_002"
# Setting attribute "site_station" to "SP250_12hr"
# Setting attribute "trip" to "KISSME2017Deployment"
# Setting attribute "is_profile_data" to "1"
# Setting attribute "timezone" to "UTC"
# Setting attribute "instrument_model" to "Solander CTD"
# Setting attribute "nominal_latitude" to ""
# Setting attribute "nominal_longitude" to ""
# Setting attribute "nominal_site_depth" to "261.0"
# E:\Experiments\kissme17\Archive_Profiling_FV00\Solander CTD
# Generating filename from naming convention.
# Best export dir is the raw_file_directory.
# Will to user input directory.
# Exporting E:\Experiments\kissme17\Archive_Profiling_FV00\Solander CTD//[KISSME2017]_[KISSME2017Deployment]_[SP250_12hr]_[Solander CTD]_[]_[SP250_12hr_002]_[].nc
# (array([15186, 16531, 17450, 18325, 19185], dtype=int64),)
# Initialising accessor.
# STORING RAW FILE ATTRIBUTES
# Setting attribute "raw_file_name" to "SP250_12hr_003.cnv"
# Setting attribute "raw_file_directory" to "E:/Experiments/kissme17/ProfileData/CTD"
# {'title': '', 'institution': 'The University of Western Australia', 'institution_division': 'Ocean Dynamics', 'source': '', 'project': '', 'history': '', 'references': '', 'comment': '', 'Conventions': 'CF-1.7', 'trip': '', 'trip_deployed': '', 'site': '', 'site_station': '', 'instrument_make': '', 'instrument_model': '', 'instrument_serial_number': '', 'raw_file_name': 'SP250_12hr_003.cnv', 'raw_file_directory': 'E:/Experiments/kissme17/ProfileData/CTD', 'raw_file_attributes': '', 'last_export_file_name': '', 'last_export_directory': '', 'last_load_file_name': '', 'last_load_directory': '', 'outfile_append': '', 'disclaimer': '', 'nominal_latitude': '', 'nominal_longitude': '', 'nominal_site_depth': '', 'pressure_sensor_height_asb': '', 'nominal_instrument_height_asb': '', 'nominal_instrument_orientation': '', 'timezone': '', 'is_profile_data': 0}
# Setting attribute "title" to "Measured data from a profiling Seabird CTD"
# Setting attribute "source" to "Profiling CTD from A.I.M.S. R.V. Solander"
# Setting attribute "project" to "KISSME2017"
# Setting attribute "raw_file_name" to "SP250_12hr_003"
# Setting attribute "site_station" to "SP250_12hr"
# Setting attribute "trip" to "KISSME2017Deployment"
# Setting attribute "is_profile_data" to "1"
# Setting attribute "timezone" to "UTC"
# Setting attribute "instrument_model" to "Solander CTD"
# Setting attribute "nominal_latitude" to ""
# Setting attribute "nominal_longitude" to ""
# Setting attribute "nominal_site_depth" to "258.0"
# E:\Experiments\kissme17\Archive_Profiling_FV00\Solander CTD
# Generating filename from naming convention.
# Best export dir is the raw_file_directory.
# Will to user input directory.
# Exporting E:\Experiments\kissme17\Archive_Profiling_FV00\Solander CTD//[KISSME2017]_[KISSME2017Deployment]_[SP250_12hr]_[Solander CTD]_[]_[SP250_12hr_003]_[].nc
# Initialising accessor.
# STORING RAW FILE ATTRIBUTES
# Setting attribute "raw_file_name" to "SP250_12hr_004.cnv"
# Setting attribute "raw_file_directory" to "E:/Experiments/kissme17/ProfileData/CTD"
# {'title': '', 'institution': 'The University of Western Australia', 'institution_division': 'Ocean Dynamics', 'source': '', 'project': '', 'history': '', 'references': '', 'comment': '', 'Conventions': 'CF-1.7', 'trip': '', 'trip_deployed': '', 'site': '', 'site_station': '', 'instrument_make': '', 'instrument_model': '', 'instrument_serial_number': '', 'raw_file_name': 'SP250_12hr_004.cnv', 'raw_file_directory': 'E:/Experiments/kissme17/ProfileData/CTD', 'raw_file_attributes': '', 'last_export_file_name': '', 'last_export_directory': '', 'last_load_file_name': '', 'last_load_directory': '', 'outfile_append': '', 'disclaimer': '', 'nominal_latitude': '', 'nominal_longitude': '', 'nominal_site_depth': '', 'pressure_sensor_height_asb': '', 'nominal_instrument_height_asb': '', 'nominal_instrument_orientation': '', 'timezone': '', 'is_profile_data': 0}
# Setting attribute "title" to "Measured data from a profiling Seabird CTD"
# Setting attribute "source" to "Profiling CTD from A.I.M.S. R.V. Solander"
# Setting attribute "project" to "KISSME2017"
# Setting attribute "raw_file_name" to "SP250_12hr_004"
# Setting attribute "site_station" to "SP250_12hr"
# Setting attribute "trip" to "KISSME2017Deployment"
# Setting attribute "is_profile_data" to "1"
# Setting attribute "timezone" to "UTC"
# Setting attribute "instrument_model" to "Solander CTD"
# Setting attribute "nominal_latitude" to ""
# Setting attribute "nominal_longitude" to ""
# Setting attribute "nominal_site_depth" to "258.0"
# E:\Experiments\kissme17\Archive_Profiling_FV00\Solander CTD
# Generating filename from naming convention.
# Best export dir is the raw_file_directory.
# Will to user input directory.
# Exporting E:\Experiments\kissme17\Archive_Profiling_FV00\Solander CTD//[KISSME2017]_[KISSME2017Deployment]_[SP250_12hr]_[Solander CTD]_[]_[SP250_12hr_004]_[].nc
# Initialising accessor.
# STORING RAW FILE ATTRIBUTES
# Setting attribute "raw_file_name" to "SP250_12hr_005.cnv"
# Setting attribute "raw_file_directory" to "E:/Experiments/kissme17/ProfileData/CTD"
# {'title': '', 'institution': 'The University of Western Australia', 'institution_division': 'Ocean Dynamics', 'source': '', 'project': '', 'history': '', 'references': '', 'comment': '', 'Conventions': 'CF-1.7', 'trip': '', 'trip_deployed': '', 'site': '', 'site_station': '', 'instrument_make': '', 'instrument_model': '', 'instrument_serial_number': '', 'raw_file_name': 'SP250_12hr_005.cnv', 'raw_file_directory': 'E:/Experiments/kissme17/ProfileData/CTD', 'raw_file_attributes': '', 'last_export_file_name': '', 'last_export_directory': '', 'last_load_file_name': '', 'last_load_directory': '', 'outfile_append': '', 'disclaimer': '', 'nominal_latitude': '', 'nominal_longitude': '', 'nominal_site_depth': '', 'pressure_sensor_height_asb': '', 'nominal_instrument_height_asb': '', 'nominal_instrument_orientation': '', 'timezone': '', 'is_profile_data': 0}
# Setting attribute "title" to "Measured data from a profiling Seabird CTD"
# Setting attribute "source" to "Profiling CTD from A.I.M.S. R.V. Solander"
# Setting attribute "project" to "KISSME2017"
# Setting attribute "raw_file_name" to "SP250_12hr_005"
# Setting attribute "site_station" to "SP250_12hr"
# Setting attribute "trip" to "KISSME2017Deployment"
# Setting attribute "is_profile_data" to "1"
# Setting attribute "timezone" to "UTC"
# Setting attribute "instrument_model" to "Solander CTD"
# Setting attribute "nominal_latitude" to ""
# Setting attribute "nominal_longitude" to ""
# Setting attribute "nominal_site_depth" to "257.0"
# E:\Experiments\kissme17\Archive_Profiling_FV00\Solander CTD
# Generating filename from naming convention.
# Best export dir is the raw_file_directory.
# Will to user input directory.
# Exporting E:\Experiments\kissme17\Archive_Profiling_FV00\Solander CTD//[KISSME2017]_[KISSME2017Deployment]_[SP250_12hr]_[Solander CTD]_[]_[SP250_12hr_005]_[].nc
# (array([18049, 18097, 18140, 18193, 18241], dtype=int64),)
# Initialising accessor.
# STORING RAW FILE ATTRIBUTES
# Setting attribute "raw_file_name" to "SP250_12hr_006.cnv"
# Setting attribute "raw_file_directory" to "E:/Experiments/kissme17/ProfileData/CTD"
# {'title': '', 'institution': 'The University of Western Australia', 'institution_division': 'Ocean Dynamics', 'source': '', 'project': '', 'history': '', 'references': '', 'comment': '', 'Conventions': 'CF-1.7', 'trip': '', 'trip_deployed': '', 'site': '', 'site_station': '', 'instrument_make': '', 'instrument_model': '', 'instrument_serial_number': '', 'raw_file_name': 'SP250_12hr_006.cnv', 'raw_file_directory': 'E:/Experiments/kissme17/ProfileData/CTD', 'raw_file_attributes': '', 'last_export_file_name': '', 'last_export_directory': '', 'last_load_file_name': '', 'last_load_directory': '', 'outfile_append': '', 'disclaimer': '', 'nominal_latitude': '', 'nominal_longitude': '', 'nominal_site_depth': '', 'pressure_sensor_height_asb': '', 'nominal_instrument_height_asb': '', 'nominal_instrument_orientation': '', 'timezone': '', 'is_profile_data': 0}
# Setting attribute "title" to "Measured data from a profiling Seabird CTD"
# Setting attribute "source" to "Profiling CTD from A.I.M.S. R.V. Solander"
# Setting attribute "project" to "KISSME2017"
# Setting attribute "raw_file_name" to "SP250_12hr_006"
# Setting attribute "site_station" to "SP250_12hr"
# Setting attribute "trip" to "KISSME2017Deployment"
# Setting attribute "is_profile_data" to "1"
# Setting attribute "timezone" to "UTC"
# Setting attribute "instrument_model" to "Solander CTD"
# Setting attribute "nominal_latitude" to ""
# Setting attribute "nominal_longitude" to ""
# Setting attribute "nominal_site_depth" to "256.0"
# E:\Experiments\kissme17\Archive_Profiling_FV00\Solander CTD
# Generating filename from naming convention.
# Best export dir is the raw_file_directory.
# Will to user input directory.
# Exporting E:\Experiments\kissme17\Archive_Profiling_FV00\Solander CTD//[KISSME2017]_[KISSME2017Deployment]_[SP250_12hr]_[Solander CTD]_[]_[SP250_12hr_006]_[].nc
# Initialising accessor.
# STORING RAW FILE ATTRIBUTES
# Setting attribute "raw_file_name" to "SP250_12hr_007.cnv"
# Setting attribute "raw_file_directory" to "E:/Experiments/kissme17/ProfileData/CTD"
# {'title': '', 'institution': 'The University of Western Australia', 'institution_division': 'Ocean Dynamics', 'source': '', 'project': '', 'history': '', 'references': '', 'comment': '', 'Conventions': 'CF-1.7', 'trip': '', 'trip_deployed': '', 'site': '', 'site_station': '', 'instrument_make': '', 'instrument_model': '', 'instrument_serial_number': '', 'raw_file_name': 'SP250_12hr_007.cnv', 'raw_file_directory': 'E:/Experiments/kissme17/ProfileData/CTD', 'raw_file_attributes': '', 'last_export_file_name': '', 'last_export_directory': '', 'last_load_file_name': '', 'last_load_directory': '', 'outfile_append': '', 'disclaimer': '', 'nominal_latitude': '', 'nominal_longitude': '', 'nominal_site_depth': '', 'pressure_sensor_height_asb': '', 'nominal_instrument_height_asb': '', 'nominal_instrument_orientation': '', 'timezone': '', 'is_profile_data': 0}
# Setting attribute "title" to "Measured data from a profiling Seabird CTD"
# Setting attribute "source" to "Profiling CTD from A.I.M.S. R.V. Solander"
# Setting attribute "project" to "KISSME2017"
# Setting attribute "raw_file_name" to "SP250_12hr_007"
# Setting attribute "site_station" to "SP250_12hr"
# Setting attribute "trip" to "KISSME2017Deployment"
# Setting attribute "is_profile_data" to "1"
# Setting attribute "timezone" to "UTC"
# Setting attribute "instrument_model" to "Solander CTD"
# Setting attribute "nominal_latitude" to ""
# Setting attribute "nominal_longitude" to ""
# Setting attribute "nominal_site_depth" to "259.0"
# E:\Experiments\kissme17\Archive_Profiling_FV00\Solander CTD
# Generating filename from naming convention.
# Best export dir is the raw_file_directory.
# Will to user input directory.
# Exporting E:\Experiments\kissme17\Archive_Profiling_FV00\Solander CTD//[KISSME2017]_[KISSME2017Deployment]_[SP250_12hr]_[Solander CTD]_[]_[SP250_12hr_007]_[].nc
# Initialising accessor.
# STORING RAW FILE ATTRIBUTES
# Setting attribute "raw_file_name" to "SP250_12hr_008.cnv"
# Setting attribute "raw_file_directory" to "E:/Experiments/kissme17/ProfileData/CTD"
# {'title': '', 'institution': 'The University of Western Australia', 'institution_division': 'Ocean Dynamics', 'source': '', 'project': '', 'history': '', 'references': '', 'comment': '', 'Conventions': 'CF-1.7', 'trip': '', 'trip_deployed': '', 'site': '', 'site_station': '', 'instrument_make': '', 'instrument_model': '', 'instrument_serial_number': '', 'raw_file_name': 'SP250_12hr_008.cnv', 'raw_file_directory': 'E:/Experiments/kissme17/ProfileData/CTD', 'raw_file_attributes': '', 'last_export_file_name': '', 'last_export_directory': '', 'last_load_file_name': '', 'last_load_directory': '', 'outfile_append': '', 'disclaimer': '', 'nominal_latitude': '', 'nominal_longitude': '', 'nominal_site_depth': '', 'pressure_sensor_height_asb': '', 'nominal_instrument_height_asb': '', 'nominal_instrument_orientation': '', 'timezone': '', 'is_profile_data': 0}
# Setting attribute "title" to "Measured data from a profiling Seabird CTD"
# Setting attribute "source" to "Profiling CTD from A.I.M.S. R.V. Solander"
# Setting attribute "project" to "KISSME2017"
# Setting attribute "raw_file_name" to "SP250_12hr_008"
# Setting attribute "site_station" to "SP250_12hr"
# Setting attribute "trip" to "KISSME2017Deployment"
# Setting attribute "is_profile_data" to "1"
# Setting attribute "timezone" to "UTC"
# Setting attribute "instrument_model" to "Solander CTD"
# Setting attribute "nominal_latitude" to ""
# Setting attribute "nominal_longitude" to ""
# Setting attribute "nominal_site_depth" to "259.0"
# E:\Experiments\kissme17\Archive_Profiling_FV00\Solander CTD
# Generating filename from naming convention.
# Best export dir is the raw_file_directory.
# Will to user input directory.
# Exporting E:\Experiments\kissme17\Archive_Profiling_FV00\Solander CTD//[KISSME2017]_[KISSME2017Deployment]_[SP250_12hr]_[Solander CTD]_[]_[SP250_12hr_008]_[].nc
# (array([18590, 19587, 20499, 21436, 21474, 22291, 22331], dtype=int64),)
# Initialising accessor.
# STORING RAW FILE ATTRIBUTES
# Setting attribute "raw_file_name" to "SP250_12hr_009.cnv"
# Setting attribute "raw_file_directory" to "E:/Experiments/kissme17/ProfileData/CTD"
# {'title': '', 'institution': 'The University of Western Australia', 'institution_division': 'Ocean Dynamics', 'source': '', 'project': '', 'history': '', 'references': '', 'comment': '', 'Conventions': 'CF-1.7', 'trip': '', 'trip_deployed': '', 'site': '', 'site_station': '', 'instrument_make': '', 'instrument_model': '', 'instrument_serial_number': '', 'raw_file_name': 'SP250_12hr_009.cnv', 'raw_file_directory': 'E:/Experiments/kissme17/ProfileData/CTD', 'raw_file_attributes': '', 'last_export_file_name': '', 'last_export_directory': '', 'last_load_file_name': '', 'last_load_directory': '', 'outfile_append': '', 'disclaimer': '', 'nominal_latitude': '', 'nominal_longitude': '', 'nominal_site_depth': '', 'pressure_sensor_height_asb': '', 'nominal_instrument_height_asb': '', 'nominal_instrument_orientation': '', 'timezone': '', 'is_profile_data': 0}
# Setting attribute "title" to "Measured data from a profiling Seabird CTD"
# Setting attribute "source" to "Profiling CTD from A.I.M.S. R.V. Solander"
# Setting attribute "project" to "KISSME2017"
# Setting attribute "raw_file_name" to "SP250_12hr_009"
# Setting attribute "site_station" to "SP250_12hr"
# Setting attribute "trip" to "KISSME2017Deployment"
# Setting attribute "is_profile_data" to "1"
# Setting attribute "timezone" to "UTC"
# Setting attribute "instrument_model" to "Solander CTD"
# ...
# E:\Experiments\kissme17\Archive_Profiling_FV00\Solander CTD
# Generating filename from naming convention.
# Best export dir is the raw_file_directory.
# Will to user input directory.
# Exporting E:\Experiments\kissme17\Archive_Profiling_FV00\Solander CTD//[KISSME2017]_[KISSME2017Deployment]_[UWAB]_[Solander CTD]_[]_[UWAB-009]_[].nc
# Initialising accessor.
# STORING RAW FILE ATTRIBUTES
# Setting attribute "raw_file_name" to "UWAB-010.cnv"
# Setting attribute "raw_file_directory" to "E:/Experiments/kissme17/ProfileData/CTD"
# {'title': '', 'institution': 'The University of Western Australia', 'institution_division': 'Ocean Dynamics', 'source': '', 'project': '', 'history': '', 'references': '', 'comment': '', 'Conventions': 'CF-1.7', 'trip': '', 'trip_deployed': '', 'site': '', 'site_station': '', 'instrument_make': '', 'instrument_model': '', 'instrument_serial_number': '', 'raw_file_name': 'UWAB-010.cnv', 'raw_file_directory': 'E:/Experiments/kissme17/ProfileData/CTD', 'raw_file_attributes': '', 'last_export_file_name': '', 'last_export_directory': '', 'last_load_file_name': '', 'last_load_directory': '', 'outfile_append': '', 'disclaimer': '', 'nominal_latitude': '', 'nominal_longitude': '', 'nominal_site_depth': '', 'pressure_sensor_height_asb': '', 'nominal_instrument_height_asb': '', 'nominal_instrument_orientation': '', 'timezone': '', 'is_profile_data': 0}
# Setting attribute "title" to "Measured data from a profiling Seabird CTD"
# Setting attribute "source" to "Profiling CTD from A.I.M.S. R.V. Solander"
# Setting attribute "project" to "KISSME2017"
# Setting attribute "raw_file_name" to "UWAB-010"
# Setting attribute "site_station" to "UWAB"
# Setting attribute "trip" to "KISSME2017Deployment"
# Setting attribute "is_profile_data" to "1"
# Setting attribute "timezone" to "UTC"
# Setting attribute "instrument_model" to "Solander CTD"
# Setting attribute "nominal_latitude" to ""
# Setting attribute "nominal_longitude" to ""
# Setting attribute "nominal_site_depth" to "259.0"
# E:\Experiments\kissme17\Archive_Profiling_FV00\Solander CTD
# Generating filename from naming convention.
# Best export dir is the raw_file_directory.
# Will to user input directory.
# Exporting E:\Experiments\kissme17\Archive_Profiling_FV00\Solander CTD//[KISSME2017]_[KISSME2017Deployment]_[UWAB]_[Solander CTD]_[]_[UWAB-010]_[].nc
# Initialising accessor.
# STORING RAW FILE ATTRIBUTES
# Setting attribute "raw_file_name" to "UWAB-011.cnv"
# Setting attribute "raw_file_directory" to "E:/Experiments/kissme17/ProfileData/CTD"
# {'title': '', 'institution': 'The University of Western Australia', 'institution_division': 'Ocean Dynamics', 'source': '', 'project': '', 'history': '', 'references': '', 'comment': '', 'Conventions': 'CF-1.7', 'trip': '', 'trip_deployed': '', 'site': '', 'site_station': '', 'instrument_make': '', 'instrument_model': '', 'instrument_serial_number': '', 'raw_file_name': 'UWAB-011.cnv', 'raw_file_directory': 'E:/Experiments/kissme17/ProfileData/CTD', 'raw_file_attributes': '', 'last_export_file_name': '', 'last_export_directory': '', 'last_load_file_name': '', 'last_load_directory': '', 'outfile_append': '', 'disclaimer': '', 'nominal_latitude': '', 'nominal_longitude': '', 'nominal_site_depth': '', 'pressure_sensor_height_asb': '', 'nominal_instrument_height_asb': '', 'nominal_instrument_orientation': '', 'timezone': '', 'is_profile_data': 0}
# Setting attribute "title" to "Measured data from a profiling Seabird CTD"
# Setting attribute "source" to "Profiling CTD from A.I.M.S. R.V. Solander"
# Setting attribute "project" to "KISSME2017"
# Setting attribute "raw_file_name" to "UWAB-011"
# Setting attribute "site_station" to "UWAB"
# Setting attribute "trip" to "KISSME2017Deployment"
# Setting attribute "is_profile_data" to "1"
# Setting attribute "timezone" to "UTC"
# Setting attribute "instrument_model" to "Solander CTD"
# Setting attribute "nominal_latitude" to ""
# Setting attribute "nominal_longitude" to ""
# Setting attribute "nominal_site_depth" to "259.0"
# E:\Experiments\kissme17\Archive_Profiling_FV00\Solander CTD
# Generating filename from naming convention.
# Best export dir is the raw_file_directory.
# Will to user input directory.
# Exporting E:\Experiments\kissme17\Archive_Profiling_FV00\Solander CTD//[KISSME2017]_[KISSME2017Deployment]_[UWAB]_[Solander CTD]_[]_[UWAB-011]_[].nc
# (array([11069, 13387, 14656, 17806, 19496, 21383], dtype=int64),)
# Initialising accessor.
# STORING RAW FILE ATTRIBUTES
# Setting attribute "raw_file_name" to "UWAB-012.cnv"
# Setting attribute "raw_file_directory" to "E:/Experiments/kissme17/ProfileData/CTD"
# {'title': '', 'institution': 'The University of Western Australia', 'institution_division': 'Ocean Dynamics', 'source': '', 'project': '', 'history': '', 'references': '', 'comment': '', 'Conventions': 'CF-1.7', 'trip': '', 'trip_deployed': '', 'site': '', 'site_station': '', 'instrument_make': '', 'instrument_model': '', 'instrument_serial_number': '', 'raw_file_name': 'UWAB-012.cnv', 'raw_file_directory': 'E:/Experiments/kissme17/ProfileData/CTD', 'raw_file_attributes': '', 'last_export_file_name': '', 'last_export_directory': '', 'last_load_file_name': '', 'last_load_directory': '', 'outfile_append': '', 'disclaimer': '', 'nominal_latitude': '', 'nominal_longitude': '', 'nominal_site_depth': '', 'pressure_sensor_height_asb': '', 'nominal_instrument_height_asb': '', 'nominal_instrument_orientation': '', 'timezone': '', 'is_profile_data': 0}
# Setting attribute "title" to "Measured data from a profiling Seabird CTD"
# Setting attribute "source" to "Profiling CTD from A.I.M.S. R.V. Solander"
# Setting attribute "project" to "KISSME2017"
# Setting attribute "raw_file_name" to "UWAB-012"
# Setting attribute "site_station" to "UWAB"
# Setting attribute "trip" to "KISSME2017Deployment"
# Setting attribute "is_profile_data" to "1"
# Setting attribute "timezone" to "UTC"
# Setting attribute "instrument_model" to "Solander CTD"
# Setting attribute "nominal_latitude" to ""
# Setting attribute "nominal_longitude" to ""
# Setting attribute "nominal_site_depth" to "260.0"
# E:\Experiments\kissme17\Archive_Profiling_FV00\Solander CTD
# Generating filename from naming convention.
# Best export dir is the raw_file_directory.
# Will to user input directory.
# Exporting E:\Experiments\kissme17\Archive_Profiling_FV00\Solander CTD//[KISSME2017]_[KISSME2017Deployment]_[UWAB]_[Solander CTD]_[]_[UWAB-012]_[].nc
# Initialising accessor.
# STORING RAW FILE ATTRIBUTES
# Setting attribute "raw_file_name" to "UWAB-013.cnv"
# Setting attribute "raw_file_directory" to "E:/Experiments/kissme17/ProfileData/CTD"
# {'title': '', 'institution': 'The University of Western Australia', 'institution_division': 'Ocean Dynamics', 'source': '', 'project': '', 'history': '', 'references': '', 'comment': '', 'Conventions': 'CF-1.7', 'trip': '', 'trip_deployed': '', 'site': '', 'site_station': '', 'instrument_make': '', 'instrument_model': '', 'instrument_serial_number': '', 'raw_file_name': 'UWAB-013.cnv', 'raw_file_directory': 'E:/Experiments/kissme17/ProfileData/CTD', 'raw_file_attributes': '', 'last_export_file_name': '', 'last_export_directory': '', 'last_load_file_name': '', 'last_load_directory': '', 'outfile_append': '', 'disclaimer': '', 'nominal_latitude': '', 'nominal_longitude': '', 'nominal_site_depth': '', 'pressure_sensor_height_asb': '', 'nominal_instrument_height_asb': '', 'nominal_instrument_orientation': '', 'timezone': '', 'is_profile_data': 0}
# Setting attribute "title" to "Measured data from a profiling Seabird CTD"
# Setting attribute "source" to "Profiling CTD from A.I.M.S. R.V. Solander"
# Setting attribute "project" to "KISSME2017"
# Setting attribute "raw_file_name" to "UWAB-013"
# Setting attribute "site_station" to "UWAB"
# Setting attribute "trip" to "KISSME2017Deployment"
# Setting attribute "is_profile_data" to "1"
# Setting attribute "timezone" to "UTC"
# Setting attribute "instrument_model" to "Solander CTD"
# Setting attribute "nominal_latitude" to ""
# Setting attribute "nominal_longitude" to ""
# Setting attribute "nominal_site_depth" to "261.0"
# E:\Experiments\kissme17\Archive_Profiling_FV00\Solander CTD
# Generating filename from naming convention.
# Best export dir is the raw_file_directory.
# Will to user input directory.
# Exporting E:\Experiments\kissme17\Archive_Profiling_FV00\Solander CTD//[KISSME2017]_[KISSME2017Deployment]_[UWAB]_[Solander CTD]_[]_[UWAB-013]_[].nc
# Initialising accessor.
# STORING RAW FILE ATTRIBUTES
# Setting attribute "raw_file_name" to "UWAB-014.cnv"
# Setting attribute "raw_file_directory" to "E:/Experiments/kissme17/ProfileData/CTD"
# {'title': '', 'institution': 'The University of Western Australia', 'institution_division': 'Ocean Dynamics', 'source': '', 'project': '', 'history': '', 'references': '', 'comment': '', 'Conventions': 'CF-1.7', 'trip': '', 'trip_deployed': '', 'site': '', 'site_station': '', 'instrument_make': '', 'instrument_model': '', 'instrument_serial_number': '', 'raw_file_name': 'UWAB-014.cnv', 'raw_file_directory': 'E:/Experiments/kissme17/ProfileData/CTD', 'raw_file_attributes': '', 'last_export_file_name': '', 'last_export_directory': '', 'last_load_file_name': '', 'last_load_directory': '', 'outfile_append': '', 'disclaimer': '', 'nominal_latitude': '', 'nominal_longitude': '', 'nominal_site_depth': '', 'pressure_sensor_height_asb': '', 'nominal_instrument_height_asb': '', 'nominal_instrument_orientation': '', 'timezone': '', 'is_profile_data': 0}
# Setting attribute "title" to "Measured data from a profiling Seabird CTD"
# Setting attribute "source" to "Profiling CTD from A.I.M.S. R.V. Solander"
# Setting attribute "project" to "KISSME2017"
# Setting attribute "raw_file_name" to "UWAB-014"
# Setting attribute "site_station" to "UWAB"
# Setting attribute "trip" to "KISSME2017Deployment"
# Setting attribute "is_profile_data" to "1"
# Setting attribute "timezone" to "UTC"
# Setting attribute "instrument_model" to "Solander CTD"
# Setting attribute "nominal_latitude" to ""
# Setting attribute "nominal_longitude" to ""
# Setting attribute "nominal_site_depth" to "260.0"
# E:\Experiments\kissme17\Archive_Profiling_FV00\Solander CTD
# Generating filename from naming convention.
# Best export dir is the raw_file_directory.
# Will to user input directory.
# Exporting E:\Experiments\kissme17\Archive_Profiling_FV00\Solander CTD//[KISSME2017]_[KISSME2017Deployment]_[UWAB]_[Solander CTD]_[]_[UWAB-014]_[].nc
# Initialising accessor.
# STORING RAW FILE ATTRIBUTES
# Setting attribute "raw_file_name" to "UWAB-015.cnv"
# Setting attribute "raw_file_directory" to "E:/Experiments/kissme17/ProfileData/CTD"
# {'title': '', 'institution': 'The University of Western Australia', 'institution_division': 'Ocean Dynamics', 'source': '', 'project': '', 'history': '', 'references': '', 'comment': '', 'Conventions': 'CF-1.7', 'trip': '', 'trip_deployed': '', 'site': '', 'site_station': '', 'instrument_make': '', 'instrument_model': '', 'instrument_serial_number': '', 'raw_file_name': 'UWAB-015.cnv', 'raw_file_directory': 'E:/Experiments/kissme17/ProfileData/CTD', 'raw_file_attributes': '', 'last_export_file_name': '', 'last_export_directory': '', 'last_load_file_name': '', 'last_load_directory': '', 'outfile_append': '', 'disclaimer': '', 'nominal_latitude': '', 'nominal_longitude': '', 'nominal_site_depth': '', 'pressure_sensor_height_asb': '', 'nominal_instrument_height_asb': '', 'nominal_instrument_orientation': '', 'timezone': '', 'is_profile_data': 0}
# Setting attribute "title" to "Measured data from a profiling Seabird CTD"
# Setting attribute "source" to "Profiling CTD from A.I.M.S. R.V. Solander"
# Setting attribute "project" to "KISSME2017"
# Setting attribute "raw_file_name" to "UWAB-015"
# Setting attribute "site_station" to "UWAB"
# Setting attribute "trip" to "KISSME2017Deployment"
# Setting attribute "is_profile_data" to "1"
# Setting attribute "timezone" to "UTC"
# Setting attribute "instrument_model" to "Solander CTD"
# Setting attribute "nominal_latitude" to ""
# Setting attribute "nominal_longitude" to ""
# Setting attribute "nominal_site_depth" to "259.0"
# E:\Experiments\kissme17\Archive_Profiling_FV00\Solander CTD
# Generating filename from naming convention.
# Best export dir is the raw_file_directory.
# Will to user input directory.
# Exporting E:\Experiments\kissme17\Archive_Profiling_FV00\Solander CTD//[KISSME2017]_[KISSME2017Deployment]_[UWAB]_[Solander CTD]_[]_[UWAB-015]_[].nc
# Initialising accessor.
# STORING RAW FILE ATTRIBUTES
# Setting attribute "raw_file_name" to "UWAB-016.cnv"
# Setting attribute "raw_file_directory" to "E:/Experiments/kissme17/ProfileData/CTD"
# {'title': '', 'institution': 'The University of Western Australia', 'institution_division': 'Ocean Dynamics', 'source': '', 'project': '', 'history': '', 'references': '', 'comment': '', 'Conventions': 'CF-1.7', 'trip': '', 'trip_deployed': '', 'site': '', 'site_station': '', 'instrument_make': '', 'instrument_model': '', 'instrument_serial_number': '', 'raw_file_name': 'UWAB-016.cnv', 'raw_file_directory': 'E:/Experiments/kissme17/ProfileData/CTD', 'raw_file_attributes': '', 'last_export_file_name': '', 'last_export_directory': '', 'last_load_file_name': '', 'last_load_directory': '', 'outfile_append': '', 'disclaimer': '', 'nominal_latitude': '', 'nominal_longitude': '', 'nominal_site_depth': '', 'pressure_sensor_height_asb': '', 'nominal_instrument_height_asb': '', 'nominal_instrument_orientation': '', 'timezone': '', 'is_profile_data': 0}
# Setting attribute "title" to "Measured data from a profiling Seabird CTD"
# Setting attribute "source" to "Profiling CTD from A.I.M.S. R.V. Solander"
# Setting attribute "project" to "KISSME2017"
# Setting attribute "raw_file_name" to "UWAB-016"
# Setting attribute "site_station" to "UWAB"
# Setting attribute "trip" to "KISSME2017Deployment"
# Setting attribute "is_profile_data" to "1"
# Setting attribute "timezone" to "UTC"
# Setting attribute "instrument_model" to "Solander CTD"
# Setting attribute "nominal_latitude" to ""
# Setting attribute "nominal_longitude" to ""
# Setting attribute "nominal_site_depth" to "260.0"
# E:\Experiments\kissme17\Archive_Profiling_FV00\Solander CTD
# Generating filename from naming convention.
# Best export dir is the raw_file_directory.
# Will to user input directory.
# Exporting E:\Experiments\kissme17\Archive_Profiling_FV00\Solander CTD//[KISSME2017]_[KISSME2017Deployment]_[UWAB]_[Solander CTD]_[]_[UWAB-016]_[].nc
# (array([19915, 19954, 19995, 20051, 20085, 20148], dtype=int64),)
# Initialising accessor.
# STORING RAW FILE ATTRIBUTES
# Setting attribute "raw_file_name" to "UWAB-Transect-001.cnv"
# Setting attribute "raw_file_directory" to "E:/Experiments/kissme17/ProfileData/CTD"
# {'title': '', 'institution': 'The University of Western Australia', 'institution_division': 'Ocean Dynamics', 'source': '', 'project': '', 'history': '', 'references': '', 'comment': '', 'Conventions': 'CF-1.7', 'trip': '', 'trip_deployed': '', 'site': '', 'site_station': '', 'instrument_make': '', 'instrument_model': '', 'instrument_serial_number': '', 'raw_file_name': 'UWAB-Transect-001.cnv', 'raw_file_directory': 'E:/Experiments/kissme17/ProfileData/CTD', 'raw_file_attributes': '', 'last_export_file_name': '', 'last_export_directory': '', 'last_load_file_name': '', 'last_load_directory': '', 'outfile_append': '', 'disclaimer': '', 'nominal_latitude': '', 'nominal_longitude': '', 'nominal_site_depth': '', 'pressure_sensor_height_asb': '', 'nominal_instrument_height_asb': '', 'nominal_instrument_orientation': '', 'timezone': '', 'is_profile_data': 0}
# Setting attribute "title" to "Measured data from a profiling Seabird CTD"
# Setting attribute "source" to "Profiling CTD from A.I.M.S. R.V. Solander"
# Setting attribute "project" to "KISSME2017"
# Setting attribute "raw_file_name" to "UWAB-Transect-001"
# Setting attribute "site_station" to "UWAB_transect"
# Setting attribute "trip" to "KISSME2017Deployment"
# Setting attribute "is_profile_data" to "1"
# Setting attribute "timezone" to "UTC"
# Setting attribute "instrument_model" to "Solander CTD"
# Setting attribute "nominal_latitude" to ""
# Setting attribute "nominal_longitude" to ""
# Setting attribute "nominal_site_depth" to "155.0"

# %% [markdown]
# # VMP Now
# Start with a test

# %%
if False:

    pfile = project_root + r'\Archive_Profiling_FV00\VMP_test\UWA_013.P'
    ini_file = project_root + r'\Archive_Profiling_FV00\VMP_test\default_vehicle_attributes.ini'

    rr, ds = rsi_vmp.from_pfile(pfile, ini_file)

    rr.add_comment('AZ', 'Testing')

    rr.ds.Ax.plot()

# %% [markdown]
# ## Now crush through them
# VMP logs are a nightmare. Do these blind for now.

# %%
pfilewc = project_root + r'/Data/Rockland/VMP/UWA*.P'
pfiles = glob.glob(pfilewc)
print(pfiles)

ini_file = project_root + r'/ProfileData/VMP/default_vehicle_attributes.ini'
# ini_file = project_root + r'\Archive_Profiling_FV00\VMP_test\default_vehicle_attributes.ini'

direc = r'E:/Experiments/kissme17/ProfileData/VMP/'

# for pfile in pfiles:
for index, row in db_data['profiler_metadata'].iterrows():
        
    attributes = ai.profiler_row_to_attrs(row)
    instrument = attributes['instrument_model']
    filename = attributes['raw_file_name']
    
    if not type(instrument) == str:
        print('Skipping')
        continue
    if not instrument.lower() in ['rockland_vmp_250']:
        print('Skipping')
        continue
        
#     attributes = {
#         'project': row['Project'],
#         'raw_file_name': row['Filename'],
#         'site_station': row['StationID'],
#         'trip': row['Trip'],
#         'is_profile_data': 1,
#         'timezone': 'UTC',
#         'instrument_model':  row['InstrumentType'],
#         'nominal_latitude': row['Profiler in [Lat]'],
#         'nominal_longitude': row['Profiler in [Lon]']}
    
    if not filename[-2::] == '.p':
#         filename = os.path.join(filename, '.p')
        filename += '.p'
    
    filename = os.path.join(direc, filename)
        
    rr, ds = rsi_vmp.from_pfile(filename, ini_file)
    rr.update_attributes_with_dict(attributes)
    
    ai.pIMOS_export(rr, archive_dir, instrument)
# Out:
# []
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# ***THE CONCEPT OF ODD AND EVEN CHANNELS HAS NOT BEEN IMPLEMENTED, FIX THIS IN THE FUTURE***
# file open
# Did not find the section
# invalid literal for int() with base 10: 'tr'
# invalid literal for int() with base 10: '_r'
# invalid literal for int() with base 10: ''
# Header digested, reading records
# Reading complete, calculating time and calibrating
# Not doing the second fit as yet
# Fast and slow are equal in length, no interp needed
# Not doing the second fit as yet
# Not doing the second fit as yet
# {'id': '5', 'type': 'therm', 'name': 'T1_dT1', 'diff_gain': '0.95', 'data': array([11404., 11392., 11383., ..., 11015., 10862., 10757.]), 'time': array(['2017-04-02T22:09:00.000000', '2017-04-02T22:09:00.000000',
#        '2017-04-02T22:09:00.000000', ..., '2017-04-02T22:28:37.000000',
#        '2017-04-02T22:28:37.000000', '2017-04-02T22:28:37.000000'],
#       dtype='datetime64[us]')}
# adc_fs
# Failed in calibrating T1_dT1
# {'id': '7', 'type': 'therm', 'name': 'T2_dT2', 'diff_gain': '0.92', 'data': array([-49., -51., -53., ..., -61., -55., -53.]), 'time': array(['2017-04-02T22:09:00.000000', '2017-04-02T22:09:00.000000',
#        '2017-04-02T22:09:00.000000', ..., '2017-04-02T22:28:37.000000',
#        '2017-04-02T22:28:37.000000', '2017-04-02T22:28:37.000000'],
#       dtype='datetime64[us]')}
# adc_fs
# Failed in calibrating T2_dT2
# T1_hres is a hres column, popping it (Spirit of JSC)
# Fast and slow are equal in length, no interp needed
# P_hres is a hres column, popping it (Spirit of JSC)
# Fast and slow are equal in length, no interp needed
# T2_hres is a hres column, popping it (Spirit of JSC)
# Fast and slow are equal in length, no interp needed
# ***ASSUMING VMP, FIX THIS IN THE FUTURE***
# ***ODAS ATTEMT TO TAKE THIS FROM ROOT AND FAILING THAT ASSUME VMP***
# ***HAVE DONE NOTHING WITH THE HOTEL FILE, FIX THIS IN THE FUTURE***
# ***HAVE DONE NOTHING WITH THE TEMPERATURE, FIX THIS IN THE FUTURE***
# ***IVE DONE A HACK JOB OF THE GRADIENTS, FIX THIS IN THE FUTURE***
# Not sure what this is: T1!
# Not sure what this is: T2!
# Initialising accessor.
# STORING RAW FILE ATTRIBUTES
# Setting attribute "raw_file_name" to "UWA_005.p"
# Setting attribute "raw_file_directory" to "E:/Experiments/kissme17/ProfileData/VMP"
# YEAR
# MONTH
# DAY
# HOUR
# MINUTE
# SECOND
# MILLISECOND
# DATETIME
# CONFIG_STRING
# FS_FAST
# FS_SLOW
# {'title': '', 'institution': 'The University of Western Australia', 'institution_division': 'Ocean Dynamics', 'source': '', 'project': '', 'history': '', 'references': '', 'comment': '', 'Conventions': 'CF-1.7', 'trip': '', 'trip_deployed': '', 'site': '', 'site_station': '', 'instrument_make': '', 'instrument_model': '', 'instrument_serial_number': '', 'raw_file_name': 'UWA_005.p', 'raw_file_directory': 'E:/Experiments/kissme17/ProfileData/VMP', 'raw_file_attributes': "{'Year': 2017, 'Month': 4, 'Day': 2, 'Hour': 22, 'Minute': 8, 'Second': 58, 'Millisecond': 0, 'datetime': datetime.datetime(2017, 4, 2, 22, 8, 58), 'config_string': '; Rolf Lueck, 2010-12-02\\r\\n;For Ming Feng VMP200 SN050, 2012-04-16 by Dave Cronkrite\\r\\n; 2012-05-22, Modified by Rolf Lueck in Perth.\\r\\n; 2017-03-30, Modified by CBluteau to reflect the 2x shear probes & 2xFP07 used\\r\\nrate=512\\r\\nprefix=uwa_\\r\\ndisk=c:/data\\r\\nrecsize=1\\r\\nprofile=vertical\\r\\nno-fast=6\\r\\nno-slow=2\\r\\n\\r\\n[matrix]\\r\\nnum_rows=8\\r\\nrow01=\\t255\\t0\\t1\\t2\\t5\\t7\\t8\\t9\\r\\nrow02=\\t32\\t40\\t1\\t2\\t5\\t7\\t8\\t9\\r\\nrow03=\\t41\\t42\\t1\\t2\\t5\\t7\\t8\\t9\\r\\nrow04=\\t4\\t6\\t1\\t2\\t5\\t7\\t8\\t9\\t\\r\\nrow05=\\t10\\t11\\t1\\t2\\t5\\t7\\t8\\t9\\r\\nrow06=\\t12\\t0\\t1\\t2\\t5\\t7\\t8\\t9\\r\\nrow07=\\t0\\t0\\t1\\t2\\t5\\t7\\t8\\t9\\r\\nrow08=\\t4\\t6\\t1\\t2\\t5\\t7\\t8\\t9\\r\\n\\r\\n[cruise_info]\\r\\nship=Solander\\r\\ninstrument=VMP-200\\r\\nSN=050\\r\\nowner=Ming Feng\\r\\ninstitute=UWA\\r\\nlocation=Browse\\r\\ncruise=KISSME\\r\\noperator=Cynthia Bluteau\\r\\n\\r\\n\\r\\n[gnd1]\\r\\nid=0\\r\\ntype=gnd\\r\\nname=Gnd\\r\\ncoef0=0\\r\\n\\r\\n[pitch]\\r\\nid=1\\r\\ntype=accel\\r\\nname=Ax\\r\\ncoef0=0\\r\\ncoef1=1\\r\\n\\r\\n[roll]\\r\\ntype=accel\\r\\nid=2\\r\\nname=Ay\\r\\ncoef0=0\\r\\ncoef1=1\\r\\n\\r\\n\\r\\n\\r\\n[shear1]\\r\\nid=8\\r\\ntype=shear\\r\\nSN=M1624\\r\\nname=sh1\\r\\ndiff_gain=0.94\\r\\nsens=0.0861\\r\\nadc_fs=4.096\\r\\nadc_bits=16\\r\\n\\r\\n\\r\\n[shear2]\\r\\nid=9\\r\\nname=sh2\\r\\ntype=shear\\r\\ndiff_gain=0.95\\r\\nSN=M1636\\r\\nsens=0.0817\\r\\nadc_fs=4.096\\r\\nadc_bits=16\\r\\n\\r\\n[therm1]\\r\\nid=4\\r\\ntype=therm\\r\\nname=T1\\r\\nadc_fs=4.096\\r\\nadc_bits=16\\r\\na=-4.7\\r\\nb=0.99849\\r\\nG=6\\r\\nE_B=0.68235\\r\\n; Specific to the FP07 used\\r\\nSN=T1303\\r\\nbeta=3071.06\\r\\nT_0=282.150\\r\\nunits=[degC]\\r\\n\\r\\n[dtherm1]\\r\\nid=5\\r\\ntype=therm\\r\\nname=T1_dT1\\r\\ndiff_gain=0.95\\r\\n\\r\\n\\r\\n[genvoltage0]\\r\\nid=32\\r\\ntype=voltage\\r\\nname=V_Bat\\r\\nadc_bits=16\\r\\nadc_fs=4.096\\r\\nG=0.1\\r\\nunits=[V]\\r\\n\\r\\n[pres]\\r\\nid=10\\r\\ntype=poly\\r\\nname=P\\r\\ncoef0=-2.37817\\r\\ncoef1=0.053084\\r\\ncoef2=0\\r\\ncoef3=0\\r\\nunits=[dBar]\\r\\n\\r\\n[dpres]\\r\\nid=11\\r\\ntype=poly\\r\\nname=P_dP\\r\\ndiff_gain=20.2\\r\\n\\r\\n[incl_x]\\r\\nid=40\\r\\ntype=inclxy\\r\\nname=Incl_X\\r\\ncoef0=0\\r\\ncoef1=0.025\\r\\nunits=[deg]\\r\\n\\r\\n[incl_y]\\r\\nid=41\\r\\ntype=inclxy\\r\\nname=Incl_Y\\r\\ncoef0=0\\r\\ncoef1=0.025\\r\\nunits=[deg]\\r\\n\\r\\n[incl_t]\\r\\nid=42\\r\\ntype=inclt\\r\\nname=Incl_T\\r\\ncoef0=624\\r\\ncoef1=-0.47\\r\\nunits=[degC]\\r\\n\\r\\n[genpoly0]\\r\\nid=12\\r\\ntype=poly\\r\\nname=PV\\r\\ncoef0=4.096\\r\\ncoef1=1.25e-4\\r\\ncoef2=0\\r\\ncoef3=0\\r\\nunits=[V]\\r\\n\\r\\n; redundant/additional FP07\\r\\n[therm2]\\r\\nid=6\\r\\ntype=therm\\r\\nname=T2\\r\\nadc_fs=4.096\\r\\nadc_bits=16\\r\\na=-16\\r\\nb=0.99858\\r\\nG=6\\r\\nE_B=0.68226\\r\\n; used the Fp07 that was moored during T-tide as a redundant FP07\\r\\nSN=T938\\r\\nbeta=3048.11\\r\\nT_0=290.008\\r\\nunits=[degC]\\r\\n\\r\\n[dtherm2]\\r\\nid=7\\r\\ntype=therm\\r\\nname=T2_dT2\\r\\ndiff_gain=0.92\\r\\n\\r\\n', 'fs_fast': 512.03275, 'fs_slow': 64.00409375}", 'last_export_file_name': '', 'last_export_directory': '', 'last_load_file_name': '', 'last_load_directory': '', 'outfile_append': '', 'disclaimer': '', 'nominal_latitude': '', 'nominal_longitude': '', 'nominal_site_depth': '', 'pressure_sensor_height ...
# Setting attribute "title" to "Measured data from a RSI VMP read from .P file"
# Setting attribute "source" to "RSI VMP"
# Setting attribute "project" to "KISSME2017"
# Setting attribute "raw_file_name" to "UWA_005"
# Setting attribute "site_station" to "SP250_12hr"
# Setting attribute "is_profile_data" to "1"
# Setting attribute "timezone" to "UTC"
# Setting attribute "instrument_model" to "rockland_vmp_250"
# Setting attribute "nominal_latitude" to "-13.76905"
# Setting attribute "nominal_longitude" to "123.35206"
# E:\Experiments\kissme17\Archive_Profiling_FV00\rockland_vmp_250
# Generating filename from naming convention.
# Best export dir is the raw_file_directory.
# Will to user input directory.
# Exporting E:\Experiments\kissme17\Archive_Profiling_FV00\rockland_vmp_250//[KISSME2017]_[]_[SP250_12hr]_[rockland_vmp_250]_[]_[UWA_005]_[].nc
# ***THE CONCEPT OF ODD AND EVEN CHANNELS HAS NOT BEEN IMPLEMENTED, FIX THIS IN THE FUTURE***
# file open
# Did not find the section
# invalid literal for int() with base 10: 'tr'
# invalid literal for int() with base 10: '_r'
# invalid literal for int() with base 10: ''
# Header digested, reading records
# Reading complete, calculating time and calibrating
# Not doing the second fit as yet
# Fast and slow are equal in length, no interp needed
# Not doing the second fit as yet
# Not doing the second fit as yet
# {'id': '5', 'type': 'therm', 'name': 'T1_dT1', 'diff_gain': '0.95', 'data': array([10811., 10746., 10616., ..., 10673., 10795., 10867.]), 'time': array(['2017-04-02T22:31:12.000000', '2017-04-02T22:31:12.000000',
#        '2017-04-02T22:31:12.000000', ..., '2017-04-02T22:44:47.000000',
#        '2017-04-02T22:44:47.000000', '2017-04-02T22:44:47.000000'],
#       dtype='datetime64[us]')}
# adc_fs
# Failed in calibrating T1_dT1
# {'id': '7', 'type': 'therm', 'name': 'T2_dT2', 'diff_gain': '0.92', 'data': array([-52., -47., -50., ..., -59., -52., -50.]), 'time': array(['2017-04-02T22:31:12.000000', '2017-04-02T22:31:12.000000',
#        '2017-04-02T22:31:12.000000', ..., '2017-04-02T22:44:47.000000',
#        '2017-04-02T22:44:47.000000', '2017-04-02T22:44:47.000000'],
#       dtype='datetime64[us]')}
# adc_fs
# Failed in calibrating T2_dT2
# T1_hres is a hres column, popping it (Spirit of JSC)
# Fast and slow are equal in length, no interp needed
# P_hres is a hres column, popping it (Spirit of JSC)
# Fast and slow are equal in length, no interp needed
# T2_hres is a hres column, popping it (Spirit of JSC)
# Fast and slow are equal in length, no interp needed
# ***ASSUMING VMP, FIX THIS IN THE FUTURE***
# ***ODAS ATTEMT TO TAKE THIS FROM ROOT AND FAILING THAT ASSUME VMP***
# ***HAVE DONE NOTHING WITH THE HOTEL FILE, FIX THIS IN THE FUTURE***
# ***HAVE DONE NOTHING WITH THE TEMPERATURE, FIX THIS IN THE FUTURE***
# ***IVE DONE A HACK JOB OF THE GRADIENTS, FIX THIS IN THE FUTURE***
# Not sure what this is: T1!
# Not sure what this is: T2!
# Initialising accessor.
# STORING RAW FILE ATTRIBUTES
# Setting attribute "raw_file_name" to "UWA_006.p"
# Setting attribute "raw_file_directory" to "E:/Experiments/kissme17/ProfileData/VMP"
# YEAR
# MONTH
# DAY
# HOUR
# MINUTE
# SECOND
# MILLISECOND
# DATETIME
# CONFIG_STRING
# FS_FAST
# FS_SLOW
# {'title': '', 'institution': 'The University of Western Australia', 'institution_division': 'Ocean Dynamics', 'source': '', 'project': '', 'history': '', 'references': '', 'comment': '', 'Conventions': 'CF-1.7', 'trip': '', 'trip_deployed': '', 'site': '', 'site_station': '', 'instrument_make': '', 'instrument_model': '', 'instrument_serial_number': '', 'raw_file_name': 'UWA_006.p', 'raw_file_directory': 'E:/Experiments/kissme17/ProfileData/VMP', 'raw_file_attributes': "{'Year': 2017, 'Month': 4, 'Day': 2, 'Hour': 22, 'Minute': 31, 'Second': 11, 'Millisecond': 0, 'datetime': datetime.datetime(2017, 4, 2, 22, 31, 11), 'config_string': '; Rolf Lueck, 2010-12-02\\r\\n;For Ming Feng VMP200 SN050, 2012-04-16 by Dave Cronkrite\\r\\n; 2012-05-22, Modified by Rolf Lueck in Perth.\\r\\n; 2017-03-30, Modified by CBluteau to reflect the 2x shear probes & 2xFP07 used\\r\\nrate=512\\r\\nprefix=uwa_\\r\\ndisk=c:/data\\r\\nrecsize=1\\r\\nprofile=vertical\\r\\nno-fast=6\\r\\nno-slow=2\\r\\n\\r\\n[matrix]\\r\\nnum_rows=8\\r\\nrow01=\\t255\\t0\\t1\\t2\\t5\\t7\\t8\\t9\\r\\nrow02=\\t32\\t40\\t1\\t2\\t5\\t7\\t8\\t9\\r\\nrow03=\\t41\\t42\\t1\\t2\\t5\\t7\\t8\\t9\\r\\nrow04=\\t4\\t6\\t1\\t2\\t5\\t7\\t8\\t9\\t\\r\\nrow05=\\t10\\t11\\t1\\t2\\t5\\t7\\t8\\t9\\r\\nrow06=\\t12\\t0\\t1\\t2\\t5\\t7\\t8\\t9\\r\\nrow07=\\t0\\t0\\t1\\t2\\t5\\t7\\t8\\t9\\r\\nrow08=\\t4\\t6\\t1\\t2\\t5\\t7\\t8\\t9\\r\\n\\r\\n[cruise_info]\\r\\nship=Solander\\r\\ninstrument=VMP-200\\r\\nSN=050\\r\\nowner=Ming Feng\\r\\ninstitute=UWA\\r\\nlocation=Browse\\r\\ncruise=KISSME\\r\\noperator=Cynthia Bluteau\\r\\n\\r\\n\\r\\n[gnd1]\\r\\nid=0\\r\\ntype=gnd\\r\\nname=Gnd\\r\\ncoef0=0\\r\\n\\r\\n[pitch]\\r\\nid=1\\r\\ntype=accel\\r\\nname=Ax\\r\\ncoef0=0\\r\\ncoef1=1\\r\\n\\r\\n[roll]\\r\\ntype=accel\\r\\nid=2\\r\\nname=Ay\\r\\ncoef0=0\\r\\ncoef1=1\\r\\n\\r\\n\\r\\n\\r\\n[shear1]\\r\\nid=8\\r\\ntype=shear\\r\\nSN=M1624\\r\\nname=sh1\\r\\ndiff_gain=0.94\\r\\nsens=0.0861\\r\\nadc_fs=4.096\\r\\nadc_bits=16\\r\\n\\r\\n\\r\\n[shear2]\\r\\nid=9\\r\\nname=sh2\\r\\ntype=shear\\r\\ndiff_gain=0.95\\r\\nSN=M1636\\r\\nsens=0.0817\\r\\nadc_fs=4.096\\r\\nadc_bits=16\\r\\n\\r\\n[therm1]\\r\\nid=4\\r\\ntype=therm\\r\\nname=T1\\r\\nadc_fs=4.096\\r\\nadc_bits=16\\r\\na=-4.7\\r\\nb=0.99849\\r\\nG=6\\r\\nE_B=0.68235\\r\\n; Specific to the FP07 used\\r\\nSN=T1303\\r\\nbeta=3071.06\\r\\nT_0=282.150\\r\\nunits=[degC]\\r\\n\\r\\n[dtherm1]\\r\\nid=5\\r\\ntype=therm\\r\\nname=T1_dT1\\r\\ndiff_gain=0.95\\r\\n\\r\\n\\r\\n[genvoltage0]\\r\\nid=32\\r\\ntype=voltage\\r\\nname=V_Bat\\r\\nadc_bits=16\\r\\nadc_fs=4.096\\r\\nG=0.1\\r\\nunits=[V]\\r\\n\\r\\n[pres]\\r\\nid=10\\r\\ntype=poly\\r\\nname=P\\r\\ncoef0=-2.37817\\r\\ncoef1=0.053084\\r\\ncoef2=0\\r\\ncoef3=0\\r\\nunits=[dBar]\\r\\n\\r\\n[dpres]\\r\\nid=11\\r\\ntype=poly\\r\\nname=P_dP\\r\\ndiff_gain=20.2\\r\\n\\r\\n[incl_x]\\r\\nid=40\\r\\ntype=inclxy\\r\\nname=Incl_X\\r\\ncoef0=0\\r\\ncoef1=0.025\\r\\nunits=[deg]\\r\\n\\r\\n[incl_y]\\r\\nid=41\\r\\ntype=inclxy\\r\\nname=Incl_Y\\r\\ncoef0=0\\r\\ncoef1=0.025\\r\\nunits=[deg]\\r\\n\\r\\n[incl_t]\\r\\nid=42\\r\\ntype=inclt\\r\\nname=Incl_T\\r\\ncoef0=624\\r\\ncoef1=-0.47\\r\\nunits=[degC]\\r\\n\\r\\n[genpoly0]\\r\\nid=12\\r\\ntype=poly\\r\\nname=PV\\r\\ncoef0=4.096\\r\\ncoef1=1.25e-4\\r\\ncoef2=0\\r\\ncoef3=0\\r\\nunits=[V]\\r\\n\\r\\n; redundant/additional FP07\\r\\n[therm2]\\r\\nid=6\\r\\ntype=therm\\r\\nname=T2\\r\\nadc_fs=4.096\\r\\nadc_bits=16\\r\\na=-16\\r\\nb=0.99858\\r\\nG=6\\r\\nE_B=0.68226\\r\\n; used the Fp07 that was moored during T-tide as a redundant FP07\\r\\nSN=T938\\r\\nbeta=3048.11\\r\\nT_0=290.008\\r\\nunits=[degC]\\r\\n\\r\\n[dtherm2]\\r\\nid=7\\r\\ntype=therm\\r\\nname=T2_dT2\\r\\ndiff_gain=0.92\\r\\n\\r\\n', 'fs_fast': 512.03275, 'fs_slow': 64.00409375}", 'last_export_file_name': '', 'last_export_directory': '', 'last_load_file_name': '', 'last_load_directory': '', 'outfile_append': '', 'disclaimer': '', 'nominal_latitude': '', 'nominal_longitude': '', 'nominal_site_depth': '', 'pressure_sensor_heig ...
# Setting attribute "title" to "Measured data from a RSI VMP read from .P file"
# Setting attribute "source" to "RSI VMP"
# Setting attribute "project" to "KISSME2017"
# Setting attribute "raw_file_name" to "UWA_006"
# Setting attribute "site_station" to "SP250_12hr"
# Setting attribute "is_profile_data" to "1"
# Setting attribute "timezone" to "UTC"
# Setting attribute "instrument_model" to "rockland_vmp_250"
# Setting attribute "nominal_latitude" to "-13.76217"
# Setting attribute "nominal_longitude" to "123.34339"
# E:\Experiments\kissme17\Archive_Profiling_FV00\rockland_vmp_250
# Generating filename from naming convention.
# Best export dir is the raw_file_directory.
# Will to user input directory.
# Exporting E:\Experiments\kissme17\Archive_Profiling_FV00\rockland_vmp_250//[KISSME2017]_[]_[SP250_12hr]_[rockland_vmp_250]_[]_[UWA_006]_[].nc
# ***THE CONCEPT OF ODD AND EVEN CHANNELS HAS NOT BEEN IMPLEMENTED, FIX THIS IN THE FUTURE***
# file open
# Did not find the section
# invalid literal for int() with base 10: 'tr'
# invalid literal for int() with base 10: '_r'
# invalid literal for int() with base 10: ''
# Header digested, reading records
# Reading complete, calculating time and calibrating
# Not doing the second fit as yet
# Fast and slow are equal in length, no interp needed
# Not doing the second fit as yet
# Not doing the second fit as yet
# {'id': '5', 'type': 'therm', 'name': 'T1_dT1', 'diff_gain': '0.95', 'data': array([12014., 11915., 11833., ..., 10987., 11013., 11059.]), 'time': array(['2017-04-02T23:56:05.000000', '2017-04-02T23:56:05.000000',
#        '2017-04-02T23:56:05.000000', ..., '2017-04-03T00:26:09.000000',
#        '2017-04-03T00:26:09.000000', '2017-04-03T00:26:09.000000'],
#       dtype='datetime64[us]')}
# adc_fs
# Failed in calibrating T1_dT1
# {'id': '7', 'type': 'therm', 'name': 'T2_dT2', 'diff_gain': '0.92', 'data': array([-55., -52., -52., ..., -45., -47., -51.]), 'time': array(['2017-04-02T23:56:05.000000', '2017-04-02T23:56:05.000000',
#        '2017-04-02T23:56:05.000000', ..., '2017-04-03T00:26:09.000000',
#        '2017-04-03T00:26:09.000000', '2017-04-03T00:26:09.000000'],
#       dtype='datetime64[us]')}
# adc_fs
# Failed in calibrating T2_dT2
# T1_hres is a hres column, popping it (Spirit of JSC)
# Fast and slow are equal in length, no interp needed
# P_hres is a hres column, popping it (Spirit of JSC)
# Fast and slow are equal in length, no interp needed
# T2_hres is a hres column, popping it (Spirit of JSC)
# Fast and slow are equal in length, no interp needed
# ***ASSUMING VMP, FIX THIS IN THE FUTURE***
# ***ODAS ATTEMT TO TAKE THIS FROM ROOT AND FAILING THAT ASSUME VMP***
# ***HAVE DONE NOTHING WITH THE HOTEL FILE, FIX THIS IN THE FUTURE***
# ***HAVE DONE NOTHING WITH THE TEMPERATURE, FIX THIS IN THE FUTURE***
# ***IVE DONE A HACK JOB OF THE GRADIENTS, FIX THIS IN THE FUTURE***
# Not sure what this is: T1!
# Not sure what this is: T2!
# Initialising accessor.
# STORING RAW FILE ATTRIBUTES
# Setting attribute "raw_file_name" to "UWA_007.p"
# Setting attribute "raw_file_directory" to "E:/Experiments/kissme17/ProfileData/VMP"
# YEAR
# MONTH
# DAY
# HOUR
# MINUTE
# SECOND
# MILLISECOND
# DATETIME
# CONFIG_STRING
# FS_FAST
# FS_SLOW
# {'title': '', 'institution': 'The University of Western Australia', 'institution_division': 'Ocean Dynamics', 'source': '', 'project': '', 'history': '', 'references': '', 'comment': '', 'Conventions': 'CF-1.7', 'trip': '', 'trip_deployed': '', 'site': '', 'site_station': '', 'instrument_make': '', 'instrument_model': '', 'instrument_serial_number': '', 'raw_file_name': 'UWA_007.p', 'raw_file_directory': 'E:/Experiments/kissme17/ProfileData/VMP', 'raw_file_attributes': "{'Year': 2017, 'Month': 4, 'Day': 2, 'Hour': 23, 'Minute': 56, 'Second': 4, 'Millisecond': 0, 'datetime': datetime.datetime(2017, 4, 2, 23, 56, 4), 'config_string': '; Rolf Lueck, 2010-12-02\\r\\n;For Ming Feng VMP200 SN050, 2012-04-16 by Dave Cronkrite\\r\\n; 2012-05-22, Modified by Rolf Lueck in Perth.\\r\\n; 2017-03-30, Modified by CBluteau to reflect the 2x shear probes & 2xFP07 used\\r\\nrate=512\\r\\nprefix=uwa_\\r\\ndisk=c:/data\\r\\nrecsize=1\\r\\nprofile=vertical\\r\\nno-fast=6\\r\\nno-slow=2\\r\\n\\r\\n[matrix]\\r\\nnum_rows=8\\r\\nrow01=\\t255\\t0\\t1\\t2\\t5\\t7\\t8\\t9\\r\\nrow02=\\t32\\t40\\t1\\t2\\t5\\t7\\t8\\t9\\r\\nrow03=\\t41\\t42\\t1\\t2\\t5\\t7\\t8\\t9\\r\\nrow04=\\t4\\t6\\t1\\t2\\t5\\t7\\t8\\t9\\t\\r\\nrow05=\\t10\\t11\\t1\\t2\\t5\\t7\\t8\\t9\\r\\nrow06=\\t12\\t0\\t1\\t2\\t5\\t7\\t8\\t9\\r\\nrow07=\\t0\\t0\\t1\\t2\\t5\\t7\\t8\\t9\\r\\nrow08=\\t4\\t6\\t1\\t2\\t5\\t7\\t8\\t9\\r\\n\\r\\n[cruise_info]\\r\\nship=Solander\\r\\ninstrument=VMP-200\\r\\nSN=050\\r\\nowner=Ming Feng\\r\\ninstitute=UWA\\r\\nlocation=Browse\\r\\ncruise=KISSME\\r\\noperator=Cynthia Bluteau\\r\\n\\r\\n\\r\\n[gnd1]\\r\\nid=0\\r\\ntype=gnd\\r\\nname=Gnd\\r\\ncoef0=0\\r\\n\\r\\n[pitch]\\r\\nid=1\\r\\ntype=accel\\r\\nname=Ax\\r\\ncoef0=0\\r\\ncoef1=1\\r\\n\\r\\n[roll]\\r\\ntype=accel\\r\\nid=2\\r\\nname=Ay\\r\\ncoef0=0\\r\\ncoef1=1\\r\\n\\r\\n\\r\\n\\r\\n[shear1]\\r\\nid=8\\r\\ntype=shear\\r\\nSN=M1624\\r\\nname=sh1\\r\\ndiff_gain=0.94\\r\\nsens=0.0861\\r\\nadc_fs=4.096\\r\\nadc_bits=16\\r\\n\\r\\n\\r\\n[shear2]\\r\\nid=9\\r\\nname=sh2\\r\\ntype=shear\\r\\ndiff_gain=0.95\\r\\nSN=M1636\\r\\nsens=0.0817\\r\\nadc_fs=4.096\\r\\nadc_bits=16\\r\\n\\r\\n[therm1]\\r\\nid=4\\r\\ntype=therm\\r\\nname=T1\\r\\nadc_fs=4.096\\r\\nadc_bits=16\\r\\na=-4.7\\r\\nb=0.99849\\r\\nG=6\\r\\nE_B=0.68235\\r\\n; Specific to the FP07 used\\r\\nSN=T1303\\r\\nbeta=3071.06\\r\\nT_0=282.150\\r\\nunits=[degC]\\r\\n\\r\\n[dtherm1]\\r\\nid=5\\r\\ntype=therm\\r\\nname=T1_dT1\\r\\ndiff_gain=0.95\\r\\n\\r\\n\\r\\n[genvoltage0]\\r\\nid=32\\r\\ntype=voltage\\r\\nname=V_Bat\\r\\nadc_bits=16\\r\\nadc_fs=4.096\\r\\nG=0.1\\r\\nunits=[V]\\r\\n\\r\\n[pres]\\r\\nid=10\\r\\ntype=poly\\r\\nname=P\\r\\ncoef0=-2.37817\\r\\ncoef1=0.053084\\r\\ncoef2=0\\r\\ncoef3=0\\r\\nunits=[dBar]\\r\\n\\r\\n[dpres]\\r\\nid=11\\r\\ntype=poly\\r\\nname=P_dP\\r\\ndiff_gain=20.2\\r\\n\\r\\n[incl_x]\\r\\nid=40\\r\\ntype=inclxy\\r\\nname=Incl_X\\r\\ncoef0=0\\r\\ncoef1=0.025\\r\\nunits=[deg]\\r\\n\\r\\n[incl_y]\\r\\nid=41\\r\\ntype=inclxy\\r\\nname=Incl_Y\\r\\ncoef0=0\\r\\ncoef1=0.025\\r\\nunits=[deg]\\r\\n\\r\\n[incl_t]\\r\\nid=42\\r\\ntype=inclt\\r\\nname=Incl_T\\r\\ncoef0=624\\r\\ncoef1=-0.47\\r\\nunits=[degC]\\r\\n\\r\\n[genpoly0]\\r\\nid=12\\r\\ntype=poly\\r\\nname=PV\\r\\ncoef0=4.096\\r\\ncoef1=1.25e-4\\r\\ncoef2=0\\r\\ncoef3=0\\r\\nunits=[V]\\r\\n\\r\\n; redundant/additional FP07\\r\\n[therm2]\\r\\nid=6\\r\\ntype=therm\\r\\nname=T2\\r\\nadc_fs=4.096\\r\\nadc_bits=16\\r\\na=-16\\r\\nb=0.99858\\r\\nG=6\\r\\nE_B=0.68226\\r\\n; used the Fp07 that was moored during T-tide as a redundant FP07\\r\\nSN=T938\\r\\nbeta=3048.11\\r\\nT_0=290.008\\r\\nunits=[degC]\\r\\n\\r\\n[dtherm2]\\r\\nid=7\\r\\ntype=therm\\r\\nname=T2_dT2\\r\\ndiff_gain=0.92\\r\\n\\r\\n', 'fs_fast': 512.03275, 'fs_slow': 64.00409375}", 'last_export_file_name': '', 'last_export_directory': '', 'last_load_file_name': '', 'last_load_directory': '', 'outfile_append': '', 'disclaimer': '', 'nominal_latitude': '', 'nominal_longitude': '', 'nominal_site_depth': '', 'pressure_sensor_height ...
# Setting attribute "title" to "Measured data from a RSI VMP read from .P file"
# Setting attribute "source" to "RSI VMP"
# Setting attribute "project" to "KISSME2017"
# Setting attribute "raw_file_name" to "UWA_007"
# Setting attribute "site_station" to "SP250_12hr"
# Setting attribute "is_profile_data" to "1"
# Setting attribute "timezone" to "UTC"
# Setting attribute "instrument_model" to "rockland_vmp_250"
# Setting attribute "nominal_latitude" to "-13.77234"
# Setting attribute "nominal_longitude" to "123.34905"
# E:\Experiments\kissme17\Archive_Profiling_FV00\rockland_vmp_250
# Generating filename from naming convention.
# Best export dir is the raw_file_directory.
# Will to user input directory.
# Exporting E:\Experiments\kissme17\Archive_Profiling_FV00\rockland_vmp_250//[KISSME2017]_[]_[SP250_12hr]_[rockland_vmp_250]_[]_[UWA_007]_[].nc
# ***THE CONCEPT OF ODD AND EVEN CHANNELS HAS NOT BEEN IMPLEMENTED, FIX THIS IN THE FUTURE***
# file open
# Did not find the section
# invalid literal for int() with base 10: 'tr'
# invalid literal for int() with base 10: '_r'
# invalid literal for int() with base 10: ''
# Header digested, reading records
# Reading complete, calculating time and calibrating
# Not doing the second fit as yet
# Fast and slow are equal in length, no interp needed
# Not doing the second fit as yet
# Not doing the second fit as yet
# {'id': '5', 'type': 'therm', 'name': 'T1_dT1', 'diff_gain': '0.95', 'data': array([10834., 10891., 10968., ..., 10864., 10831., 10848.]), 'time': array(['2017-04-03T00:26:48.000000', '2017-04-03T00:26:48.000000',
#        '2017-04-03T00:26:48.000000', ..., '2017-04-03T00:40:40.000000',
#        '2017-04-03T00:40:40.000000', '2017-04-03T00:40:40.000000'],
#       dtype='datetime64[us]')}
# adc_fs
# Failed in calibrating T1_dT1
# {'id': '7', 'type': 'therm', 'name': 'T2_dT2', 'diff_gain': '0.92', 'data': array([-46., -50., -52., ..., -58., -64., -46.]), 'time': array(['2017-04-03T00:26:48.000000', '2017-04-03T00:26:48.000000',
#        '2017-04-03T00:26:48.000000', ..., '2017-04-03T00:40:40.000000',
#        '2017-04-03T00:40:40.000000', '2017-04-03T00:40:40.000000'],
#       dtype='datetime64[us]')}
# adc_fs
# Failed in calibrating T2_dT2
# T1_hres is a hres column, popping it (Spirit of JSC)
# Fast and slow are equal in length, no interp needed
# P_hres is a hres column, popping it (Spirit of JSC)
# Fast and slow are equal in length, no interp needed
# T2_hres is a hres column, popping it (Spirit of JSC)
# Fast and slow are equal in length, no interp needed
# ***ASSUMING VMP, FIX THIS IN THE FUTURE***
# ***ODAS ATTEMT TO TAKE THIS FROM ROOT AND FAILING THAT ASSUME VMP***
# ***HAVE DONE NOTHING WITH THE HOTEL FILE, FIX THIS IN THE FUTURE***
# ***HAVE DONE NOTHING WITH THE TEMPERATURE, FIX THIS IN THE FUTURE***
# ***IVE DONE A HACK JOB OF THE GRADIENTS, FIX THIS IN THE FUTURE***
# Not sure what this is: T1!
# Not sure what this is: T2!
# Initialising accessor.
# STORING RAW FILE ATTRIBUTES
# Setting attribute "raw_file_name" to "UWA_008.p"
# Setting attribute "raw_file_directory" to "E:/Experiments/kissme17/ProfileData/VMP"
# YEAR
# MONTH
# DAY
# HOUR
# MINUTE
# SECOND
# MILLISECOND
# DATETIME
# CONFIG_STRING
# FS_FAST
# FS_SLOW
# {'title': '', 'institution': 'The University of Western Australia', 'institution_division': 'Ocean Dynamics', 'source': '', 'project': '', 'history': '', 'references': '', 'comment': '', 'Conventions': 'CF-1.7', 'trip': '', 'trip_deployed': '', 'site': '', 'site_station': '', 'instrument_make': '', 'instrument_model': '', 'instrument_serial_number': '', 'raw_file_name': 'UWA_008.p', 'raw_file_directory': 'E:/Experiments/kissme17/ProfileData/VMP', 'raw_file_attributes': "{'Year': 2017, 'Month': 4, 'Day': 3, 'Hour': 0, 'Minute': 26, 'Second': 47, 'Millisecond': 0, 'datetime': datetime.datetime(2017, 4, 3, 0, 26, 47), 'config_string': '; Rolf Lueck, 2010-12-02\\r\\n;For Ming Feng VMP200 SN050, 2012-04-16 by Dave Cronkrite\\r\\n; 2012-05-22, Modified by Rolf Lueck in Perth.\\r\\n; 2017-03-30, Modified by CBluteau to reflect the 2x shear probes & 2xFP07 used\\r\\nrate=512\\r\\nprefix=uwa_\\r\\ndisk=c:/data\\r\\nrecsize=1\\r\\nprofile=vertical\\r\\nno-fast=6\\r\\nno-slow=2\\r\\n\\r\\n[matrix]\\r\\nnum_rows=8\\r\\nrow01=\\t255\\t0\\t1\\t2\\t5\\t7\\t8\\t9\\r\\nrow02=\\t32\\t40\\t1\\t2\\t5\\t7\\t8\\t9\\r\\nrow03=\\t41\\t42\\t1\\t2\\t5\\t7\\t8\\t9\\r\\nrow04=\\t4\\t6\\t1\\t2\\t5\\t7\\t8\\t9\\t\\r\\nrow05=\\t10\\t11\\t1\\t2\\t5\\t7\\t8\\t9\\r\\nrow06=\\t12\\t0\\t1\\t2\\t5\\t7\\t8\\t9\\r\\nrow07=\\t0\\t0\\t1\\t2\\t5\\t7\\t8\\t9\\r\\nrow08=\\t4\\t6\\t1\\t2\\t5\\t7\\t8\\t9\\r\\n\\r\\n[cruise_info]\\r\\nship=Solander\\r\\ninstrument=VMP-200\\r\\nSN=050\\r\\nowner=Ming Feng\\r\\ninstitute=UWA\\r\\nlocation=Browse\\r\\ncruise=KISSME\\r\\noperator=Cynthia Bluteau\\r\\n\\r\\n\\r\\n[gnd1]\\r\\nid=0\\r\\ntype=gnd\\r\\nname=Gnd\\r\\ncoef0=0\\r\\n\\r\\n[pitch]\\r\\nid=1\\r\\ntype=accel\\r\\nname=Ax\\r\\ncoef0=0\\r\\ncoef1=1\\r\\n\\r\\n[roll]\\r\\ntype=accel\\r\\nid=2\\r\\nname=Ay\\r\\ncoef0=0\\r\\ncoef1=1\\r\\n\\r\\n\\r\\n\\r\\n[shear1]\\r\\nid=8\\r\\ntype=shear\\r\\nSN=M1624\\r\\nname=sh1\\r\\ndiff_gain=0.94\\r\\nsens=0.0861\\r\\nadc_fs=4.096\\r\\nadc_bits=16\\r\\n\\r\\n\\r\\n[shear2]\\r\\nid=9\\r\\nname=sh2\\r\\ntype=shear\\r\\ndiff_gain=0.95\\r\\nSN=M1636\\r\\nsens=0.0817\\r\\nadc_fs=4.096\\r\\nadc_bits=16\\r\\n\\r\\n[therm1]\\r\\nid=4\\r\\ntype=therm\\r\\nname=T1\\r\\nadc_fs=4.096\\r\\nadc_bits=16\\r\\na=-4.7\\r\\nb=0.99849\\r\\nG=6\\r\\nE_B=0.68235\\r\\n; Specific to the FP07 used\\r\\nSN=T1303\\r\\nbeta=3071.06\\r\\nT_0=282.150\\r\\nunits=[degC]\\r\\n\\r\\n[dtherm1]\\r\\nid=5\\r\\ntype=therm\\r\\nname=T1_dT1\\r\\ndiff_gain=0.95\\r\\n\\r\\n\\r\\n[genvoltage0]\\r\\nid=32\\r\\ntype=voltage\\r\\nname=V_Bat\\r\\nadc_bits=16\\r\\nadc_fs=4.096\\r\\nG=0.1\\r\\nunits=[V]\\r\\n\\r\\n[pres]\\r\\nid=10\\r\\ntype=poly\\r\\nname=P\\r\\ncoef0=-2.37817\\r\\ncoef1=0.053084\\r\\ncoef2=0\\r\\ncoef3=0\\r\\nunits=[dBar]\\r\\n\\r\\n[dpres]\\r\\nid=11\\r\\ntype=poly\\r\\nname=P_dP\\r\\ndiff_gain=20.2\\r\\n\\r\\n[incl_x]\\r\\nid=40\\r\\ntype=inclxy\\r\\nname=Incl_X\\r\\ncoef0=0\\r\\ncoef1=0.025\\r\\nunits=[deg]\\r\\n\\r\\n[incl_y]\\r\\nid=41\\r\\ntype=inclxy\\r\\nname=Incl_Y\\r\\ncoef0=0\\r\\ncoef1=0.025\\r\\nunits=[deg]\\r\\n\\r\\n[incl_t]\\r\\nid=42\\r\\ntype=inclt\\r\\nname=Incl_T\\r\\ncoef0=624\\r\\ncoef1=-0.47\\r\\nunits=[degC]\\r\\n\\r\\n[genpoly0]\\r\\nid=12\\r\\ntype=poly\\r\\nname=PV\\r\\ncoef0=4.096\\r\\ncoef1=1.25e-4\\r\\ncoef2=0\\r\\ncoef3=0\\r\\nunits=[V]\\r\\n\\r\\n; redundant/additional FP07\\r\\n[therm2]\\r\\nid=6\\r\\ntype=therm\\r\\nname=T2\\r\\nadc_fs=4.096\\r\\nadc_bits=16\\r\\na=-16\\r\\nb=0.99858\\r\\nG=6\\r\\nE_B=0.68226\\r\\n; used the Fp07 that was moored during T-tide as a redundant FP07\\r\\nSN=T938\\r\\nbeta=3048.11\\r\\nT_0=290.008\\r\\nunits=[degC]\\r\\n\\r\\n[dtherm2]\\r\\nid=7\\r\\ntype=therm\\r\\nname=T2_dT2\\r\\ndiff_gain=0.92\\r\\n\\r\\n', 'fs_fast': 512.03275, 'fs_slow': 64.00409375}", 'last_export_file_name': '', 'last_export_directory': '', 'last_load_file_name': '', 'last_load_directory': '', 'outfile_append': '', 'disclaimer': '', 'nominal_latitude': '', 'nominal_longitude': '', 'nominal_site_depth': '', 'pressure_sensor_height ...
# Setting attribute "title" to "Measured data from a RSI VMP read from .P file"
# Setting attribute "source" to "RSI VMP"
# Setting attribute "project" to "KISSME2017"
# Setting attribute "raw_file_name" to "UWA_008"
# Setting attribute "site_station" to "SP250_12hr"
# Setting attribute "is_profile_data" to "1"
# Setting attribute "timezone" to "UTC"
# Setting attribute "instrument_model" to "rockland_vmp_250"
# Setting attribute "nominal_latitude" to "-13.77459"
# Setting attribute "nominal_longitude" to "123.34506"
# E:\Experiments\kissme17\Archive_Profiling_FV00\rockland_vmp_250
# Generating filename from naming convention.
# Best export dir is the raw_file_directory.
# Will to user input directory.
# Exporting E:\Experiments\kissme17\Archive_Profiling_FV00\rockland_vmp_250//[KISSME2017]_[]_[SP250_12hr]_[rockland_vmp_250]_[]_[UWA_008]_[].nc
# ***THE CONCEPT OF ODD AND EVEN CHANNELS HAS NOT BEEN IMPLEMENTED, FIX THIS IN THE FUTURE***
# file open
# Did not find the section
# invalid literal for int() with base 10: 'tr'
# invalid literal for int() with base 10: '_r'
# invalid literal for int() with base 10: ''
# Header digested, reading records
# Reading complete, calculating time and calibrating
# Not doing the second fit as yet
# Fast and slow are equal in length, no interp needed
# Not doing the second fit as yet
# Not doing the second fit as yet
# {'id': '5', 'type': 'therm', 'name': 'T1_dT1', 'diff_gain': '0.95', 'data': array([12173., 12129., 12088., ...,  7981.,  9037.,  9475.]), 'time': array(['2017-04-03T02:23:06.000000', '2017-04-03T02:23:06.000000',
#        '2017-04-03T02:23:06.000000', ..., '2017-04-03T02:59:57.000000',
#        '2017-04-03T02:59:57.000000', '2017-04-03T02:59:57.000000'],
#       dtype='datetime64[us]')}
# adc_fs
# Failed in calibrating T1_dT1
# {'id': '7', 'type': 'therm', 'name': 'T2_dT2', 'diff_gain': '0.92', 'data': array([ -17., -109.,  -46., ...,  -40.,  -56.,  -58.]), 'time': array(['2017-04-03T02:23:06.000000', '2017-04-03T02:23:06.000000',
#        '2017-04-03T02:23:06.000000', ..., '2017-04-03T02:59:57.000000',
#        '2017-04-03T02:59:57.000000', '2017-04-03T02:59:57.000000'],
#       dtype='datetime64[us]')}
# adc_fs
# Failed in calibrating T2_dT2
# T1_hres is a hres column, popping it (Spirit of JSC)
# Fast and slow are equal in length, no interp needed
# P_hres is a hres column, popping it (Spirit of JSC)
# Fast and slow are equal in length, no interp needed
# T2_hres is a hres column, popping it (Spirit of JSC)
# Fast and slow are equal in length, no interp needed
# ***ASSUMING VMP, FIX THIS IN THE FUTURE***
# ***ODAS ATTEMT TO TAKE THIS FROM ROOT AND FAILING THAT ASSUME VMP***
# ***HAVE DONE NOTHING WITH THE HOTEL FILE, FIX THIS IN THE FUTURE***
# ***HAVE DONE NOTHING WITH THE TEMPERATURE, FIX THIS IN THE FUTURE***
# ***IVE DONE A HACK JOB OF THE GRADIENTS, FIX THIS IN THE FUTURE***
# Not sure what this is: T1!
# Not sure what this is: T2!
# Initialising accessor.
# STORING RAW FILE ATTRIBUTES
# Setting attribute "raw_file_name" to "UWA_009.p"
# Setting attribute "raw_file_directory" to "E:/Experiments/kissme17/ProfileData/VMP"
# YEAR
# MONTH
# DAY
# HOUR
# MINUTE
# SECOND
# MILLISECOND
# DATETIME
# CONFIG_STRING
# FS_FAST
# FS_SLOW
# {'title': '', 'institution': 'The University of Western Australia', 'institution_division': 'Ocean Dynamics', 'source': '', 'project': '', 'history': '', 'references': '', 'comment': '', 'Conventions': 'CF-1.7', 'trip': '', 'trip_deployed': '', 'site': '', 'site_station': '', 'instrument_make': '', 'instrument_model': '', 'instrument_serial_number': '', 'raw_file_name': 'UWA_009.p', 'raw_file_directory': 'E:/Experiments/kissme17/ProfileData/VMP', 'raw_file_attributes': "{'Year': 2017, 'Month': 4, 'Day': 3, 'Hour': 2, 'Minute': 23, 'Second': 4, 'Millisecond': 0, 'datetime': datetime.datetime(2017, 4, 3, 2, 23, 4), 'config_string': '; Rolf Lueck, 2010-12-02\\r\\n;For Ming Feng VMP200 SN050, 2012-04-16 by Dave Cronkrite\\r\\n; 2012-05-22, Modified by Rolf Lueck in Perth.\\r\\n; 2017-03-30, Modified by CBluteau to reflect the 2x shear probes & 2xFP07 used\\r\\nrate=512\\r\\nprefix=uwa_\\r\\ndisk=c:/data\\r\\nrecsize=1\\r\\nprofile=vertical\\r\\nno-fast=6\\r\\nno-slow=2\\r\\n\\r\\n[matrix]\\r\\nnum_rows=8\\r\\nrow01=\\t255\\t0\\t1\\t2\\t5\\t7\\t8\\t9\\r\\nrow02=\\t32\\t40\\t1\\t2\\t5\\t7\\t8\\t9\\r\\nrow03=\\t41\\t42\\t1\\t2\\t5\\t7\\t8\\t9\\r\\nrow04=\\t4\\t6\\t1\\t2\\t5\\t7\\t8\\t9\\t\\r\\nrow05=\\t10\\t11\\t1\\t2\\t5\\t7\\t8\\t9\\r\\nrow06=\\t12\\t0\\t1\\t2\\t5\\t7\\t8\\t9\\r\\nrow07=\\t0\\t0\\t1\\t2\\t5\\t7\\t8\\t9\\r\\nrow08=\\t4\\t6\\t1\\t2\\t5\\t7\\t8\\t9\\r\\n\\r\\n[cruise_info]\\r\\nship=Solander\\r\\ninstrument=VMP-200\\r\\nSN=050\\r\\nowner=Ming Feng\\r\\ninstitute=UWA\\r\\nlocation=Browse\\r\\ncruise=KISSME\\r\\noperator=Cynthia Bluteau\\r\\n\\r\\n\\r\\n[gnd1]\\r\\nid=0\\r\\ntype=gnd\\r\\nname=Gnd\\r\\ncoef0=0\\r\\n\\r\\n[pitch]\\r\\nid=1\\r\\ntype=accel\\r\\nname=Ax\\r\\ncoef0=0\\r\\ncoef1=1\\r\\n\\r\\n[roll]\\r\\ntype=accel\\r\\nid=2\\r\\nname=Ay\\r\\ncoef0=0\\r\\ncoef1=1\\r\\n\\r\\n\\r\\n\\r\\n[shear1]\\r\\nid=8\\r\\ntype=shear\\r\\nSN=M1624\\r\\nname=sh1\\r\\ndiff_gain=0.94\\r\\nsens=0.0861\\r\\nadc_fs=4.096\\r\\nadc_bits=16\\r\\n\\r\\n\\r\\n[shear2]\\r\\nid=9\\r\\nname=sh2\\r\\ntype=shear\\r\\ndiff_gain=0.95\\r\\nSN=M1636\\r\\nsens=0.0817\\r\\nadc_fs=4.096\\r\\nadc_bits=16\\r\\n\\r\\n[therm1]\\r\\nid=4\\r\\ntype=therm\\r\\nname=T1\\r\\nadc_fs=4.096\\r\\nadc_bits=16\\r\\na=-4.7\\r\\nb=0.99849\\r\\nG=6\\r\\nE_B=0.68235\\r\\n; Specific to the FP07 used\\r\\nSN=T1303\\r\\nbeta=3071.06\\r\\nT_0=282.150\\r\\nunits=[degC]\\r\\n\\r\\n[dtherm1]\\r\\nid=5\\r\\ntype=therm\\r\\nname=T1_dT1\\r\\ndiff_gain=0.95\\r\\n\\r\\n\\r\\n[genvoltage0]\\r\\nid=32\\r\\ntype=voltage\\r\\nname=V_Bat\\r\\nadc_bits=16\\r\\nadc_fs=4.096\\r\\nG=0.1\\r\\nunits=[V]\\r\\n\\r\\n[pres]\\r\\nid=10\\r\\ntype=poly\\r\\nname=P\\r\\ncoef0=-2.37817\\r\\ncoef1=0.053084\\r\\ncoef2=0\\r\\ncoef3=0\\r\\nunits=[dBar]\\r\\n\\r\\n[dpres]\\r\\nid=11\\r\\ntype=poly\\r\\nname=P_dP\\r\\ndiff_gain=20.2\\r\\n\\r\\n[incl_x]\\r\\nid=40\\r\\ntype=inclxy\\r\\nname=Incl_X\\r\\ncoef0=0\\r\\ncoef1=0.025\\r\\nunits=[deg]\\r\\n\\r\\n[incl_y]\\r\\nid=41\\r\\ntype=inclxy\\r\\nname=Incl_Y\\r\\ncoef0=0\\r\\ncoef1=0.025\\r\\nunits=[deg]\\r\\n\\r\\n[incl_t]\\r\\nid=42\\r\\ntype=inclt\\r\\nname=Incl_T\\r\\ncoef0=624\\r\\ncoef1=-0.47\\r\\nunits=[degC]\\r\\n\\r\\n[genpoly0]\\r\\nid=12\\r\\ntype=poly\\r\\nname=PV\\r\\ncoef0=4.096\\r\\ncoef1=1.25e-4\\r\\ncoef2=0\\r\\ncoef3=0\\r\\nunits=[V]\\r\\n\\r\\n; redundant/additional FP07\\r\\n[therm2]\\r\\nid=6\\r\\ntype=therm\\r\\nname=T2\\r\\nadc_fs=4.096\\r\\nadc_bits=16\\r\\na=-16\\r\\nb=0.99858\\r\\nG=6\\r\\nE_B=0.68226\\r\\n; used the Fp07 that was moored during T-tide as a redundant FP07\\r\\nSN=T938\\r\\nbeta=3048.11\\r\\nT_0=290.008\\r\\nunits=[degC]\\r\\n\\r\\n[dtherm2]\\r\\nid=7\\r\\ntype=therm\\r\\nname=T2_dT2\\r\\ndiff_gain=0.92\\r\\n\\r\\n', 'fs_fast': 512.03275, 'fs_slow': 64.00409375}", 'last_export_file_name': '', 'last_export_directory': '', 'last_load_file_name': '', 'last_load_directory': '', 'outfile_append': '', 'disclaimer': '', 'nominal_latitude': '', 'nominal_longitude': '', 'nominal_site_depth': '', 'pressure_sensor_height_a ...
# Setting attribute "title" to "Measured data from a RSI VMP read from .P file"
# Setting attribute "source" to "RSI VMP"
# Setting attribute "project" to "KISSME2017"
# Setting attribute "raw_file_name" to "UWA_009"
# Setting attribute "site_station" to "SP250_12hr"
# Setting attribute "is_profile_data" to "1"
# Setting attribute "timezone" to "UTC"
# Setting attribute "instrument_model" to "rockland_vmp_250"
# Setting attribute "nominal_latitude" to "-13.7695"
# Setting attribute "nominal_longitude" to "123.35364"
# E:\Experiments\kissme17\Archive_Profiling_FV00\rockland_vmp_250
# Generating filename from naming convention.
# Best export dir is the raw_file_directory.
# Will to user input directory.
# Exporting E:\Experiments\kissme17\Archive_Profiling_FV00\rockland_vmp_250//[KISSME2017]_[]_[SP250_12hr]_[rockland_vmp_250]_[]_[UWA_009]_[].nc
# ***THE CONCEPT OF ODD AND EVEN CHANNELS HAS NOT BEEN IMPLEMENTED, FIX THIS IN THE FUTURE***
# file open
# Did not find the section
# invalid literal for int() with base 10: 'tr'
# invalid literal for int() with base 10: '_r'
# invalid literal for int() with base 10: ''
# Header digested, reading records
# Reading complete, calculating time and calibrating
# Not doing the second fit as yet
# Fast and slow are equal in length, no interp needed
# Not doing the second fit as yet
# Not doing the second fit as yet
# {'id': '5', 'type': 'therm', 'name': 'T1_dT1', 'diff_gain': '0.95', 'data': array([12640., 12529., 12492., ..., 12081., 13050., 13382.]), 'time': array(['2017-04-03T04:00:23.000000', '2017-04-03T04:00:23.000000',
#        '2017-04-03T04:00:23.000000', ..., '2017-04-03T04:29:39.000000',
#        '2017-04-03T04:29:39.000000', '2017-04-03T04:29:39.000000'],
#       dtype='datetime64[us]')}
# adc_fs
# Failed in calibrating T1_dT1
# {'id': '7', 'type': 'therm', 'name': 'T2_dT2', 'diff_gain': '0.92', 'data': array([-32., -52., -66., ..., -48., -55., -51.]), 'time': array(['2017-04-03T04:00:23.000000', '2017-04-03T04:00:23.000000',
#        '2017-04-03T04:00:23.000000', ..., '2017-04-03T04:29:39.000000',
#        '2017-04-03T04:29:39.000000', '2017-04-03T04:29:39.000000'],
#       dtype='datetime64[us]')}
# adc_fs
# Failed in calibrating T2_dT2
# T1_hres is a hres column, popping it (Spirit of JSC)
# Fast and slow are equal in length, no interp needed
# P_hres is a hres column, popping it (Spirit of JSC)
# Fast and slow are equal in length, no interp needed
# T2_hres is a hres column, popping it (Spirit of JSC)
# Fast and slow are equal in length, no interp needed
# ***ASSUMING VMP, FIX THIS IN THE FUTURE***
# ***ODAS ATTEMT TO TAKE THIS FROM ROOT AND FAILING THAT ASSUME VMP***
# ***HAVE DONE NOTHING WITH THE HOTEL FILE, FIX THIS IN THE FUTURE***
# ***HAVE DONE NOTHING WITH THE TEMPERATURE, FIX THIS IN THE FUTURE***
# ***IVE DONE A HACK JOB OF THE GRADIENTS, FIX THIS IN THE FUTURE***
# Not sure what this is: T1!
# Not sure what this is: T2!
# Initialising accessor.
# STORING RAW FILE ATTRIBUTES
# Setting attribute "raw_file_name" to "UWA_010.p"
# Setting attribute "raw_file_directory" to "E:/Experiments/kissme17/ProfileData/VMP"
# YEAR
# MONTH
# DAY
# HOUR
# MINUTE
# SECOND
# MILLISECOND
# DATETIME
# CONFIG_STRING
# FS_FAST
# FS_SLOW
# {'title': '', 'institution': 'The University of Western Australia', 'institution_division': 'Ocean Dynamics', 'source': '', 'project': '', 'history': '', 'references': '', 'comment': '', 'Conventions': 'CF-1.7', 'trip': '', 'trip_deployed': '', 'site': '', 'site_station': '', 'instrument_make': '', 'instrument_model': '', 'instrument_serial_number': '', 'raw_file_name': 'UWA_010.p', 'raw_file_directory': 'E:/Experiments/kissme17/ProfileData/VMP', 'raw_file_attributes': "{'Year': 2017, 'Month': 4, 'Day': 3, 'Hour': 4, 'Minute': 0, 'Second': 22, 'Millisecond': 0, 'datetime': datetime.datetime(2017, 4, 3, 4, 0, 22), 'config_string': '; Rolf Lueck, 2010-12-02\\r\\n;For Ming Feng VMP200 SN050, 2012-04-16 by Dave Cronkrite\\r\\n; 2012-05-22, Modified by Rolf Lueck in Perth.\\r\\n; 2017-03-30, Modified by CBluteau to reflect the 2x shear probes & 2xFP07 used\\r\\nrate=512\\r\\nprefix=uwa_\\r\\ndisk=c:/data\\r\\nrecsize=1\\r\\nprofile=vertical\\r\\nno-fast=6\\r\\nno-slow=2\\r\\n\\r\\n[matrix]\\r\\nnum_rows=8\\r\\nrow01=\\t255\\t0\\t1\\t2\\t5\\t7\\t8\\t9\\r\\nrow02=\\t32\\t40\\t1\\t2\\t5\\t7\\t8\\t9\\r\\nrow03=\\t41\\t42\\t1\\t2\\t5\\t7\\t8\\t9\\r\\nrow04=\\t4\\t6\\t1\\t2\\t5\\t7\\t8\\t9\\t\\r\\nrow05=\\t10\\t11\\t1\\t2\\t5\\t7\\t8\\t9\\r\\nrow06=\\t12\\t0\\t1\\t2\\t5\\t7\\t8\\t9\\r\\nrow07=\\t0\\t0\\t1\\t2\\t5\\t7\\t8\\t9\\r\\nrow08=\\t4\\t6\\t1\\t2\\t5\\t7\\t8\\t9\\r\\n\\r\\n[cruise_info]\\r\\nship=Solander\\r\\ninstrument=VMP-200\\r\\nSN=050\\r\\nowner=Ming Feng\\r\\ninstitute=UWA\\r\\nlocation=Browse\\r\\ncruise=KISSME\\r\\noperator=Cynthia Bluteau\\r\\n\\r\\n\\r\\n[gnd1]\\r\\nid=0\\r\\ntype=gnd\\r\\nname=Gnd\\r\\ncoef0=0\\r\\n\\r\\n[pitch]\\r\\nid=1\\r\\ntype=accel\\r\\nname=Ax\\r\\ncoef0=0\\r\\ncoef1=1\\r\\n\\r\\n[roll]\\r\\ntype=accel\\r\\nid=2\\r\\nname=Ay\\r\\ncoef0=0\\r\\ncoef1=1\\r\\n\\r\\n\\r\\n\\r\\n[shear1]\\r\\nid=8\\r\\ntype=shear\\r\\nSN=M1624\\r\\nname=sh1\\r\\ndiff_gain=0.94\\r\\nsens=0.0861\\r\\nadc_fs=4.096\\r\\nadc_bits=16\\r\\n\\r\\n\\r\\n[shear2]\\r\\nid=9\\r\\nname=sh2\\r\\ntype=shear\\r\\ndiff_gain=0.95\\r\\nSN=M1636\\r\\nsens=0.0817\\r\\nadc_fs=4.096\\r\\nadc_bits=16\\r\\n\\r\\n[therm1]\\r\\nid=4\\r\\ntype=therm\\r\\nname=T1\\r\\nadc_fs=4.096\\r\\nadc_bits=16\\r\\na=-4.7\\r\\nb=0.99849\\r\\nG=6\\r\\nE_B=0.68235\\r\\n; Specific to the FP07 used\\r\\nSN=T1303\\r\\nbeta=3071.06\\r\\nT_0=282.150\\r\\nunits=[degC]\\r\\n\\r\\n[dtherm1]\\r\\nid=5\\r\\ntype=therm\\r\\nname=T1_dT1\\r\\ndiff_gain=0.95\\r\\n\\r\\n\\r\\n[genvoltage0]\\r\\nid=32\\r\\ntype=voltage\\r\\nname=V_Bat\\r\\nadc_bits=16\\r\\nadc_fs=4.096\\r\\nG=0.1\\r\\nunits=[V]\\r\\n\\r\\n[pres]\\r\\nid=10\\r\\ntype=poly\\r\\nname=P\\r\\ncoef0=-2.37817\\r\\ncoef1=0.053084\\r\\ncoef2=0\\r\\ncoef3=0\\r\\nunits=[dBar]\\r\\n\\r\\n[dpres]\\r\\nid=11\\r\\ntype=poly\\r\\nname=P_dP\\r\\ndiff_gain=20.2\\r\\n\\r\\n[incl_x]\\r\\nid=40\\r\\ntype=inclxy\\r\\nname=Incl_X\\r\\ncoef0=0\\r\\ncoef1=0.025\\r\\nunits=[deg]\\r\\n\\r\\n[incl_y]\\r\\nid=41\\r\\ntype=inclxy\\r\\nname=Incl_Y\\r\\ncoef0=0\\r\\ncoef1=0.025\\r\\nunits=[deg]\\r\\n\\r\\n[incl_t]\\r\\nid=42\\r\\ntype=inclt\\r\\nname=Incl_T\\r\\ncoef0=624\\r\\ncoef1=-0.47\\r\\nunits=[degC]\\r\\n\\r\\n[genpoly0]\\r\\nid=12\\r\\ntype=poly\\r\\nname=PV\\r\\ncoef0=4.096\\r\\ncoef1=1.25e-4\\r\\ncoef2=0\\r\\ncoef3=0\\r\\nunits=[V]\\r\\n\\r\\n; redundant/additional FP07\\r\\n[therm2]\\r\\nid=6\\r\\ntype=therm\\r\\nname=T2\\r\\nadc_fs=4.096\\r\\nadc_bits=16\\r\\na=-16\\r\\nb=0.99858\\r\\nG=6\\r\\nE_B=0.68226\\r\\n; used the Fp07 that was moored during T-tide as a redundant FP07\\r\\nSN=T938\\r\\nbeta=3048.11\\r\\nT_0=290.008\\r\\nunits=[degC]\\r\\n\\r\\n[dtherm2]\\r\\nid=7\\r\\ntype=therm\\r\\nname=T2_dT2\\r\\ndiff_gain=0.92\\r\\n\\r\\n', 'fs_fast': 512.03275, 'fs_slow': 64.00409375}", 'last_export_file_name': '', 'last_export_directory': '', 'last_load_file_name': '', 'last_load_directory': '', 'outfile_append': '', 'disclaimer': '', 'nominal_latitude': '', 'nominal_longitude': '', 'nominal_site_depth': '', 'pressure_sensor_height_a ...
# Setting attribute "title" to "Measured data from a RSI VMP read from .P file"
# Setting attribute "source" to "RSI VMP"
# Setting attribute "project" to "KISSME2017"
# Setting attribute "raw_file_name" to "UWA_010"
# Setting attribute "site_station" to "SP250_12hr"
# Setting attribute "is_profile_data" to "1"
# Setting attribute "timezone" to "UTC"
# Setting attribute "instrument_model" to "rockland_vmp_250"
# Setting attribute "nominal_latitude" to "-13.77001"
# Setting attribute "nominal_longitude" to "123.35474"
# E:\Experiments\kissme17\Archive_Profiling_FV00\rockland_vmp_250
# Generating filename from naming convention.
# Best export dir is the raw_file_directory.
# Will to user input directory.
# Exporting E:\Experiments\kissme17\Archive_Profiling_FV00\rockland_vmp_250//[KISSME2017]_[]_[SP250_12hr]_[rockland_vmp_250]_[]_[UWA_010]_[].nc
# ***THE CONCEPT OF ODD AND EVEN CHANNELS HAS NOT BEEN IMPLEMENTED, FIX THIS IN THE FUTURE***
# file open
# Did not find the section
# invalid literal for int() with base 10: 'tr'
# invalid literal for int() with base 10: '_r'
# invalid literal for int() with base 10: ''
# Header digested, reading records
# Reading complete, calculating time and calibrating
# Not doing the second fit as yet
# Fast and slow are equal in length, no interp needed
# Not doing the second fit as yet
# Not doing the second fit as yet
# {'id': '5', 'type': 'therm', 'name': 'T1_dT1', 'diff_gain': '0.95', 'data': array([12471., 12440., 12522., ...,  9590.,  9267.,  9019.]), 'time': array(['2017-04-03T05:58:56.000000', '2017-04-03T05:58:56.000000',
#        '2017-04-03T05:58:56.000000', ..., '2017-04-03T06:36:20.000000',
#        '2017-04-03T06:36:20.000000', '2017-04-03T06:36:20.000000'],
#       dtype='datetime64[us]')}
# adc_fs
# Failed in calibrating T1_dT1
# {'id': '7', 'type': 'therm', 'name': 'T2_dT2', 'diff_gain': '0.92', 'data': array([-11., -69., -51., ..., -54., -60., -47.]), 'time': array(['2017-04-03T05:58:56.000000', '2017-04-03T05:58:56.000000',
#        '2017-04-03T05:58:56.000000', ..., '2017-04-03T06:36:20.000000',
#        '2017-04-03T06:36:20.000000', '2017-04-03T06:36:20.000000'],
#       dtype='datetime64[us]')}
# adc_fs
# Failed in calibrating T2_dT2
# T1_hres is a hres column, popping it (Spirit of JSC)
# Fast and slow are equal in length, no interp needed
# P_hres is a hres column, popping it (Spirit of JSC)
# Fast and slow are equal in length, no interp needed
# T2_hres is a hres column, popping it (Spirit of JSC)
# Fast and slow are equal in length, no interp needed
# ***ASSUMING VMP, FIX THIS IN THE FUTURE***
# ***ODAS ATTEMT TO TAKE THIS FROM ROOT AND FAILING THAT ASSUME VMP***
# ***HAVE DONE NOTHING WITH THE HOTEL FILE, FIX THIS IN THE FUTURE***
# ***HAVE DONE NOTHING WITH THE TEMPERATURE, FIX THIS IN THE FUTURE***
# ***IVE DONE A HACK JOB OF THE GRADIENTS, FIX THIS IN THE FUTURE***
# Not sure what this is: T1!
# Not sure what this is: T2!
# Initialising accessor.
# STORING RAW FILE ATTRIBUTES
# Setting attribute "raw_file_name" to "UWA_011.p"
# Setting attribute "raw_file_directory" to "E:/Experiments/kissme17/ProfileData/VMP"
# YEAR
# MONTH
# DAY
# HOUR
# MINUTE
# SECOND
# MILLISECOND
# DATETIME
# CONFIG_STRING
# FS_FAST
# FS_SLOW
# ...
# Setting attribute "title" to "Measured data from a RSI VMP read from .P file"
# Setting attribute "source" to "RSI VMP"
# Setting attribute "project" to "KISSME2017"
# Setting attribute "raw_file_name" to "UWA_040"
# Setting attribute "site_station" to "UWAD_transect"
# Setting attribute "is_profile_data" to "1"
# Setting attribute "timezone" to "UTC"
# Setting attribute "instrument_model" to "rockland_vmp_250"
# Setting attribute "nominal_latitude" to "-14.2295"
# Setting attribute "nominal_longitude" to "123.04568"
# E:\Experiments\kissme17\Archive_Profiling_FV00\rockland_vmp_250
# Generating filename from naming convention.
# Best export dir is the raw_file_directory.
# Will to user input directory.
# Exporting E:\Experiments\kissme17\Archive_Profiling_FV00\rockland_vmp_250//[KISSME2017]_[]_[UWAD_transect]_[rockland_vmp_250]_[]_[UWA_040]_[].nc
# ***THE CONCEPT OF ODD AND EVEN CHANNELS HAS NOT BEEN IMPLEMENTED, FIX THIS IN THE FUTURE***
# file open
# Did not find the section
# invalid literal for int() with base 10: 'tr'
# invalid literal for int() with base 10: '_r'
# invalid literal for int() with base 10: ''
# Header digested, reading records
# Reading complete, calculating time and calibrating
# Not doing the second fit as yet
# Fast and slow are equal in length, no interp needed
# Not doing the second fit as yet
# Not doing the second fit as yet
# {'id': '5', 'type': 'therm', 'name': 'T1_dT1', 'diff_gain': '0.95', 'data': array([11864., 12175., 12425., ..., 10883., 11136., 11336.]), 'time': array(['2017-04-07T07:22:10.000000', '2017-04-07T07:22:10.000000',
#        '2017-04-07T07:22:10.000000', ..., '2017-04-07T07:44:25.000000',
#        '2017-04-07T07:44:25.000000', '2017-04-07T07:44:25.000000'],
#       dtype='datetime64[us]')}
# adc_fs
# Failed in calibrating T1_dT1
# {'id': '7', 'type': 'therm', 'name': 'T2_dT2', 'diff_gain': '0.92', 'data': array([7960., 7907., 7875., ..., 1388., 1028., 1344.]), 'time': array(['2017-04-07T07:22:10.000000', '2017-04-07T07:22:10.000000',
#        '2017-04-07T07:22:10.000000', ..., '2017-04-07T07:44:25.000000',
#        '2017-04-07T07:44:25.000000', '2017-04-07T07:44:25.000000'],
#       dtype='datetime64[us]')}
# adc_fs
# Failed in calibrating T2_dT2
# T1_hres is a hres column, popping it (Spirit of JSC)
# Fast and slow are equal in length, no interp needed
# P_hres is a hres column, popping it (Spirit of JSC)
# Fast and slow are equal in length, no interp needed
# T2_hres is a hres column, popping it (Spirit of JSC)
# Fast and slow are equal in length, no interp needed
# ***ASSUMING VMP, FIX THIS IN THE FUTURE***
# ***ODAS ATTEMT TO TAKE THIS FROM ROOT AND FAILING THAT ASSUME VMP***
# ***HAVE DONE NOTHING WITH THE HOTEL FILE, FIX THIS IN THE FUTURE***
# ***HAVE DONE NOTHING WITH THE TEMPERATURE, FIX THIS IN THE FUTURE***
# ***IVE DONE A HACK JOB OF THE GRADIENTS, FIX THIS IN THE FUTURE***
# Not sure what this is: T1!
# Not sure what this is: T2!
# Initialising accessor.
# STORING RAW FILE ATTRIBUTES
# Setting attribute "raw_file_name" to "UWA_041.p"
# Setting attribute "raw_file_directory" to "E:/Experiments/kissme17/ProfileData/VMP"
# YEAR
# MONTH
# DAY
# HOUR
# MINUTE
# SECOND
# MILLISECOND
# DATETIME
# CONFIG_STRING
# FS_FAST
# FS_SLOW
# {'title': '', 'institution': 'The University of Western Australia', 'institution_division': 'Ocean Dynamics', 'source': '', 'project': '', 'history': '', 'references': '', 'comment': '', 'Conventions': 'CF-1.7', 'trip': '', 'trip_deployed': '', 'site': '', 'site_station': '', 'instrument_make': '', 'instrument_model': '', 'instrument_serial_number': '', 'raw_file_name': 'UWA_041.p', 'raw_file_directory': 'E:/Experiments/kissme17/ProfileData/VMP', 'raw_file_attributes': "{'Year': 2017, 'Month': 4, 'Day': 7, 'Hour': 7, 'Minute': 22, 'Second': 9, 'Millisecond': 0, 'datetime': datetime.datetime(2017, 4, 7, 7, 22, 9), 'config_string': '; Rolf Lueck, 2010-12-02\\r\\n;For Ming Feng VMP200 SN050, 2012-04-16 by Dave Cronkrite\\r\\n; 2012-05-22, Modified by Rolf Lueck in Perth.\\r\\n; 2017-03-30, Modified by CBluteau to reflect the 2x shear probes & 2xFP07 used\\r\\nrate=512\\r\\nprefix=uwa_\\r\\ndisk=c:/data\\r\\nrecsize=1\\r\\nprofile=vertical\\r\\nno-fast=6\\r\\nno-slow=2\\r\\n\\r\\n[matrix]\\r\\nnum_rows=8\\r\\nrow01=\\t255\\t0\\t1\\t2\\t5\\t7\\t8\\t9\\r\\nrow02=\\t32\\t40\\t1\\t2\\t5\\t7\\t8\\t9\\r\\nrow03=\\t41\\t42\\t1\\t2\\t5\\t7\\t8\\t9\\r\\nrow04=\\t4\\t6\\t1\\t2\\t5\\t7\\t8\\t9\\t\\r\\nrow05=\\t10\\t11\\t1\\t2\\t5\\t7\\t8\\t9\\r\\nrow06=\\t12\\t0\\t1\\t2\\t5\\t7\\t8\\t9\\r\\nrow07=\\t0\\t0\\t1\\t2\\t5\\t7\\t8\\t9\\r\\nrow08=\\t4\\t6\\t1\\t2\\t5\\t7\\t8\\t9\\r\\n\\r\\n[cruise_info]\\r\\nship=Solander\\r\\ninstrument=VMP-200\\r\\nSN=050\\r\\nowner=Ming Feng\\r\\ninstitute=UWA\\r\\nlocation=Browse\\r\\ncruise=KISSME\\r\\noperator=Cynthia Bluteau\\r\\n\\r\\n\\r\\n[gnd1]\\r\\nid=0\\r\\ntype=gnd\\r\\nname=Gnd\\r\\ncoef0=0\\r\\n\\r\\n[pitch]\\r\\nid=1\\r\\ntype=accel\\r\\nname=Ax\\r\\ncoef0=0\\r\\ncoef1=1\\r\\n\\r\\n[roll]\\r\\ntype=accel\\r\\nid=2\\r\\nname=Ay\\r\\ncoef0=0\\r\\ncoef1=1\\r\\n\\r\\n\\r\\n\\r\\n[shear1]\\r\\nid=8\\r\\ntype=shear\\r\\nSN=M1624\\r\\nname=sh1\\r\\ndiff_gain=0.94\\r\\nsens=0.0861\\r\\nadc_fs=4.096\\r\\nadc_bits=16\\r\\n\\r\\n\\r\\n[shear2]\\r\\nid=9\\r\\nname=sh2\\r\\ntype=shear\\r\\ndiff_gain=0.95\\r\\nSN=M1636\\r\\nsens=0.0817\\r\\nadc_fs=4.096\\r\\nadc_bits=16\\r\\n\\r\\n[therm1]\\r\\nid=4\\r\\ntype=therm\\r\\nname=T1\\r\\nadc_fs=4.096\\r\\nadc_bits=16\\r\\na=-4.7\\r\\nb=0.99849\\r\\nG=6\\r\\nE_B=0.68235\\r\\n; Specific to the FP07 used\\r\\nSN=T1303\\r\\nbeta=3071.06\\r\\nT_0=282.150\\r\\nunits=[degC]\\r\\n\\r\\n[dtherm1]\\r\\nid=5\\r\\ntype=therm\\r\\nname=T1_dT1\\r\\ndiff_gain=0.95\\r\\n\\r\\n\\r\\n[genvoltage0]\\r\\nid=32\\r\\ntype=voltage\\r\\nname=V_Bat\\r\\nadc_bits=16\\r\\nadc_fs=4.096\\r\\nG=0.1\\r\\nunits=[V]\\r\\n\\r\\n[pres]\\r\\nid=10\\r\\ntype=poly\\r\\nname=P\\r\\ncoef0=-2.37817\\r\\ncoef1=0.053084\\r\\ncoef2=0\\r\\ncoef3=0\\r\\nunits=[dBar]\\r\\n\\r\\n[dpres]\\r\\nid=11\\r\\ntype=poly\\r\\nname=P_dP\\r\\ndiff_gain=20.2\\r\\n\\r\\n[incl_x]\\r\\nid=40\\r\\ntype=inclxy\\r\\nname=Incl_X\\r\\ncoef0=0\\r\\ncoef1=0.025\\r\\nunits=[deg]\\r\\n\\r\\n[incl_y]\\r\\nid=41\\r\\ntype=inclxy\\r\\nname=Incl_Y\\r\\ncoef0=0\\r\\ncoef1=0.025\\r\\nunits=[deg]\\r\\n\\r\\n[incl_t]\\r\\nid=42\\r\\ntype=inclt\\r\\nname=Incl_T\\r\\ncoef0=624\\r\\ncoef1=-0.47\\r\\nunits=[degC]\\r\\n\\r\\n[genpoly0]\\r\\nid=12\\r\\ntype=poly\\r\\nname=PV\\r\\ncoef0=4.096\\r\\ncoef1=1.25e-4\\r\\ncoef2=0\\r\\ncoef3=0\\r\\nunits=[V]\\r\\n\\r\\n; redundant/additional FP07\\r\\n[therm2]\\r\\nid=6\\r\\ntype=therm\\r\\nname=T2\\r\\nadc_fs=4.096\\r\\nadc_bits=16\\r\\na=-16\\r\\nb=0.99858\\r\\nG=6\\r\\nE_B=0.68226\\r\\n; used the Fp07 that was moored during T-tide as a redundant FP07\\r\\nSN=T938\\r\\nbeta=3048.11\\r\\nT_0=290.008\\r\\nunits=[degC]\\r\\n\\r\\n[dtherm2]\\r\\nid=7\\r\\ntype=therm\\r\\nname=T2_dT2\\r\\ndiff_gain=0.92\\r\\n\\r\\n', 'fs_fast': 512.03275, 'fs_slow': 64.00409375}", 'last_export_file_name': '', 'last_export_directory': '', 'last_load_file_name': '', 'last_load_directory': '', 'outfile_append': '', 'disclaimer': '', 'nominal_latitude': '', 'nominal_longitude': '', 'nominal_site_depth': '', 'pressure_sensor_height_a ...
# Setting attribute "title" to "Measured data from a RSI VMP read from .P file"
# Setting attribute "source" to "RSI VMP"
# Setting attribute "project" to "KISSME2017"
# Setting attribute "raw_file_name" to "UWA_041"
# Setting attribute "site_station" to "nan"
# Setting attribute "is_profile_data" to "1"
# Setting attribute "timezone" to "UTC"
# Setting attribute "instrument_model" to "rockland_vmp_250"
# Setting attribute "nominal_latitude" to "nan"
# Setting attribute "nominal_longitude" to "nan"
# E:\Experiments\kissme17\Archive_Profiling_FV00\rockland_vmp_250
# Generating filename from naming convention.
# Best export dir is the raw_file_directory.
# Will to user input directory.
# Exporting E:\Experiments\kissme17\Archive_Profiling_FV00\rockland_vmp_250//[KISSME2017]_[]_[]_[rockland_vmp_250]_[]_[UWA_041]_[].nc
# ***THE CONCEPT OF ODD AND EVEN CHANNELS HAS NOT BEEN IMPLEMENTED, FIX THIS IN THE FUTURE***
# file open
# Did not find the section
# invalid literal for int() with base 10: 'tr'
# invalid literal for int() with base 10: '_r'
# invalid literal for int() with base 10: ''
# Header digested, reading records
# Reading complete, calculating time and calibrating
# Not doing the second fit as yet
# Fast and slow are equal in length, no interp needed
# Not doing the second fit as yet
# Not doing the second fit as yet
# {'id': '5', 'type': 'therm', 'name': 'T1_dT1', 'diff_gain': '0.95', 'data': array([-14., -18., -18., ...,   1.,  -1., -14.]), 'time': array(['2017-04-07T08:05:01.000000', '2017-04-07T08:05:01.000000',
#        '2017-04-07T08:05:01.000000', ..., '2017-04-07T08:05:21.000000',
#        '2017-04-07T08:05:21.000000', '2017-04-07T08:05:21.000000'],
#       dtype='datetime64[us]')}
# adc_fs
# Failed in calibrating T1_dT1
# {'id': '7', 'type': 'therm', 'name': 'T2_dT2', 'diff_gain': '0.92', 'data': array([-56., -53., -48., ..., -37., -39., -51.]), 'time': array(['2017-04-07T08:05:01.000000', '2017-04-07T08:05:01.000000',
#        '2017-04-07T08:05:01.000000', ..., '2017-04-07T08:05:21.000000',
#        '2017-04-07T08:05:21.000000', '2017-04-07T08:05:21.000000'],
#       dtype='datetime64[us]')}
# adc_fs
# Failed in calibrating T2_dT2
# T1_hres is a hres column, popping it (Spirit of JSC)
# Fast and slow are equal in length, no interp needed
# P_hres is a hres column, popping it (Spirit of JSC)
# Fast and slow are equal in length, no interp needed
# T2_hres is a hres column, popping it (Spirit of JSC)
# Fast and slow are equal in length, no interp needed
# ***ASSUMING VMP, FIX THIS IN THE FUTURE***
# ***ODAS ATTEMT TO TAKE THIS FROM ROOT AND FAILING THAT ASSUME VMP***
# ***HAVE DONE NOTHING WITH THE HOTEL FILE, FIX THIS IN THE FUTURE***
# ***HAVE DONE NOTHING WITH THE TEMPERATURE, FIX THIS IN THE FUTURE***
# ***IVE DONE A HACK JOB OF THE GRADIENTS, FIX THIS IN THE FUTURE***
# Not sure what this is: T1!
# Not sure what this is: T2!
# Initialising accessor.
# STORING RAW FILE ATTRIBUTES
# Setting attribute "raw_file_name" to "UWA_042.p"
# Setting attribute "raw_file_directory" to "E:/Experiments/kissme17/ProfileData/VMP"
# YEAR
# MONTH
# DAY
# HOUR
# MINUTE
# SECOND
# MILLISECOND
# DATETIME
# CONFIG_STRING
# FS_FAST
# FS_SLOW
# {'title': '', 'institution': 'The University of Western Australia', 'institution_division': 'Ocean Dynamics', 'source': '', 'project': '', 'history': '', 'references': '', 'comment': '', 'Conventions': 'CF-1.7', 'trip': '', 'trip_deployed': '', 'site': '', 'site_station': '', 'instrument_make': '', 'instrument_model': '', 'instrument_serial_number': '', 'raw_file_name': 'UWA_042.p', 'raw_file_directory': 'E:/Experiments/kissme17/ProfileData/VMP', 'raw_file_attributes': "{'Year': 2017, 'Month': 4, 'Day': 7, 'Hour': 8, 'Minute': 5, 'Second': 0, 'Millisecond': 0, 'datetime': datetime.datetime(2017, 4, 7, 8, 5), 'config_string': '; Rolf Lueck, 2010-12-02\\r\\n;For Ming Feng VMP200 SN050, 2012-04-16 by Dave Cronkrite\\r\\n; 2012-05-22, Modified by Rolf Lueck in Perth.\\r\\n; 2017-03-30, Modified by CBluteau to reflect the 2x shear probes & 2xFP07 used\\r\\nrate=512\\r\\nprefix=uwa_\\r\\ndisk=c:/data\\r\\nrecsize=1\\r\\nprofile=vertical\\r\\nno-fast=6\\r\\nno-slow=2\\r\\n\\r\\n[matrix]\\r\\nnum_rows=8\\r\\nrow01=\\t255\\t0\\t1\\t2\\t5\\t7\\t8\\t9\\r\\nrow02=\\t32\\t40\\t1\\t2\\t5\\t7\\t8\\t9\\r\\nrow03=\\t41\\t42\\t1\\t2\\t5\\t7\\t8\\t9\\r\\nrow04=\\t4\\t6\\t1\\t2\\t5\\t7\\t8\\t9\\t\\r\\nrow05=\\t10\\t11\\t1\\t2\\t5\\t7\\t8\\t9\\r\\nrow06=\\t12\\t0\\t1\\t2\\t5\\t7\\t8\\t9\\r\\nrow07=\\t0\\t0\\t1\\t2\\t5\\t7\\t8\\t9\\r\\nrow08=\\t4\\t6\\t1\\t2\\t5\\t7\\t8\\t9\\r\\n\\r\\n[cruise_info]\\r\\nship=Solander\\r\\ninstrument=VMP-200\\r\\nSN=050\\r\\nowner=Ming Feng\\r\\ninstitute=UWA\\r\\nlocation=Browse\\r\\ncruise=KISSME\\r\\noperator=Cynthia Bluteau\\r\\n\\r\\n\\r\\n[gnd1]\\r\\nid=0\\r\\ntype=gnd\\r\\nname=Gnd\\r\\ncoef0=0\\r\\n\\r\\n[pitch]\\r\\nid=1\\r\\ntype=accel\\r\\nname=Ax\\r\\ncoef0=0\\r\\ncoef1=1\\r\\n\\r\\n[roll]\\r\\ntype=accel\\r\\nid=2\\r\\nname=Ay\\r\\ncoef0=0\\r\\ncoef1=1\\r\\n\\r\\n\\r\\n\\r\\n[shear1]\\r\\nid=8\\r\\ntype=shear\\r\\nSN=M1624\\r\\nname=sh1\\r\\ndiff_gain=0.94\\r\\nsens=0.0861\\r\\nadc_fs=4.096\\r\\nadc_bits=16\\r\\n\\r\\n\\r\\n[shear2]\\r\\nid=9\\r\\nname=sh2\\r\\ntype=shear\\r\\ndiff_gain=0.95\\r\\nSN=M1636\\r\\nsens=0.0817\\r\\nadc_fs=4.096\\r\\nadc_bits=16\\r\\n\\r\\n[therm1]\\r\\nid=4\\r\\ntype=therm\\r\\nname=T1\\r\\nadc_fs=4.096\\r\\nadc_bits=16\\r\\na=-4.7\\r\\nb=0.99849\\r\\nG=6\\r\\nE_B=0.68235\\r\\n; Specific to the FP07 used\\r\\nSN=T1303\\r\\nbeta=3071.06\\r\\nT_0=282.150\\r\\nunits=[degC]\\r\\n\\r\\n[dtherm1]\\r\\nid=5\\r\\ntype=therm\\r\\nname=T1_dT1\\r\\ndiff_gain=0.95\\r\\n\\r\\n\\r\\n[genvoltage0]\\r\\nid=32\\r\\ntype=voltage\\r\\nname=V_Bat\\r\\nadc_bits=16\\r\\nadc_fs=4.096\\r\\nG=0.1\\r\\nunits=[V]\\r\\n\\r\\n[pres]\\r\\nid=10\\r\\ntype=poly\\r\\nname=P\\r\\ncoef0=-2.37817\\r\\ncoef1=0.053084\\r\\ncoef2=0\\r\\ncoef3=0\\r\\nunits=[dBar]\\r\\n\\r\\n[dpres]\\r\\nid=11\\r\\ntype=poly\\r\\nname=P_dP\\r\\ndiff_gain=20.2\\r\\n\\r\\n[incl_x]\\r\\nid=40\\r\\ntype=inclxy\\r\\nname=Incl_X\\r\\ncoef0=0\\r\\ncoef1=0.025\\r\\nunits=[deg]\\r\\n\\r\\n[incl_y]\\r\\nid=41\\r\\ntype=inclxy\\r\\nname=Incl_Y\\r\\ncoef0=0\\r\\ncoef1=0.025\\r\\nunits=[deg]\\r\\n\\r\\n[incl_t]\\r\\nid=42\\r\\ntype=inclt\\r\\nname=Incl_T\\r\\ncoef0=624\\r\\ncoef1=-0.47\\r\\nunits=[degC]\\r\\n\\r\\n[genpoly0]\\r\\nid=12\\r\\ntype=poly\\r\\nname=PV\\r\\ncoef0=4.096\\r\\ncoef1=1.25e-4\\r\\ncoef2=0\\r\\ncoef3=0\\r\\nunits=[V]\\r\\n\\r\\n; redundant/additional FP07\\r\\n[therm2]\\r\\nid=6\\r\\ntype=therm\\r\\nname=T2\\r\\nadc_fs=4.096\\r\\nadc_bits=16\\r\\na=-16\\r\\nb=0.99858\\r\\nG=6\\r\\nE_B=0.68226\\r\\n; used the Fp07 that was moored during T-tide as a redundant FP07\\r\\nSN=T938\\r\\nbeta=3048.11\\r\\nT_0=290.008\\r\\nunits=[degC]\\r\\n\\r\\n[dtherm2]\\r\\nid=7\\r\\ntype=therm\\r\\nname=T2_dT2\\r\\ndiff_gain=0.92\\r\\n\\r\\n', 'fs_fast': 512.03275, 'fs_slow': 64.00409375}", 'last_export_file_name': '', 'last_export_directory': '', 'last_load_file_name': '', 'last_load_directory': '', 'outfile_append': '', 'disclaimer': '', 'nominal_latitude': '', 'nominal_longitude': '', 'nominal_site_depth': '', 'pressure_sensor_height_asb':  ...
# Setting attribute "title" to "Measured data from a RSI VMP read from .P file"
# Setting attribute "source" to "RSI VMP"
# Setting attribute "project" to "KISSME2017"
# Setting attribute "raw_file_name" to "UWA_042"
# Setting attribute "site_station" to "nan"
# Setting attribute "is_profile_data" to "1"
# Setting attribute "timezone" to "UTC"
# Setting attribute "instrument_model" to "rockland_vmp_250"
# Setting attribute "nominal_latitude" to "nan"
# Setting attribute "nominal_longitude" to "nan"
# E:\Experiments\kissme17\Archive_Profiling_FV00\rockland_vmp_250
# Generating filename from naming convention.
# Best export dir is the raw_file_directory.
# Will to user input directory.
# Exporting E:\Experiments\kissme17\Archive_Profiling_FV00\rockland_vmp_250//[KISSME2017]_[]_[]_[rockland_vmp_250]_[]_[UWA_042]_[].nc

# %%
row
# Out:
# Project                                                          KISSME2017
# Trip                                                   KISSME2017Deployment
# StationID                                                               NaN
# Profiler in [DateUTC]                                                   NaN
# Profiler in [TimeUTC]                                                   NaN
# Profiler out [TimeUTC]                                                  NaN
# Profiler in [Lat]                                                       NaN
# Profiler in [Lon]                                                       NaN
# Filename                                                            UWA_042
# InstrumentType                                             rockland_vmp_250
# Unnamed: 10                                                             NaN
# Unnamed: 11                                                             NaN
# Cast Depth Screen (m)                                                   NaN
# Depth Sounder (m)                                                       NaN
# Total Depth Sounder depth plus 2m Xduser offset (m)                     NaN
# Comment                                                                 NaN
# UWA Bottles                                                             NaN
# LISST Raw Filename                                                      NaN
# Unnamed: 18                                                             NaN
# LISST NC Filename                                                       NaN
# Unnamed: 20                                                             NaN
# UWA Niskin Bottle No. + Depth (m)                                       NaN
# Name: 126, dtype: object

# %% [markdown]
# # Make a MAP

# %%
import shapefile
import cartopy.crs as ccrs
import zutils.plotting as zplot

shp = shapefile.Reader(r'../../../zutils/data/bathy/ga/NWS_500.shp')
shp = shapefile.Reader(r'../../../zutils/sandpit/BATHY_ga_grid_to_coutour_shp/NWS_ALL_LEVELS.shp')

# %%
xl = [123, 123.4]
yl = [-14.4, -13.7]

xl = [122.4, 123.6]
yl = [-14.6, -13.5]

vmp_path = os.path.join(archive_dir, 'rockland_vmp_250')

plt.figure(figsize=(10, 10))

zl = zplot.axis_layer(heights = [5, 5], widths = [5, 10*np.diff(xl)/np.diff(yl), 5], hspace=2.5) 
zl.verbose = False

ax1 = zl.lay(1, 0, rowbleed=1, projection=ccrs.PlateCarree())
ax_main = zl.lay(1, 1, rowbleed=1, projection=ccrs.PlateCarree())

ax2 = zl.lay(0, 2, projection=ccrs.PlateCarree())
ax3 = zl.lay(1, 2, projection=ccrs.PlateCarree())

# plt.axes()
# ax_main = plt.axes(projection=ccrs.PlateCarree())

for i, file in enumerate(os.listdir(vmp_path)):
    
    fullpath = os.path.join(vmp_path, file)
    
    ds = xr.open_dataset(fullpath)
    
    if i == 0:
        label = 'VMP'
    else:
        label = None
        
    ax_main.plot(ds.lon_nom, ds.lat_nom, 'bo', label=label)
    ax1.plot(ds.lon_nom, ds.lat_nom, 'bo')
    ax2.plot(ds.lon_nom, ds.lat_nom, 'bo')
    ax3.plot(ds.lon_nom, ds.lat_nom, 'bo')
    
ctd_path = os.path.join(archive_dir, 'solander ctd')

for i, file in enumerate(os.listdir(ctd_path)):
    
    fullpath = os.path.join(ctd_path, file)
    
    ds = xr.open_dataset(fullpath)
    
    if i == 0:
        label = 'CTD'
    else:
        label = None
    ax_main.plot(np.mean(ds.longitude), np.mean(ds.latitude), 'r+', label=label)
    ax1.plot(np.mean(ds.longitude), np.mean(ds.latitude), 'r+')
    ax2.plot(np.mean(ds.longitude), np.mean(ds.latitude), 'r+')
    ax3.plot(np.mean(ds.longitude), np.mean(ds.latitude), 'r+')
    
for record in shp.shapeRecords():
    x, y = np.array(record.shape.points).T
    ax_main.plot(x, y, 'k', lw=0.5)

ax_main.legend()
ax_main.set_xlim(xl)
ax_main.set_ylim(yl)
ax_main.set_aspect('equal')
ax_main.gridlines(draw_labels=True)

ax1.set_xlim(123.02, 123.06)
ax1.set_ylim(-14.27, -14.17)
ax1.gridlines()
ax1.set_title('D-Transect')

ax2.set_xlim(123.33, 123.37)
ax2.set_ylim(-13.79, -13.75)
ax2.gridlines()
ax2.set_title('KISSME ARRAY')

ax3.set_ylim(-14.26, -14.12)
ax3.set_xlim(123.18, 123.32)
ax3.gridlines()
ax3.set_title('B-Transect')
# Out:
# Figure size is 27.909090909090807 x 13.0 cm
# Text(0.5, 1.0, 'B-Transect')

# %% [markdown]
# # Check naming

# %%
print(rr.get_export_location(naming_method='convention'))
print()
print(rr.get_export_location(naming_method='raw_file'))
print()
print(rr.get_export_location(naming_method='last_load'))
print()
print(rr.get_export_location(naming_method=None))
# Out:
# Generating filename from naming convention.
# Best export dir is the raw_file_directory.
# ('G:\\Experiments\\kissme17\\Archive_Profiling_FV00\\VMP', '__.nc')
#
# Will save file using raw file name and directory.
# ('G:\\Experiments\\kissme17\\Archive_Profiling_FV00\\VMP', 'UWA_013.nc')
#
# Will save file using last load file name and directory.
# ('', '')
#
# Will save file using raw file name and directory.
# ('G:\\Experiments\\kissme17\\Archive_Profiling_FV00\\VMP', 'UWA_013.nc')

# %%
rr.export(naming_method='raw_file')
# Out:
# Will save file using raw file name and directory.
# Exporting G:\Experiments\kissme17\Archive_Profiling_FV00\VMP//UWA_013.nc
# <xarray.Dataset>
# Dimensions:     (time_fast: 1192448, time_slow: 149056)
# Coordinates:
#   * time_fast   (time_fast) datetime64[ns] 2017-04-03T07:58:14 ... 2017-04-03...
#   * time_slow   (time_slow) datetime64[ns] 2017-04-03T07:58:14 ... 2017-04-03...
# Data variables: (12/28)
#     Ax          (time_fast) float64 -1.57e+03 -3.316e+03 ... -2.139e+03 -686.7
#     Ay          (time_fast) float64 -1.315e+03 -4.846e+03 ... -2.403e+03
#     sh1         (time_fast) float64 6.443 -12.01 -18.35 ... 33.86 71.1 67.16
#     sh2         (time_fast) float64 3.872 -3.986 -10.93 ... -48.4 -28.24 11.62
#     T1_dT1      (time_fast) float64 1.269e+04 1.27e+04 ... 9.315e+03 9.105e+03
#     V_Bat       (time_slow) float64 15.85 15.85 15.85 ... 15.73 15.72 15.72
#     ...          ...
#     W_fast      (time_fast) float64 0.007514 0.007487 ... -0.00165 -0.001649
#     W_slow      (time_slow) float64 0.01236 0.01193 ... -0.0008984 -0.0008535
#     speed_fast  (time_fast) float64 0.05 0.05 0.05 0.05 ... 0.05 0.05 0.05 0.05
#     speed_slow  (time_slow) float64 0.05 0.05 0.05 0.05 ... 0.05 0.05 0.05 0.05
#     gradT1      (time_fast) float64 -7.148 -7.148 -6.21 ... -0.03166 -9.851
#     gradT2      (time_fast) float64 0.008249 0.008249 ... -0.06126 -0.1119
# Attributes: (12/32)
#     title:                           Measured data from a RSI VMP read from ....
#     institution:                     The University of Western Australia
#     institution_division:            Ocean Dynamics
#     source:                          RSI VMP
#     project:
#     history:
#     ...                              ...
#     nominal_site_depth:
#     pressure_sensor_height_asb:
#     nominal_instrument_height_asb:
#     nominal_instrument_orientation:
#     timezone:
#     is_profile_data:                 0

# %% [markdown]
# ## LISST
#
# I DIDN'T HAVE THE LISST_OutputInfo.csv or LISST_Sediment_SizeBins.csv FILES FOR THE PROFILING GUY. I COPIED FROM THE MOORED GUY. ASK WILL!!!!!

# %%
filename = r'E:\Experiments\kissme17\ProfileData\LISST\2009\L0900428.csv'

rr, ds = lisst.from_csv(filename)

rr.update_attributes_with_dict(attributes)

pqc.pimosInOutWaterQC(rr, mooring, db_data)

ai.pIMOS_export(rr, archive_dir, instrument)

# fig = ai.plot_temp(rr, db_data, mooring.lower(), attributes, variable='depth',plotraw=True, experiment='kissme', recovered='kissme_recovery')
# png_path = rr.fullpath_last_export[0:-3] +'.png'
# fig.savefig(png_path, dpi=300)
# Out:
# Im a string
# Reading info
# Reading csv
# Converting time
# Adding flags
# Parsing csv
# Initialising accessor.
# STORING RAW FILE ATTRIBUTES
# Setting attribute "raw_file_name" to "L0900428.csv"
# Setting attribute "raw_file_directory" to "E:\Experiments\kissme17\ProfileData\LISST\2009"
# {'title': '', 'institution': 'The University of Western Australia', 'institution_division': 'Ocean Dynamics', 'source': '', 'project': '', 'history': '', 'references': '', 'comment': '', 'Conventions': 'CF-1.7', 'trip': '', 'trip_deployed': '', 'site': '', 'site_station': '', 'instrument_make': '', 'instrument_model': '', 'instrument_serial_number': '', 'raw_file_name': 'L0900428.csv', 'raw_file_directory': 'E:\\Experiments\\kissme17\\ProfileData\\LISST\\2009', 'raw_file_attributes': '', 'last_export_file_name': '', 'last_export_directory': '', 'last_load_file_name': '', 'last_load_directory': '', 'outfile_append': '', 'disclaimer': '', 'nominal_latitude': '', 'nominal_longitude': '', 'nominal_site_depth': '', 'pressure_sensor_height_asb': '', 'nominal_instrument_height_asb': '', 'nominal_instrument_orientation': '', 'timezone': '', 'is_profile_data': 0}
# Setting attribute "title" to "Measured data from a LISST Data Logger"
# Setting attribute "source" to "LISST Data Logger"
# Done
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-73-c065aa3f722b> in <module>
#       3 rr, ds = lisst.from_csv(filename)
#       4
# ----> 5 rr.update_attributes_with_dict(attributes)
#       6
#       7 pqc.pimosInOutWaterQC(rr, mooring, db_data)
#
# NameError: name 'attributes' is not defined

# %%
rr.ds.depth.plot()
plt.show()
rr.ds.temp.plot()
plt.show()
rr.ds.conc.T.plot()

# %% [markdown]
# # ^^ NOT THE SAME AS WILL'S NETCDFS. ASK.
