# %% [markdown]
# # Example notebook for processing SBE data with pIMOS
#
# Included instruments:
# - SBE56
# - SBE39 T
# - SBE39 TP
# - SBE37 CTD
# - And of course our very special friend, SBE37 4567 CT
#
#
# Notebook demonstrates:
# - API for reading
# - All variables/netcdf files CF compliant [compliant enough]
# - API for QAQC [note there are no automated codes for this, this just shows how such a code should interface with the xarray objects]
# - API for exporting
#
# At the bottom ALL seabird instruments are read and processed in a loop.
#
# ### NOTE:
# SBE 56s seem to have an issue with dates. I haven't really investigated this

# %%
# !pip install xarray
# !pip install -e ../crude_readers/

# %%
# import seabird as sbd
import crude_readers.read.SEABIRD_37_39_56 as read_sbd
import crude_readers.SEABIRD_37_39_56 as wrap_sbd
import os
import matplotlib.pyplot as plt
import datetime
import numpy as np 

os.path.exists(r'./KISSME samples/SBE39/3724.cnv')

# O Drive is //drive.irds.uwa.edu.au/CEME-BBL-001
pIMOS_export_dir = r'O:\Data\pIMOS\KISSME'

def pIMOS_export(rr, model, serial):
    
    folder = os.path.join(pIMOS_export_dir, model)
    if not os.path.exists(folder):
        os.mkdir(folder)

    print(folder)

    rr.folder = folder
    rr.file_ = serial
    rr.export()

# %% [markdown]
# # SBE39 TP
# Matt has code in his mycurrents seabird, derived from UHDAS, for reading both CNV and ASCII. Only the ASCII appears to work. I think the issue is with the UHDAS code.
#
# It seems like it is reading the file (based on run time) but it

# %%
asc_filename = r'./KISSME samples/SBE39/67761705.asc' 

folder, file = os.path.split(asc_filename)
rr = wrap_sbd.SEABIRD_37_39_56(folder, file, model='SBE39')
rr.ds
# Out:
# asc file appears to be for an SBE39...
# temperature and pressure
# WARNING, COMPLIANCE CHECK NOT YET IMPLEMENTED.
# WARNING, COMPLIANCE CHECK NOT YET IMPLEMENTED.
# Setting default attributes of the class.
# Setting attribute "title" to "Measured data from a Seabird Data Logger"
# Setting attribute "source" to "Seabird Data Logger"
# Setting attribute "history" to ""
# Setting attribute "comment" to ""
# <xarray.Dataset>
# Dimensions:         (time: 224272)
# Coordinates:
#   * time            (time) datetime64[ns] 2017-04-01T01:00:00 ... 2017-05-09T...
# Data variables:
#     Temperature     (time) float64 21.4 21.4 21.4 21.4 ... 12.9 12.9 12.9 12.89
#     Pressure        (time) float64 -0.047 -0.047 -0.047 ... 240.2 240.2 240.2
#     qc_Temperature  (time) float64 -999.0 -999.0 -999.0 ... -999.0 -999.0 -999.0
#     qc_Pressure     (time) float64 -999.0 -999.0 -999.0 ... -999.0 -999.0 -999.0

# %%
# %matplotlib inline
rr.ds.Temperature.plot(figsize=(15, 3))
plt.grid()
plt.xlim(rr.ds.time[[0, -1]])
plt.show()

# %% [markdown]
# # QAQC
# Apply QAQC code to everything prior to Apil 2 at 5:00 and replot.
#
# Note the qc_Temperature and qc_Pressure fields in the dataset above. These control the QAQC. Use the get_qaqc_var method to update these. Update both using '*'.

# %%
rr.update_qc_flag('*', 
                  'time',
                  np.datetime64(datetime.datetime(2017, 1, 1)),
                  np.datetime64(datetime.datetime(2017, 4, 2, 5)),
                 1)

# Now use the 'get_qaqc_var' method to pull the QAQC'd value
rr.get_qaqc_var('Temperature').plot(figsize=(15, 3))
plt.grid()
plt.xlim(rr.ds.time[[0, -1]])
plt.show()

rr.ds['Temperature'].plot(figsize=(15, 3), label='QAQC')
# You can still pull the raw data like this
rr.get_qaqc_var('Temperature').plot(label='Raw')
plt.grid()
plt.xlim(rr.ds.time[[0, -1]])
plt.show()
# Out:
# Blanking 6830 values.
# Blanking 6830 values.

# %% [markdown]
# # SBE39 T
# Matt has code in his mycurrents seabird, derived from UHDAS, for reading both CNV and ASCII. Only the ASCII appears to work. I think the issue is with the UHDAS code.
#
# It seems like it is reading the file (based on run time) but it

# %%
# cnv_filename = r'./KISSME samples/SBE39/3724.cnv'
asc_filename = r'./KISSME samples/SBE39/3724.asc'

# mcout_asc = read_sbd.parse_seabird_asc(asc_filename)

folder, file = os.path.split(asc_filename)
rr = wrap_sbd.SEABIRD_37_39_56(folder, file, model='SBE39')
rr.ds
# Out:
# asc file appears to be for an SBE39...
# WARNING, COMPLIANCE CHECK NOT YET IMPLEMENTED.
# Setting default attributes of the class.
# Setting attribute "title" to "Measured data from a Seabird Data Logger"
# Setting attribute "source" to "Seabird Data Logger"
# Setting attribute "history" to ""
# Setting attribute "comment" to ""
# <xarray.Dataset>
# Dimensions:         (time: 396749)
# Coordinates:
#   * time            (time) datetime64[ns] 2017-04-01T01:00:00 ... 2017-05-26T...
# Data variables:
#     Temperature     (time) float64 21.7 21.7 21.7 21.7 ... 26.76 27.24 27.56
#     qc_Temperature  (time) float64 -999.0 -999.0 -999.0 ... -999.0 -999.0 -999.0

# %% [markdown]
# # QAQC and plot

# %%
# %matplotlib inline

rr.update_qc_flag('*', 
                  'time',
                  np.datetime64(datetime.datetime(2017, 1, 1)),
                  np.datetime64(datetime.datetime(2017, 4, 2, 3)),
                 1)
rr.update_qc_flag('*', 
                  'time',
                  np.datetime64(datetime.datetime(2017, 5, 22, 0)),
                  np.datetime64(datetime.datetime(2017, 6, 2)),
                 1)

# You can still pull the raw data like this
rr.ds['Temperature'].plot(figsize=(15, 3), label='Raw')
rr.get_qaqc_var('Temperature').plot(label='QAQC')
plt.grid()
plt.title('Raw data')
plt.xlim(rr.ds.time[[0, -1]])
plt.legend()
plt.show()
# Out:
# Blanking 7280 values.

# %% [markdown]
# # SBE39 TP

# %%
asc_filename = r'./KISSME samples/SBE39/39751705.asc' # Has no Pressure???
asc_filename = r'./KISSME samples/SBE39/58391705.asc' # Temperature cooked??
asc_filename = r'./KISSME samples/SBE39/58551705.asc' # Temperature cooked??
asc_filename = r'./KISSME samples/SBE39/67761705.asc' 

# mcout_asc = read_sbd.parse_seabird_asc(asc_filename)

folder, file = os.path.split(asc_filename)
rr = wrap_sbd.SEABIRD_37_39_56(folder, file, model='SBE39')
rr.ds
# Out:
# asc file appears to be for an SBE39...
# temperature and pressure
# WARNING, COMPLIANCE CHECK NOT YET IMPLEMENTED.
# WARNING, COMPLIANCE CHECK NOT YET IMPLEMENTED.
# Setting default attributes of the class.
# Setting attribute "title" to "Measured data from a Seabird Data Logger"
# Setting attribute "source" to "Seabird Data Logger"
# Setting attribute "history" to ""
# Setting attribute "comment" to ""
# <xarray.Dataset>
# Dimensions:         (time: 224272)
# Coordinates:
#   * time            (time) datetime64[ns] 2017-04-01T01:00:00 ... 2017-05-09T...
# Data variables:
#     Temperature     (time) float64 21.4 21.4 21.4 21.4 ... 12.9 12.9 12.9 12.89
#     Pressure        (time) float64 -0.047 -0.047 -0.047 ... 240.2 240.2 240.2
#     qc_Temperature  (time) float64 -999.0 -999.0 -999.0 ... -999.0 -999.0 -999.0
#     qc_Pressure     (time) float64 -999.0 -999.0 -999.0 ... -999.0 -999.0 -999.0

# %%
# %matplotlib

# QAQC
rr.update_qc_flag('*', 
                  'time',
                  np.datetime64(datetime.datetime(2017, 1, 1)),
                  np.datetime64(datetime.datetime(2017, 4, 2, 5)),
                 1)

rr.get_qaqc_var('Temperature').plot(figsize=(15, 3))
plt.xlim(rr.ds.time[[0, -1]])
plt.grid()
plt.show()

rr.get_qaqc_var('Pressure').plot(figsize=(15, 3))
plt.xlim(rr.ds.time[[0, -1]])
plt.grid()
plt.ylim([235, 245])
plt.ylabel('seawater_pressure [dbar]')
# Out:
# Using matplotlib backend: Qt5Agg
# Blanking 6721 values.
# Blanking 6721 values.
# Text(0, 0.5, 'seawater_pressure [dbar]')

# %% [markdown]
# #### NOTES:
# The long names here are more like standard names, but need underscores.

# %% [markdown]
# # SBE56
# Unlike the seabird 39s, the ASCII reader does work for the 56s
#
# ### BUT THAT DATE IS WAY OFF

# %%
cnv_filename = r'./KISSME samples/SBE56/SBE056_00577_2017-05-24.cnv'

# mcout_cnv = read_sbd.parse_seabird_cnv(cnv_filename)

folder, file = os.path.split(cnv_filename)
rr = wrap_sbd.SEABIRD_37_39_56(folder, file, model='SBE56')
rr.ds
# Out:
# Reading CNV file:
# 	./KISSME samples/SBE56/SBE056_00577_2017-05-24.cnv...
# No lat/lon stored.
# WARNING, COMPLIANCE CHECK NOT YET IMPLEMENTED.
# Setting default attributes of the class.
# Setting attribute "title" to "Measured data from a Seabird Data Logger"
# Setting attribute "source" to "Seabird Data Logger"
# Setting attribute "history" to ""
# Setting attribute "comment" to ""
# <xarray.Dataset>
# Dimensions:         (time: 4787512)
# Coordinates:
#   * time            (time) datetime64[ns] 2034-07-01T02:00:00 ... 2034-08-23T...
# Data variables:
#     Temperature     (time) float64 34.2 34.21 34.21 34.22 ... 22.21 22.21 22.21
#     qc_Temperature  (time) float64 -999.0 -999.0 -999.0 ... -999.0 -999.0 -999.0

# %% [markdown]
# ### No QAQC here because the dates are silly.
# Need to fix this.

# %%
# %matplotlib inline
rr.ds.Temperature.plot(figsize=(15, 3))
plt.grid()

# %% [markdown]
# # SBE37
# Back to the CNVs for these ones.

# %%
# sbe37sm_08742_2017_05_23.cnv
cnv_filename = r'./KISSME samples/SBE37/sbe37sm_08742_2017_05_23.cnv'
os.path.exists(cnv_filename)

# mcout_cnv = read_sbd.parse_seabird_cnv(cnv_filename)

folder, file = os.path.split(cnv_filename)
rr = wrap_sbd.SEABIRD_37_39_56(folder, file, model='SBE37')
rr.ds
# Out:
# Reading CNV file:
# 	./KISSME samples/SBE37/sbe37sm_08742_2017_05_23.cnv...
# No lat/lon stored.
# WARNING, COMPLIANCE CHECK NOT YET IMPLEMENTED.
# WARNING, COMPLIANCE CHECK NOT YET IMPLEMENTED.
# WARNING, COMPLIANCE CHECK NOT YET IMPLEMENTED.
# Setting default attributes of the class.
# Setting attribute "title" to "Measured data from a Seabird Data Logger"
# Setting attribute "source" to "Seabird Data Logger"
# Setting attribute "history" to ""
# Setting attribute "comment" to ""
# <xarray.Dataset>
# Dimensions:          (time: 559239)
# Coordinates:
#   * time             (time) datetime64[ns] 2017-04-01T11:00:01 ... 2017-05-10...
# Data variables:
#     Conductivity     (time) float64 4.559 4.558 4.558 ... 4.441 4.441 4.443
#     Temperature      (time) float64 17.98 17.97 17.96 ... 16.83 16.86 16.87
#     Pressure         (time) float64 168.9 168.9 168.9 ... 170.8 170.8 170.8
#     qc_Temperature   (time) float64 -999.0 -999.0 -999.0 ... -999.0 -999.0
#     qc_Pressure      (time) float64 -999.0 -999.0 -999.0 ... -999.0 -999.0
#     qc_Conductivity  (time) float64 -999.0 -999.0 -999.0 ... -999.0 -999.0

# %%
# %matplotlib inline

rr.ds.Temperature.plot(figsize=(15, 3))
plt.xlim(rr.ds.time[[0, -1]])
plt.grid()
plt.show()

rr.ds.Pressure.plot(figsize=(15, 3))
plt.xlim(rr.ds.time[[0, -1]])
plt.ylabel('seawater_pressure [dbar]')
plt.grid()
plt.show()

rr.ds.Conductivity.plot(figsize=(15, 3))
plt.xlim(rr.ds.time[[0, -1]])
plt.grid()
# plt.ylim([235, 245])

# %% [markdown]
# # SBE37 CT
# And of course our special friend 4567 once agan requires special treatment.

# %%
4567

asc_filename = r'./KISSME samples/SBE37/SBE37SM-4567.asc'
os.path.exists(asc_filename)

# mcout_cnv = read_sbd.parse_seabird_asc(asc_filename)

folder, file = os.path.split(asc_filename)
rr = wrap_sbd.SEABIRD_37_39_56(folder, file, model='SBE37', method='asc')
rr.ds
# Out:
# asc file appears to be for an SBE37...
# WARNING, COMPLIANCE CHECK NOT YET IMPLEMENTED.
# WARNING, COMPLIANCE CHECK NOT YET IMPLEMENTED.
# Setting default attributes of the class.
# Setting attribute "title" to "Measured data from a Seabird Data Logger"
# Setting attribute "source" to "Seabird Data Logger"
# Setting attribute "history" to ""
# Setting attribute "comment" to ""
# <xarray.Dataset>
# Dimensions:          (time: 186530)
# Coordinates:
#   * time             (time) datetime64[ns] 2017-04-01T11:00:03 ... 2017-05-23...
# Data variables:
#     Temperature      (time) float64 13.23 13.23 13.23 ... 22.18 22.15 22.12
#     Conductivity     (time) float64 4.086 4.086 4.086 ... 0.01284 0.0129 0.013
#     qc_Temperature   (time) float64 -999.0 -999.0 -999.0 ... -999.0 -999.0
#     qc_Conductivity  (time) float64 -999.0 -999.0 -999.0 ... -999.0 -999.0

# %%
# %matplotlib inline
rr.update_qc_flag('*', 
                  'time',
                  np.datetime64(datetime.datetime(2017, 5, 22, 3)),
                  np.datetime64(datetime.datetime(2017, 6, 2)),
                  1)


plt.figure(figsize=(15, 3))
# rr.ds.Temperature.plot(label='Raw')
rr.get_qaqc_var('Temperature').plot(label='QAQC')
plt.xlim(rr.ds.time[[0, -1]])
plt.legend()
plt.grid()
plt.show()

plt.figure(figsize=(15, 3))
# rr.ds.Conductivity.plot(label='Raw')
rr.get_qaqc_var('Conductivity').plot(label='QAQC')
plt.xlim(rr.ds.time[[0, -1]])
plt.legend()
plt.grid()
plt.show()
# Out:
# Blanking 4130 values.
# Blanking 4130 values.

# %% [markdown]
# # Exporting to NetCDF
# Didn't go through this for every file but being xarray based this is cleary pretty simple.

# %%
pIMOS_export(rr, 'SBE37', '4567')

# %% [markdown]
# # Loop through all now using the spreadsheet

# %%
root = r'\\drive.irds.uwa.edu.au\ECM-OFFHUBP1-001\DATA\FIELD\KISSME2017\Original Folders\browse-basin-kissme'

csvfile = './KISSME2017_Instruments.csv'

# %% [markdown]
# ### Start with the ascs

# %%
os.path.exists(csvfile)

filetypes = ['SBE39 TP', 'SBE39 T', 'SBE39-ext T', 'SBE37 CT'];

instr_files = []
with open(csvfile) as f:
    for line in f.readlines():
        line = line.split(',')
        if line[9] in ['SBE39 TP', 'SBE39 T', 'SBE39-ext T']:
            print(line)
            
            asc_filename = os.path.join(root, line[8], line[7])
            print(asc_filename)
            
            sn = line[10]

            if os.path.exists(asc_filename):
                print('File exists')
            else:
                raise(Exception)
                
#             mcout_asc = read_sbd.parse_seabird_asc(asc_filename)
            
            folder, file = os.path.split(asc_filename)
            rr = wrap_sbd.SEABIRD_37_39_56(folder, file, model=line[9][0:5])
            
            pIMOS_export(rr, line[9][0:5], sn)
# Out:
# ['BRB200', '123.0459', '-14.2426', '-200', 'UTC', 'Browse Shelf', '-88.2', '39751705.asc', 'Data\\SBE39', 'SBE39 TP', '3975', '111.8', '111.8\n']
# \\drive.irds.uwa.edu.au\ECM-OFFHUBP1-001\DATA\FIELD\KISSME2017\Original Folders\browse-basin-kissme\Data\SBE39\39751705.asc
# File exists
# asc file appears to be for an SBE39...
# WARNING, COMPLIANCE CHECK NOT YET IMPLEMENTED.
# Setting default attributes of the class.
# Setting attribute "title" to "Measured data from a Seabird Data Logger"
# Setting attribute "source" to "Seabird Data Logger"
# Setting attribute "history" to ""
# Setting attribute "comment" to ""
# O:\Data\pIMOS\KISSME\SBE39
# ['BRB200', '123.0459', '-14.2426', '-200', 'UTC', 'Browse Shelf', '-70.2', '58391705.asc', 'Data\\SBE39', 'SBE39 TP', '5839', '129.8', '129.8\n']
# \\drive.irds.uwa.edu.au\ECM-OFFHUBP1-001\DATA\FIELD\KISSME2017\Original Folders\browse-basin-kissme\Data\SBE39\58391705.asc
# File exists
# asc file appears to be for an SBE39...
# temperature and pressure
# WARNING, COMPLIANCE CHECK NOT YET IMPLEMENTED.
# WARNING, COMPLIANCE CHECK NOT YET IMPLEMENTED.
# Setting default attributes of the class.
# Setting attribute "title" to "Measured data from a Seabird Data Logger"
# Setting attribute "source" to "Seabird Data Logger"
# Setting attribute "history" to ""
# Setting attribute "comment" to ""
# O:\Data\pIMOS\KISSME\SBE39
# ['BRB200', '123.0459', '-14.2426', '-200', 'UTC', 'Browse Shelf', '-60.2', '49271705.asc', 'Data\\SBE39', 'SBE39 TP', '4927', '139.8', '139.8\n']
# \\drive.irds.uwa.edu.au\ECM-OFFHUBP1-001\DATA\FIELD\KISSME2017\Original Folders\browse-basin-kissme\Data\SBE39\49271705.asc
# File exists
# asc file appears to be for an SBE39...
# temperature and pressure
# WARNING, COMPLIANCE CHECK NOT YET IMPLEMENTED.
# WARNING, COMPLIANCE CHECK NOT YET IMPLEMENTED.
# Setting default attributes of the class.
# Setting attribute "title" to "Measured data from a Seabird Data Logger"
# Setting attribute "source" to "Seabird Data Logger"
# Setting attribute "history" to ""
# Setting attribute "comment" to ""
# O:\Data\pIMOS\KISSME\SBE39
# ['BRB200', '123.0459', '-14.2426', '-200', 'UTC', 'Browse Shelf', '-50.2', '58551705.asc', 'Data\\SBE39', 'SBE39 TP', '5855', '149.8', '149.8\n']
# \\drive.irds.uwa.edu.au\ECM-OFFHUBP1-001\DATA\FIELD\KISSME2017\Original Folders\browse-basin-kissme\Data\SBE39\58551705.asc
# File exists
# asc file appears to be for an SBE39...
# temperature and pressure
# WARNING, COMPLIANCE CHECK NOT YET IMPLEMENTED.
# WARNING, COMPLIANCE CHECK NOT YET IMPLEMENTED.
# Setting default attributes of the class.
# Setting attribute "title" to "Measured data from a Seabird Data Logger"
# Setting attribute "source" to "Seabird Data Logger"
# Setting attribute "history" to ""
# Setting attribute "comment" to ""
# O:\Data\pIMOS\KISSME\SBE39
# ['NP250', '123.3535', '-13.7621', '-252', 'UTC', 'Browse Prelude', '-237.32', '67761705.asc', 'Data\\SBE39', 'SBE39 TP', '6776', '14.68', '14.68\n']
# \\drive.irds.uwa.edu.au\ECM-OFFHUBP1-001\DATA\FIELD\KISSME2017\Original Folders\browse-basin-kissme\Data\SBE39\67761705.asc
# File exists
# asc file appears to be for an SBE39...
# temperature and pressure
# WARNING, COMPLIANCE CHECK NOT YET IMPLEMENTED.
# WARNING, COMPLIANCE CHECK NOT YET IMPLEMENTED.
# Setting default attributes of the class.
# Setting attribute "title" to "Measured data from a Seabird Data Logger"
# Setting attribute "source" to "Seabird Data Logger"
# Setting attribute "history" to ""
# Setting attribute "comment" to ""
# O:\Data\pIMOS\KISSME\SBE39
# ['NP250', '123.3535', '-13.7621', '-252', 'UTC', 'Browse Prelude', '-222.32', '4455.asc', 'Data\\SBE39', 'SBE39 T', '4455', '29.68', '29.68\n']
# \\drive.irds.uwa.edu.au\ECM-OFFHUBP1-001\DATA\FIELD\KISSME2017\Original Folders\browse-basin-kissme\Data\SBE39\4455.asc
# File exists
# asc file appears to be for an SBE39...
# WARNING, COMPLIANCE CHECK NOT YET IMPLEMENTED.
# Setting default attributes of the class.
# Setting attribute "title" to "Measured data from a Seabird Data Logger"
# Setting attribute "source" to "Seabird Data Logger"
# Setting attribute "history" to ""
# Setting attribute "comment" to ""
# O:\Data\pIMOS\KISSME\SBE39
# ['NP250', '123.3535', '-13.7621', '-252', 'UTC', 'Browse Prelude', '-172.32', '4456.asc', 'Data\\SBE39', 'SBE39 T', '4456', '79.68', '79.68\n']
# \\drive.irds.uwa.edu.au\ECM-OFFHUBP1-001\DATA\FIELD\KISSME2017\Original Folders\browse-basin-kissme\Data\SBE39\4456.asc
# File exists
# asc file appears to be for an SBE39...
# WARNING, COMPLIANCE CHECK NOT YET IMPLEMENTED.
# Setting default attributes of the class.
# Setting attribute "title" to "Measured data from a Seabird Data Logger"
# Setting attribute "source" to "Seabird Data Logger"
# Setting attribute "history" to ""
# Setting attribute "comment" to ""
# O:\Data\pIMOS\KISSME\SBE39
# ['NP250', '123.3535', '-13.7621', '-252', 'UTC', 'Browse Prelude', '-142.2', '4452.asc', 'Data\\SBE39', 'SBE39 T', '4452', '109.8', '109.8\n']
# \\drive.irds.uwa.edu.au\ECM-OFFHUBP1-001\DATA\FIELD\KISSME2017\Original Folders\browse-basin-kissme\Data\SBE39\4452.asc
# File exists
# asc file appears to be for an SBE39...
# WARNING, COMPLIANCE CHECK NOT YET IMPLEMENTED.
# Setting default attributes of the class.
# Setting attribute "title" to "Measured data from a Seabird Data Logger"
# Setting attribute "source" to "Seabird Data Logger"
# Setting attribute "history" to ""
# Setting attribute "comment" to ""
# O:\Data\pIMOS\KISSME\SBE39
# ['NP250', '123.3535', '-13.7621', '-252', 'UTC', 'Browse Prelude', '-52.2', '6617.asc', 'Data\\SBE39', 'SBE39 TP', '6617', '199.8', '199.8\n']
# \\drive.irds.uwa.edu.au\ECM-OFFHUBP1-001\DATA\FIELD\KISSME2017\Original Folders\browse-basin-kissme\Data\SBE39\6617.asc
# File exists
# asc file appears to be for an SBE39...
# temperature and pressure
# WARNING, COMPLIANCE CHECK NOT YET IMPLEMENTED.
# WARNING, COMPLIANCE CHECK NOT YET IMPLEMENTED.
# Setting default attributes of the class.
# Setting attribute "title" to "Measured data from a Seabird Data Logger"
# Setting attribute "source" to "Seabird Data Logger"
# Setting attribute "history" to ""
# Setting attribute "comment" to ""
# O:\Data\pIMOS\KISSME\SBE39
# ['SP250', '123.3542', '-13.7669', '-252', 'UTC', 'Browse Prelude', '-236.6', '6527.asc', 'Data\\SBE39', 'SBE39 TP', '6527', '15.4', '15.4\n']
# \\drive.irds.uwa.edu.au\ECM-OFFHUBP1-001\DATA\FIELD\KISSME2017\Original Folders\browse-basin-kissme\Data\SBE39\6527.asc
# File exists
# asc file appears to be for an SBE39...
# temperature and pressure
# WARNING, COMPLIANCE CHECK NOT YET IMPLEMENTED.
# WARNING, COMPLIANCE CHECK NOT YET IMPLEMENTED.
# Setting default attributes of the class.
# Setting attribute "title" to "Measured data from a Seabird Data Logger"
# Setting attribute "source" to "Seabird Data Logger"
# Setting attribute "history" to ""
# Setting attribute "comment" to ""
# O:\Data\pIMOS\KISSME\SBE39
# ['SP250', '123.3542', '-13.7669', '-252', 'UTC', 'Browse Prelude', '-91.6', '6523.asc', 'Data\\SBE39', 'SBE39 TP', '6523', '160.4', '160.4\n']
# \\drive.irds.uwa.edu.au\ECM-OFFHUBP1-001\DATA\FIELD\KISSME2017\Original Folders\browse-basin-kissme\Data\SBE39\6523.asc
# File exists
# asc file appears to be for an SBE39...
# temperature and pressure
# WARNING, COMPLIANCE CHECK NOT YET IMPLEMENTED.
# WARNING, COMPLIANCE CHECK NOT YET IMPLEMENTED.
# Setting default attributes of the class.
# Setting attribute "title" to "Measured data from a Seabird Data Logger"
# Setting attribute "source" to "Seabird Data Logger"
# Setting attribute "history" to ""
# Setting attribute "comment" to ""
# O:\Data\pIMOS\KISSME\SBE39
# ['SP250', '123.3542', '-13.7669', '-252', 'UTC', 'Browse Prelude', '-21.8', '5082.asc', 'Data\\SBE39', 'SBE39 TP', '5082', '230.2', '230.2\n']
# \\drive.irds.uwa.edu.au\ECM-OFFHUBP1-001\DATA\FIELD\KISSME2017\Original Folders\browse-basin-kissme\Data\SBE39\5082.asc
# File exists
# asc file appears to be for an SBE39...
# temperature and pressure
# WARNING, COMPLIANCE CHECK NOT YET IMPLEMENTED.
# WARNING, COMPLIANCE CHECK NOT YET IMPLEMENTED.
# Setting default attributes of the class.
# Setting attribute "title" to "Measured data from a Seabird Data Logger"
# Setting attribute "source" to "Seabird Data Logger"
# Setting attribute "history" to ""
# Setting attribute "comment" to ""
# O:\Data\pIMOS\KISSME\SBE39
# ['SP250-Lander', '123.3539', '-13.7681', '-252', 'UTC', 'Browse Prelude', '-251.24', '4454.asc', 'Data\\SBE39', 'SBE39-ext T', '4454', '0.76', '0.76\n']
# \\drive.irds.uwa.edu.au\ECM-OFFHUBP1-001\DATA\FIELD\KISSME2017\Original Folders\browse-basin-kissme\Data\SBE39\4454.asc
# File exists
# asc file appears to be for an SBE39...
# WARNING, COMPLIANCE CHECK NOT YET IMPLEMENTED.
# Setting default attributes of the class.
# Setting attribute "title" to "Measured data from a Seabird Data Logger"
# Setting attribute "source" to "Seabird Data Logger"
# Setting attribute "history" to ""
# Setting attribute "comment" to ""
# O:\Data\pIMOS\KISSME\SBE39
# ['SP250-Lander', '123.3539', '-13.7681', '-252', 'UTC', 'Browse Prelude', '-250.87', '4453.asc', 'Data\\SBE39', 'SBE39-ext T', '4453', '1.13', '1.13\n']
# \\drive.irds.uwa.edu.au\ECM-OFFHUBP1-001\DATA\FIELD\KISSME2017\Original Folders\browse-basin-kissme\Data\SBE39\4453.asc
# File exists
# asc file appears to be for an SBE39...
# WARNING, COMPLIANCE CHECK NOT YET IMPLEMENTED.
# Setting default attributes of the class.
# Setting attribute "title" to "Measured data from a Seabird Data Logger"
# Setting attribute "source" to "Seabird Data Logger"
# Setting attribute "history" to ""
# Setting attribute "comment" to ""
# O:\Data\pIMOS\KISSME\SBE39
# ['SP250-Lander', '123.3539', '-13.7681', '-252', 'UTC', 'Browse Prelude', '-231.74', '6530.asc', 'Data\\SBE39', 'SBE39 TP', '6530', '20.26', '20.26\n']
# \\drive.irds.uwa.edu.au\ECM-OFFHUBP1-001\DATA\FIELD\KISSME2017\Original Folders\browse-basin-kissme\Data\SBE39\6530.asc
# File exists
# asc file appears to be for an SBE39...
# temperature and pressure
# WARNING, COMPLIANCE CHECK NOT YET IMPLEMENTED.
# WARNING, COMPLIANCE CHECK NOT YET IMPLEMENTED.
# Setting default attributes of the class.
# Setting attribute "title" to "Measured data from a Seabird Data Logger"
# Setting attribute "source" to "Seabird Data Logger"
# Setting attribute "history" to ""
# Setting attribute "comment" to ""
# O:\Data\pIMOS\KISSME\SBE39
# ['WP250', '123.349', '-13.7659', '-252', 'UTC', 'Browse Prelude', '-247.08', '3719.asc', 'Data\\SBE39', 'SBE39 T', '3719', '4.92', '4.92\n']
# \\drive.irds.uwa.edu.au\ECM-OFFHUBP1-001\DATA\FIELD\KISSME2017\Original Folders\browse-basin-kissme\Data\SBE39\3719.asc
# File exists
# asc file appears to be for an SBE39...
# WARNING, COMPLIANCE CHECK NOT YET IMPLEMENTED.
# Setting default attributes of the class.
# Setting attribute "title" to "Measured data from a Seabird Data Logger"
# Setting attribute "source" to "Seabird Data Logger"
# Setting attribute "history" to ""
# Setting attribute "comment" to ""
# O:\Data\pIMOS\KISSME\SBE39
# ['WP250', '123.349', '-13.7659', '-252', 'UTC', 'Browse Prelude', '-242.08', '3721.asc', 'Data\\SBE39', 'SBE39 T', '3721', '9.92', '9.92\n']
# \\drive.irds.uwa.edu.au\ECM-OFFHUBP1-001\DATA\FIELD\KISSME2017\Original Folders\browse-basin-kissme\Data\SBE39\3721.asc
# File exists
# asc file appears to be for an SBE39...
# WARNING, COMPLIANCE CHECK NOT YET IMPLEMENTED.
# Setting default attributes of the class.
# Setting attribute "title" to "Measured data from a Seabird Data Logger"
# Setting attribute "source" to "Seabird Data Logger"
# Setting attribute "history" to ""
# Setting attribute "comment" to ""
# O:\Data\pIMOS\KISSME\SBE39
# ['WP250', '123.349', '-13.7659', '-252', 'UTC', 'Browse Prelude', '-237.08', '6529.asc', 'Data\\SBE39', 'SBE39 TP', '6529', '14.92', '14.92\n']
# \\drive.irds.uwa.edu.au\ECM-OFFHUBP1-001\DATA\FIELD\KISSME2017\Original Folders\browse-basin-kissme\Data\SBE39\6529.asc
# File exists
# asc file appears to be for an SBE39...
# temperature and pressure
# WARNING, COMPLIANCE CHECK NOT YET IMPLEMENTED.
# WARNING, COMPLIANCE CHECK NOT YET IMPLEMENTED.
# Setting default attributes of the class.
# Setting attribute "title" to "Measured data from a Seabird Data Logger"
# Setting attribute "source" to "Seabird Data Logger"
# Setting attribute "history" to ""
# Setting attribute "comment" to ""
# O:\Data\pIMOS\KISSME\SBE39
# ['WP250', '123.349', '-13.7659', '-252', 'UTC', 'Browse Prelude', '-232.08', '3722.asc', 'Data\\SBE39', 'SBE39 T', '3722', '19.92', '19.92\n']
# \\drive.irds.uwa.edu.au\ECM-OFFHUBP1-001\DATA\FIELD\KISSME2017\Original Folders\browse-basin-kissme\Data\SBE39\3722.asc
# File exists
# asc file appears to be for an SBE39...
# WARNING, COMPLIANCE CHECK NOT YET IMPLEMENTED.
# Setting default attributes of the class.
# Setting attribute "title" to "Measured data from a Seabird Data Logger"
# Setting attribute "source" to "Seabird Data Logger"
# Setting attribute "history" to ""
# Setting attribute "comment" to ""
# O:\Data\pIMOS\KISSME\SBE39
# ['WP250', '123.349', '-13.7659', '-252', 'UTC', 'Browse Prelude', '-222.08', '3723.asc', 'Data\\SBE39', 'SBE39 T', '3723', '29.92', '29.92\n']
# \\drive.irds.uwa.edu.au\ECM-OFFHUBP1-001\DATA\FIELD\KISSME2017\Original Folders\browse-basin-kissme\Data\SBE39\3723.asc
# File exists
# asc file appears to be for an SBE39...
# WARNING, COMPLIANCE CHECK NOT YET IMPLEMENTED.
# Setting default attributes of the class.
# Setting attribute "title" to "Measured data from a Seabird Data Logger"
# Setting attribute "source" to "Seabird Data Logger"
# Setting attribute "history" to ""
# Setting attribute "comment" to ""
# O:\Data\pIMOS\KISSME\SBE39
# ['WP250', '123.349', '-13.7659', '-252', 'UTC', 'Browse Prelude', '-212.08', '3724.asc', 'Data\\SBE39', 'SBE39 T', '3724', '39.92', '39.92\n']
# \\drive.irds.uwa.edu.au\ECM-OFFHUBP1-001\DATA\FIELD\KISSME2017\Original Folders\browse-basin-kissme\Data\SBE39\3724.asc
# File exists
# asc file appears to be for an SBE39...
# WARNING, COMPLIANCE CHECK NOT YET IMPLEMENTED.
# Setting default attributes of the class.
# Setting attribute "title" to "Measured data from a Seabird Data Logger"
# Setting attribute "source" to "Seabird Data Logger"
# Setting attribute "history" to ""
# Setting attribute "comment" to ""
# O:\Data\pIMOS\KISSME\SBE39
# ['WP250', '123.349', '-13.7659', '-252', 'UTC', 'Browse Prelude', '-202.08', '3725.asc', 'Data\\SBE39', 'SBE39 T', '3725', '49.92', '49.92\n']
# \\drive.irds.uwa.edu.au\ECM-OFFHUBP1-001\DATA\FIELD\KISSME2017\Original Folders\browse-basin-kissme\Data\SBE39\3725.asc
# File exists
# asc file appears to be for an SBE39...
# WARNING, COMPLIANCE CHECK NOT YET IMPLEMENTED.
# Setting default attributes of the class.
# Setting attribute "title" to "Measured data from a Seabird Data Logger"
# Setting attribute "source" to "Seabird Data Logger"
# Setting attribute "history" to ""
# Setting attribute "comment" to ""
# O:\Data\pIMOS\KISSME\SBE39
# ['WP250', '123.349', '-13.7659', '-252', 'UTC', 'Browse Prelude', '-192.08', '3726.asc', 'Data\\SBE39', 'SBE39 T', '3726', '59.92', '59.92\n']
# \\drive.irds.uwa.edu.au\ECM-OFFHUBP1-001\DATA\FIELD\KISSME2017\Original Folders\browse-basin-kissme\Data\SBE39\3726.asc
# File exists
# asc file appears to be for an SBE39...
# WARNING, COMPLIANCE CHECK NOT YET IMPLEMENTED.
# Setting default attributes of the class.
# Setting attribute "title" to "Measured data from a Seabird Data Logger"
# Setting attribute "source" to "Seabird Data Logger"
# Setting attribute "history" to ""
# Setting attribute "comment" to ""
# O:\Data\pIMOS\KISSME\SBE39
# ['WP250', '123.349', '-13.7659', '-252', 'UTC', 'Browse Prelude', '-182.08', '3727.asc', 'Data\\SBE39', 'SBE39 T', '3727', '69.92', '69.92\n']
# \\drive.irds.uwa.edu.au\ECM-OFFHUBP1-001\DATA\FIELD\KISSME2017\Original Folders\browse-basin-kissme\Data\SBE39\3727.asc
# File exists
# asc file appears to be for an SBE39...
# WARNING, COMPLIANCE CHECK NOT YET IMPLEMENTED.
# Setting default attributes of the class.
# Setting attribute "title" to "Measured data from a Seabird Data Logger"
# Setting attribute "source" to "Seabird Data Logger"
# Setting attribute "history" to ""
# Setting attribute "comment" to ""
# O:\Data\pIMOS\KISSME\SBE39
# ['WP250', '123.349', '-13.7659', '-252', 'UTC', 'Browse Prelude', '-172.08', '3728.asc', 'Data\\SBE39', 'SBE39 T', '3728', '79.92', '79.92\n']
# \\drive.irds.uwa.edu.au\ECM-OFFHUBP1-001\DATA\FIELD\KISSME2017\Original Folders\browse-basin-kissme\Data\SBE39\3728.asc
# File exists
# asc file appears to be for an SBE39...
# WARNING, COMPLIANCE CHECK NOT YET IMPLEMENTED.
# Setting default attributes of the class.
# Setting attribute "title" to "Measured data from a Seabird Data Logger"
# Setting attribute "source" to "Seabird Data Logger"
# Setting attribute "history" to ""
# Setting attribute "comment" to ""
# O:\Data\pIMOS\KISSME\SBE39
# ['WP250', '123.349', '-13.7659', '-252', 'UTC', 'Browse Prelude', '-152.01', '3729.asc', 'Data\\SBE39', 'SBE39 T', '3729', '99.99', '99.99\n']
# \\drive.irds.uwa.edu.au\ECM-OFFHUBP1-001\DATA\FIELD\KISSME2017\Original Folders\browse-basin-kissme\Data\SBE39\3729.asc
# File exists
# asc file appears to be for an SBE39...
# WARNING, COMPLIANCE CHECK NOT YET IMPLEMENTED.
# Setting default attributes of the class.
# Setting attribute "title" to "Measured data from a Seabird Data Logger"
# Setting attribute "source" to "Seabird Data Logger"
# Setting attribute "history" to ""
# Setting attribute "comment" to ""
# O:\Data\pIMOS\KISSME\SBE39
# ['WP250', '123.349', '-13.7659', '-252', 'UTC', 'Browse Prelude', '-142.01', '3730.asc', 'Data\\SBE39', 'SBE39 T', '3730', '109.99', '109.99\n']
# \\drive.irds.uwa.edu.au\ECM-OFFHUBP1-001\DATA\FIELD\KISSME2017\Original Folders\browse-basin-kissme\Data\SBE39\3730.asc
# File exists
# asc file appears to be for an SBE39...
# WARNING, COMPLIANCE CHECK NOT YET IMPLEMENTED.
# Setting default attributes of the class.
# Setting attribute "title" to "Measured data from a Seabird Data Logger"
# Setting attribute "source" to "Seabird Data Logger"
# Setting attribute "history" to ""
# Setting attribute "comment" to ""
# O:\Data\pIMOS\KISSME\SBE39
# ['WP250', '123.349', '-13.7659', '-252', 'UTC', 'Browse Prelude', '-132.03', '3731.asc', 'Data\\SBE39', 'SBE39 T', '3731', '119.97', '119.97\n']
# \\drive.irds.uwa.edu.au\ECM-OFFHUBP1-001\DATA\FIELD\KISSME2017\Original Folders\browse-basin-kissme\Data\SBE39\3731.asc
# File exists
# asc file appears to be for an SBE39...
# WARNING, COMPLIANCE CHECK NOT YET IMPLEMENTED.
# Setting default attributes of the class.
# Setting attribute "title" to "Measured data from a Seabird Data Logger"
# Setting attribute "source" to "Seabird Data Logger"
# Setting attribute "history" to ""
# Setting attribute "comment" to ""
# O:\Data\pIMOS\KISSME\SBE39
# ['WP250', '123.349', '-13.7659', '-252', 'UTC', 'Browse Prelude', '-52.03', '3754.asc', 'Data\\SBE39', 'SBE39 T', '3754', '199.97', '199.97\n']
# \\drive.irds.uwa.edu.au\ECM-OFFHUBP1-001\DATA\FIELD\KISSME2017\Original Folders\browse-basin-kissme\Data\SBE39\3754.asc
# File exists
# asc file appears to be for an SBE39...
# WARNING, COMPLIANCE CHECK NOT YET IMPLEMENTED.
# Setting default attributes of the class.
# Setting attribute "title" to "Measured data from a Seabird Data Logger"
# Setting attribute "source" to "Seabird Data Logger"
# Setting attribute "history" to ""
# Setting attribute "comment" to ""
# O:\Data\pIMOS\KISSME\SBE39
# ['WP250', '123.349', '-13.7659', '-252', 'UTC', 'Browse Prelude', '-42.03', '3798.asc', 'Data\\SBE39', 'SBE39 T', '3798', '209.97', '209.97\n']
# \\drive.irds.uwa.edu.au\ECM-OFFHUBP1-001\DATA\FIELD\KISSME2017\Original Folders\browse-basin-kissme\Data\SBE39\3798.asc
# File exists
# asc file appears to be for an SBE39...
# WARNING, COMPLIANCE CHECK NOT YET IMPLEMENTED.
# Setting default attributes of the class.
# Setting attribute "title" to "Measured data from a Seabird Data Logger"
# Setting attribute "source" to "Seabird Data Logger"
# Setting attribute "history" to ""
# Setting attribute "comment" to ""
# O:\Data\pIMOS\KISSME\SBE39
# ['WP250', '123.349', '-13.7659', '-252', 'UTC', 'Browse Prelude', '-22', '3799.asc', 'Data\\SBE39', 'SBE39 T', '3799', '230', '219.97\n']
# \\drive.irds.uwa.edu.au\ECM-OFFHUBP1-001\DATA\FIELD\KISSME2017\Original Folders\browse-basin-kissme\Data\SBE39\3799.asc
# File exists
# asc file appears to be for an SBE39...
# WARNING, COMPLIANCE CHECK NOT YET IMPLEMENTED.
# Setting default attributes of the class.
# Setting attribute "title" to "Measured data from a Seabird Data Logger"
# Setting attribute "source" to "Seabird Data Logger"
# Setting attribute "history" to ""
# Setting attribute "comment" to ""
# O:\Data\pIMOS\KISSME\SBE39
# ['WP250', '123.349', '-13.7659', '-252', 'UTC', 'Browse Prelude', '-62', '3753.asc', 'Data\\SBE39', 'SBE39 T', '3753', '190', '189.97\n']
# \\drive.irds.uwa.edu.au\ECM-OFFHUBP1-001\DATA\FIELD\KISSME2017\Original Folders\browse-basin-kissme\Data\SBE39\3753.asc
# File exists
# asc file appears to be for an SBE39...
# WARNING, COMPLIANCE CHECK NOT YET IMPLEMENTED.
# Setting default attributes of the class.
# Setting attribute "title" to "Measured data from a Seabird Data Logger"
# Setting attribute "source" to "Seabird Data Logger"
# Setting attribute "history" to ""
# Setting attribute "comment" to ""
# O:\Data\pIMOS\KISSME\SBE39
# ['WP250', '123.349', '-13.7659', '-252', 'UTC', 'Browse Prelude', '-62', '3752.asc', 'Data\\SBE39', 'SBE39 T', '3752', '190', '179.97\n']
# \\drive.irds.uwa.edu.au\ECM-OFFHUBP1-001\DATA\FIELD\KISSME2017\Original Folders\browse-basin-kissme\Data\SBE39\3752.asc
# File exists
# asc file appears to be for an SBE39...
# WARNING, COMPLIANCE CHECK NOT YET IMPLEMENTED.
# Setting default attributes of the class.
# Setting attribute "title" to "Measured data from a Seabird Data Logger"
# Setting attribute "source" to "Seabird Data Logger"
# Setting attribute "history" to ""
# Setting attribute "comment" to ""
# O:\Data\pIMOS\KISSME\SBE39
# ['WP250', '123.349', '-13.7659', '-252', 'UTC', 'Browse Prelude', '-62', '3750.asc', 'Data\\SBE39', 'SBE39 T', '3750', '190', '169.97\n']
# \\drive.irds.uwa.edu.au\ECM-OFFHUBP1-001\DATA\FIELD\KISSME2017\Original Folders\browse-basin-kissme\Data\SBE39\3750.asc
# File exists
# asc file appears to be for an SBE39...
# WARNING, COMPLIANCE CHECK NOT YET IMPLEMENTED.
# Setting default attributes of the class.
# Setting attribute "title" to "Measured data from a Seabird Data Logger"
# Setting attribute "source" to "Seabird Data Logger"
# Setting attribute "history" to ""
# Setting attribute "comment" to ""
# O:\Data\pIMOS\KISSME\SBE39
# ['WP250', '123.349', '-13.7659', '-252', 'UTC', 'Browse Prelude', '-62', '3749.asc', 'Data\\SBE39', 'SBE39 T', '3749', '190', '149.97\n']
# \\drive.irds.uwa.edu.au\ECM-OFFHUBP1-001\DATA\FIELD\KISSME2017\Original Folders\browse-basin-kissme\Data\SBE39\3749.asc
# File exists
# asc file appears to be for an SBE39...
# WARNING, COMPLIANCE CHECK NOT YET IMPLEMENTED.
# Setting default attributes of the class.
# Setting attribute "title" to "Measured data from a Seabird Data Logger"
# Setting attribute "source" to "Seabird Data Logger"
# Setting attribute "history" to ""
# Setting attribute "comment" to ""
# O:\Data\pIMOS\KISSME\SBE39
# ['WP250', '123.349', '-13.7659', '-252', 'UTC', 'Browse Prelude', '-62', '3747.asc', 'Data\\SBE39', 'SBE39 T', '3747', '190', '139.97\n']
# \\drive.irds.uwa.edu.au\ECM-OFFHUBP1-001\DATA\FIELD\KISSME2017\Original Folders\browse-basin-kissme\Data\SBE39\3747.asc
# File exists
# asc file appears to be for an SBE39...
# WARNING, COMPLIANCE CHECK NOT YET IMPLEMENTED.
# Setting default attributes of the class.
# Setting attribute "title" to "Measured data from a Seabird Data Logger"
# Setting attribute "source" to "Seabird Data Logger"
# Setting attribute "history" to ""
# Setting attribute "comment" to ""
# O:\Data\pIMOS\KISSME\SBE39
# ['WP250', '123.349', '-13.7659', '-252', 'UTC', 'Browse Prelude', '-22', '6526.asc', 'Data\\SBE39', 'SBE39 TP', '6526', '230', '229.97\n']
# \\drive.irds.uwa.edu.au\ECM-OFFHUBP1-001\DATA\FIELD\KISSME2017\Original Folders\browse-basin-kissme\Data\SBE39\6526.asc
# File exists
# asc file appears to be for an SBE39...
# temperature and pressure
# WARNING, COMPLIANCE CHECK NOT YET IMPLEMENTED.
# WARNING, COMPLIANCE CHECK NOT YET IMPLEMENTED.
# Setting default attributes of the class.
# Setting attribute "title" to "Measured data from a Seabird Data Logger"
# Setting attribute "source" to "Seabird Data Logger"
# Setting attribute "history" to ""
# Setting attribute "comment" to ""
# O:\Data\pIMOS\KISSME\SBE39

# %% [markdown]
# ### Now the cnvs

# %%
os.path.exists(csvfile)

filetypes = ['SBE56 T', 'SBE37 CTD', 'SBE37 CT'];
filetypes = ['SBE56 T', 'SBE37 CTD'];

instr_files = []
with open(csvfile) as f:
    for line in f.readlines():
        line = line.split(',')
        if line[9] in filetypes:
            print(line)
            
            asc_filename = os.path.join(root, line[8], line[7])
            print(asc_filename)
            
            if os.path.exists(asc_filename):
                print('File exists')
            else:
                raise(Exception)
                
            mcout_asc = read_sbd.parse_seabird_cnv(asc_filename)
            folder, file = os.path.split(asc_filename)
            rr = wrap_sbd.SEABIRD_37_39_56(folder, file, model=line[9][0:5])
            
            sn = line[10]
            pIMOS_export(rr, line[9][0:5], sn)
# Out:
# ['BRB200', '123.0459', '-14.2426', '-200', 'UTC', 'Browse Shelf', '-175.2', 'sbe37sm_08742_2017_05_23.cnv', 'Data\\SBE37', 'SBE37 CTD', '8742', '24.8', '24.8\n']
# \\drive.irds.uwa.edu.au\ECM-OFFHUBP1-001\DATA\FIELD\KISSME2017\Original Folders\browse-basin-kissme\Data\SBE37\sbe37sm_08742_2017_05_23.cnv
# File exists
# Reading CNV file:
# 	\\drive.irds.uwa.edu.au\ECM-OFFHUBP1-001\DATA\FIELD\KISSME2017\Original Folders\browse-basin-kissme\Data\SBE37\sbe37sm_08742_2017_05_23.cnv...
# No lat/lon stored.
# Reading CNV file:
# 	\\drive.irds.uwa.edu.au\ECM-OFFHUBP1-001\DATA\FIELD\KISSME2017\Original Folders\browse-basin-kissme\Data\SB