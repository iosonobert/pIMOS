# %%
import pandas as pd
import datetime
import xarray as xr
from zutils.xr import xrwrap
import matplotlib.pyplot as plt
import importlib
import numpy as np

# %%
fn = r'X:\DATA\PROJECTS\19WAU-0027_Eramurra Salt Project\2. Metocean & Water Quality/'
# fn += r'2. Metocean\4_Analysis\07 Period_7\SIC02\wetlab_SIC02_11062021/SIC02_FLNTU_1722_11062021.raw'
fn += r'2. Metocean\4_Analysis\07 Period_7\SIC02\wetlab_SIC02_11062021/SIC02_FLNTU_1722_11062021.raw'

df = pd.read_csv(fn, skiprows=1, delim_whitespace=True, names=['date', 'time', 'c1', 'c2', 'c3', 'c4', 'c5', 'c6', 'c7'])

df.time = df.date + ' ' + df.time
df = df.drop(['date'], axis=1)
df.time = pd.to_datetime(df.time,dayfirst = True, format = "%m/%d/%y %H:%M:%S")

df.drop(df.tail(1).index,inplace=True) 

ds = df.set_index('time').to_xarray()

ds = ds.sel({'time': slice(None, datetime.datetime(2021, 3, 22, 11))})

SF=0.0061
DC=51

ds['turbidity'] = xr.DataArray(SF*(ds.c4.values-DC), dims={'time':ds.time})
ds['turbidity'].attrs['units'] ='NTU'

plt.figure(figsize=(20, 4))
ds['turbidity'].plot()
plt.grid()

# %%
class WETLABS_NTU(xrwrap):

    def __init__(self, infile, driver='pandas', attributes={}):
        
        self.parse_infile(infile)
        
        self.driver_name = driver

        spam_loader = importlib.find_loader(driver)
        if spam_loader is None:
            raise(Exception('No module found for driver {}.'.format(driver)))

        self.driver = importlib.import_module(driver)

        if driver.lower() in ['pandas']: 
            self.read_raw_pd(attributes=attributes)
        elif driver.lower() == 'xarray':
            self.load(self.folder, self.file_)
        else:
            raise(Exception('{} is not a valid driver'.format(driver)))

        self.update_global_attrs()
    
    def update_global_attrs(self):
        """
        Each wrapper should overload this function
        """

        # CF Compliance
        print('Updating attributes function of the class.')
        self.update_attribute('title', 'Measured data from a TDRI ADCP read from .PD0 files')
        self.update_attribute('institution', 'UWA')
        self.update_attribute('source', 'TDRI ADCP [Workhorse, Quartermaster, or Longranger]')
        self.update_attribute('history', '')
        self.update_attribute('references', '')
        self.update_attribute('comment', '')
        
    def read_raw_pd(self, attributes):
        
        df = pd.read_csv(self.fullpath, skiprows=1, delim_whitespace=True, names=['date', 'time', 'c1', 'c2', 'c3', 'c4', 'c5', 'c6', 'c7'])

        df.time = df.date + ' ' + df.time
        df = df.drop(['date'], axis=1)
        df.time = pd.to_datetime(df.time,dayfirst = True, format = "%m/%d/%y %H:%M:%S")

        df.drop(df.tail(1).index,inplace=True) 

        ds = df.set_index('time').to_xarray()

        self.ds = ds
        
    def _calibrate_turbidity_from_dev(self, device_file):
        """
        Calibrate turbidity using device file. Read the SF, DC and column.
        """
        
        raise(Exception("Haven't coded this"))
        
    def _calibrate_turbidity(self, SF, DC, column):
        """
        Calibrate turbidity
        """

        ds = self.ds
        
        if not type(column) in [int]:
            raise(Eception("Column number must be an integer"))
            
        column_name = 'c{:0}'.format(column)
        if not column_name in ds.data_vars.keys():
            raise(Eception("Invalid column number"))
            
        print(column_name)
        
        ds['turbidity'] = xr.DataArray(SF*(ds[column_name].values-DC), dims={'time':ds.time})
        ds['turbidity'].attrs['units'] ='NTU'
        ds['turbidity'].attrs['long_name'] ='seawater_turbidity'
        ds['turbidity'].attrs['standard_name'] ='seawater_turbidity'
        
    def _calc_burst_mean(self, parameter='turbidity', cutoff=None):
        
        """
        cutoff: the time in seconds that distinguishes bursts
        """
        
        ds = self.ds
        
        if cutoff is None: 
            cutoff = np.mean(np.diff(ds['time']))/10
        else:
            cutoff = np.timedelta64(cutoff, 's')
        print('Splitting bursts usinf a cutoff of {}'.format(cutoff))

        dt = np.diff(ds['time'])
        burst_ind = np.where(np.diff(ds['time'].values)>cutoff)[0]+1

        burst_ind = np.concatenate((np.array([0]), burst_ind, np.array([len(ds['time'].values)])))

        s = burst_ind.shape

        burst_mean = np.zeros((s[0]-1,))
        burst_median = burst_mean.copy()
        burst_median_mad = burst_mean.copy()
        burst_std = burst_mean.copy()
        burst_mean_time = burst_mean.copy().tolist()

        for i in np.arange(0, len(burst_mean)):
            ind = np.arange(burst_ind[i], burst_ind[i+1])

            burst_mean_time[i]   = np.mean(ds['time'][ind]).values
            burst_mean[i]   = np.mean(ds[parameter][ind])
            burst_median[i] = np.median(ds[parameter][ind])
            burst_std[i] = np.var(ds[parameter][ind])**(1/2)
            burst_median_mad[i] = np.max(np.abs(ds[parameter][ind]-burst_median[i])) # Max Absolute Deviation

            pass

        burst_mean_time = np.array(burst_mean_time)

        name='burst_mean_'+parameter
        ds[name] = xr.DataArray( burst_mean,\
            dims=('burst_time'),\
            name=name,\
            attrs = ds[parameter].attrs,\
            coords = {'burst_time': burst_mean_time}
        )

        name='burst_median_'+parameter
        ds[name] = xr.DataArray( burst_median,\
            dims=('burst_time'),\
            name=name,\
            attrs = ds[parameter].attrs,\
            coords = {'burst_time': burst_mean_time}
        )

        name='burst_std_'+parameter
        ds[name] = xr.DataArray( burst_std,\
            dims=('burst_time'),\
            name=name,\
            attrs = ds[parameter].attrs,\
            coords = {'burst_time': burst_mean_time}
        )
        
        name='burst_median_mad_'+parameter
        ds[name] = xr.DataArray( burst_median_mad,\
            dims=('burst_time'),\
            name=name,\
            attrs = ds[parameter].attrs,\
            coords = {'burst_time': burst_mean_time}
        )


wetlab = WETLABS_NTU(fn)
wetlab.ds
# Out:
# Im a string
# <ipython-input-72-7f9910b64425>:9: DeprecationWarning: Deprecated since Python 3.4. Use importlib.util.find_spec() instead.
#   spam_loader = importlib.find_loader(driver)
# Updating attributes function of the class.
# Setting attribute "title" to "Measured data from a TDRI ADCP read from .PD0 files"
# Setting attribute "institution" to "UWA"
# Setting attribute "source" to "TDRI ADCP [Workhorse, Quartermaster, or Longranger]"
# Setting attribute "history" to ""
# Setting attribute "references" to ""
# Setting attribute "comment" to ""
# <xarray.Dataset>
# Dimensions:  (time: 31593)
# Coordinates:
#   * time     (time) datetime64[ns] 2021-01-14T18:55:36 ... 2021-06-11T18:52:59
# Data variables:
#     c1       (time) float64 695.0 695.0 695.0 695.0 ... 695.0 695.0 695.0 695.0
#     c2       (time) float64 56.0 57.0 56.0 56.0 56.0 ... 45.0 45.0 51.0 50.0
#     c3       (time) float64 700.0 700.0 700.0 700.0 ... 700.0 700.0 700.0 700.0
# ...

# %% [markdown]
# ## Note
# The attributes in the above are blank. All the CF stuff is a property of the Wetlabs Object, and only pushed to the ds on exporting to xarray.

# %% [markdown]
# ## Calibrate
# Unfortunately I haven't coded the device file reader, so this is a 'manual' operation for now.

# %%
SF=0.0061
DC=51

wetlab._calibrate_turbidity(SF, DC, 4)
# Out:
# c4

# %%
plt.figure(figsize=(20, 4))
wetlab.ds['turbidity'].plot()
plt.grid()

# %% [markdown]
# ## Burst Median
# Need to implement some code for this

# %%
dt = np.diff(ds['time'])

plt.figure(figsize=(20, 4))
plt.plot(dt, '.')
plt.grid()
plt.ylabel('Time gap [ns]')
plt.yscale('log')

# %%
wetlab._calc_burst_mean()
ds = wetlab.ds
ds
# Out:
# Splitting bursts usinf a cutoff of 40475572929 nanoseconds
# <xarray.Dataset>
# Dimensions:                     (burst_time: 3162, time: 31593)
# Coordinates:
#   * time                        (time) datetime64[ns] 2021-01-14T18:55:36 ......
#   * burst_time                  (burst_time) datetime64[ns] 2021-01-14T18:55:...
# Data variables:
#     c1                          (time) float64 695.0 695.0 695.0 ... 695.0 695.0
#     c2                          (time) float64 56.0 57.0 56.0 ... 45.0 51.0 50.0
#     c3                          (time) float64 700.0 700.0 700.0 ... 700.0 700.0
#     c4                          (time) float64 78.0 76.0 78.0 ... 663.0 664.0
#     c5                          (time) float64 521.0 521.0 521.0 ... 527.0 526.0
#     c6                          (time) float64 1.638e+04 1.638e+04 ... 1.638e+04
#     c7                          (time) float64 nan nan nan nan ... nan nan nan
#     turbidity                   (time) float64 0.1647 0.1525 ... 3.733 3.739
# ...

# %%
# %matplotlib inline
plt.figure(figsize=(20, 4))
ds['turbidity'].plot(label='Raw')
plt.plot(ds['time'], ds['turbidity'], 'b.', label='Raw')
plt.plot(ds['burst_time'], ds['burst_mean_turbidity'], '.', label='Burst mean')
plt.plot(ds['burst_time'], ds['burst_median_turbidity'], '+', label='Burst median')
plt.grid()
plt.legend()

# %% [markdown]
# ## Goring Nikora (2002)
# This is implemented in turbo_tools, implement it here also.

# %%
from turbo_tools.classes.misc import  binner
from turbo_tools.turbo import clean
from turbo_tools.utils.misc import  fillgaps

def clean_despike(self, block_length_seconds=360000, nit = 10, block=None):
    """
    Run the despike algorithm.

    """

    n = len(self.ds.time)
    fs = 1e9/np.median(np.diff(wetlab.ds.burst_time)).item()
    
    despike_binner = binner(n, fs, block_length_seconds, block_length_seconds)

    turb = self.ds.burst_median_turbidity.values.copy()

    sn = np.sum(np.sum(np.isnan(turb)))
    print('Nans in the intial data set: {}'.format(sn)) 

    if type(block)==type(None):
        # Do all blocks with limited output
        rng = np.arange(0, despike_binner.blocks)
        verbose = False
    else:
        # Do the requested block with full verbose output
        rng = np.arange(block, block+1)
        verbose = True

    for bb in rng:

        print('Despiking {}'.format(bb))

        ind = despike_binner.get_block_index(bb)

        for ii in np.arange(nit):

            try:
                x = turb[ind]

                X = clean.despike(x, fs, intensity = 1, interp_opt='linear', n_it=10, verbose=verbose)

                if verbose:
                    sn = np.sum(np.sum(np.isnan(X)))
                    print('Nans in the cleaned block: {}'.format(sn)) 

                turb[ind] = X

                turb = fillgaps(turb) # Fill gaps again - the previous filler won't get end gaps [probably shouldn't remove end gaps but that's another story]. 

                if verbose:
                    sn = np.sum(np.sum(np.isnan(vel_xyz)))
                    print('Nans in the final data set: {}'.format(sn))
            except:
                print('THIS IS NO GOOD')
                pass
            
    return turb
            
cl = clean_despike(wetlab)
# Out:
# Nans in the intial data set: 0
# Despiking 0
# Despiking 1
# Despiking 2
# Despiking 3
# Despiking 4
# Despiking 5
# Despiking 6
# Despiking 7
# Despiking 8
# Despiking 9
# Despiking 10
# Despiking 11
# Despiking 12
# Despiking 13
# Despiking 14
# Despiking 15
# Despiking 16
# THIS IS NO GOOD
# THIS IS NO GOOD
# THIS IS NO GOOD
# THIS IS NO GOOD
# THIS IS NO GOOD
# THIS IS NO GOOD
# THIS IS NO GOOD
# THIS IS NO GOOD
# THIS IS NO GOOD
# THIS IS NO GOOD
# Despiking 17
# THIS IS NO GOOD
# THIS IS NO GOOD
# THIS IS NO GOOD
# THIS IS NO GOOD
# THIS IS NO GOOD
# THIS IS NO GOOD
# THIS IS NO GOOD
# THIS IS NO GOOD
# THIS IS NO GOOD
# THIS IS NO GOOD
# Despiking 18
# THIS IS NO GOOD
# THIS IS NO GOOD
# THIS IS NO GOOD
# THIS IS NO GOOD
# THIS IS NO GOOD
# THIS IS NO GOOD
# THIS IS NO GOOD
# THIS IS NO GOOD
# THIS IS NO GOOD
# THIS IS NO GOOD
# Despiking 19
# THIS IS NO GOOD
# THIS IS NO GOOD
# THIS IS NO GOOD
# THIS IS NO GOOD
# THIS IS NO GOOD
# THIS IS NO GOOD
# THIS IS NO GOOD
# ...

# %%
# %matplotlib 
plt.figure(figsize=(20, 4))
plt.plot(wetlab.ds.burst_time, wetlab.ds.burst_median_turbidity, label='Burst median')
plt.plot(wetlab.ds.burst_time, cl, label='Despiked burst median')
plt.grid()
plt.legend()
# Out:
# Using matplotlib backend: Qt5Agg
